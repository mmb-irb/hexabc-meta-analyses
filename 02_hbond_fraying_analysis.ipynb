# %% [markdown]
# ### Hydrogen Bonding
# ***
#
# **Jupyter Notebook** designed to demonstrate the power of the **hexABC REST-API programmatic interface**.
#
# The **REST-API** is used to extract **Hydrogen Bonds** statistics (nº of HBs, lifetimes) for specific **base pairs** (e.g. T-A, G-C) in different **MD simulations** and different **trimers** (e.g. TCA). The example is focused on **terminal trimers**, to study **fraying events**.
#
# The workflow is powered by the [hexABC database REST API](https://mmb.irbbarcelona.org/webdev3/hexABC/rest)
# ***

# %% [markdown]
# ### Importing auxiliary libraries

# %%
import requests
import urllib
import json
import plotly
import itertools
import ipywidgets
from IPython.display import display
from math import ceil

# %% [markdown]
# ### Defining auxiliary functions

# %%
#
# find_seq_term: finding MD simulations containing a sequence fragment; Returns metadata for the systems found.
#
def find_seq_term(json_data, pattern):
    complement_map = {'A': 'T', 'T': 'A', 'C': 'G', 'G': 'C'}
    complement = ''.join(complement_map[base] for base in reversed(pattern))

    matching_projects = []

    for project in json_data:
        watson_seq = project.get('sequences', [None])[0]

        if watson_seq and len(watson_seq) > 4:
            positions = []

            for motif in [pattern, complement]:
                if watson_seq.startswith(motif):
                    positions.append((motif, 2))
                if watson_seq.endswith(motif):
                    # End position is the start index of the motif at the end
                    pos = len(watson_seq) - len(motif)
                    positions.append((motif, pos + 2))  

            if positions:
                matching_projects.append({
                    'id': project['id'],
                    'name': project['name'],
                    'sequence': watson_seq,
                    'positions': positions
                })

    return matching_projects

# %% [markdown]
# ### Base REST-API URL

# %%
API_BASE_URL = "https://mmb.irbbarcelona.org/webdev3/hexABC/api"

# %% [markdown]
# ### Getting projects info
#
# Retrieving all the **projects metadata** from the **hexABC database**.
#
# * Endpoint used: https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects

# %%
url_get_projects = f'{API_BASE_URL}/projects?limit=1000'
with urllib.request.urlopen(url_get_projects) as response:
    r_projects = json.loads(response.read().decode("utf-8"))
print(json.dumps(r_projects, indent=4))

# %% [markdown]
# ### Pagination
#
# If the number of **projects** exceeds the default limit (50), **pagination** is needed. In this case, we need to loop over the returned pages to store all the desired information.

# %%
# Set a list to store all the mined metadata
projects_metadata = []

# Set a list to store all the mined accession values
accessions = []

# Get the number of projects from the previous response
n_projects = r_projects['total']

# Set the limit of projects per page
limit = 100

# Calculate the expected number of pages
pages = ceil(n_projects / limit)

# Iterate over pages
for page in range(1, pages + 1):
    
    print(f'Requesting page {page}/{pages}', end='\r')
    
    # Set the URL for the projects endpoint
    # Include both limit and page parameters
    paginated_url = f'{API_BASE_URL}/projects?limit={limit}&page={page}'
    
    # Query the API
    with urllib.request.urlopen(paginated_url) as resp:
        response = json.loads(resp.read().decode("utf-8"))
        
        # Mine target data
        projects = response['projects']
        project_accessions = [ project['accession'] for project in projects]
        accessions += project_accessions
        projects_metadata = [*projects_metadata, *projects]
    
print(f'We have obtained metadata information for {len(accessions)} simulations')

# %% [markdown]
# ## TRIMERS

# %% [markdown]
# ### Select the trimers
#
# Selecting the desired **trimers** from the list of all possible **DNA trimers** (e.g. GCG)

# %%
# Generate all possible DNA trimers
bases = ['A', 'T', 'C', 'G']
trimer_list = [''.join(p) for p in itertools.product(bases, repeat=3)]

mdsel = ipywidgets.Dropdown(
    options=trimer_list,
    description='Sel. trimer:',
    disabled=False,
    value='GCG' # default value
)
display(mdsel)

# %% [markdown]
# ### Searching for trimers
#
# Looking for specific **trimer sequence** within the **dataset**.

# %%
trimer = mdsel.value
results = find_seq_term(projects_metadata, trimer)

for result in results:
    print(f"{result['id']} - {result['name']}")
    print(f"  Watson strand: {result['sequence']}")
    for motif, pos in result['positions']:
        print(f"    ↳ found '{motif}' at position {pos}")

# %% [markdown]
# ### Extract hydrogen bond values
#
# For each **trimer** found, extract the **hydrogen bond** values **along time** for the central nucleotide (e.g. G**C**G).
#
# * Endpoint used: https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/{id}/analyses/hbonds

# %%
from collections import Counter, defaultdict
from itertools import groupby

aggregated_hbs = []
for result in results:
    print(f"{result['id']} - {result['name']}")
    print(f"  Watson strand: {result['sequence']}")
    
    url_param = f"{API_BASE_URL}/projects/{result['id']}/analyses/hbonds?from=1&to=-1&factor=500"
    print(url_param)
    
    with urllib.request.urlopen(url_param) as response:
        hbs = json.loads(response.read().decode("utf-8"))
        
    for motif, pos in result['positions']:
        print(f"    ↳ found '{motif}' at position {pos}")

        # Only interested in terminal (flanking) nucleotides
        if (pos > 2 and pos < 19):
            continue

        pos_index = pos 
        code = f"{pos_index}{motif[1]}"
        print("Code: " + code)

        # Complementary case
        if motif!=trimer:
            #pos_index = pos + 2
            code = f"{pos_index}{motif[1]}"
            print("Code -rev-: " + code)
        
        for bp_item in hbs['hbonds']:
            #print(json.dumps(bp_item['bp'], indent=4))
            
            print(bp_item['bp'])
            if (bp_item['bp'].startswith(code)):
                list_hbonds = bp_item['hbonds']
                aggregated_hbs.extend(list_hbonds)
                #print(list_hbonds)
                print(len(list_hbonds))
                
                # Percentages
                counts = Counter(list_hbonds)
                total = len(list_hbonds)
                percentages = {k: round((v / total) * 100, 2) for k, v in counts.items()}

                # Lifetimes
                lifetimes = defaultdict(list)
                for value, group in groupby(list_hbonds):
                    length = len(list(group))
                    lifetimes[value].append(length)

                # Output
                print("Percentages:")
                for value in sorted(percentages):
                    print(f"  {value}: {percentages[value]}%")

                # Output min and max per state
                print("Min and Max Lifetimes:")
                for state in sorted(lifetimes):
                    durations = lifetimes[state]
                    print(f"  {state}: min = {min(durations)}, max = {max(durations)}")
    
print("FINAL NUMBERS:")

# Percentages
counts = Counter(aggregated_hbs)
total = len(aggregated_hbs)
percentages = {k: round((v / total) * 100, 2) for k, v in counts.items()}

# Output
print("Percentages:")
for value in sorted(percentages):
    print(f"  {value}: {percentages[value]}%")
# Out:
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15T26A
# 14G27C
# 13T28A
# 12C29G
# 11C30G
# 10G31C
# 9A32T
# 8T33A
# 7A34T
# 6G35C
# 5T36A
# 4A37T
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15T26A
# 14G27C
# 13T28A
# 12C29G
# 11C30G
# 10G31C
# 9A32T
# 8T33A
# 7A34T
# 6G35C
# 5T36A
# 4A37T
# 3A38T
# 2C39G
# 1G40C
# seq012-1 - hexABC Sequence 012 - replica 1
#   Watson strand: GCAATGTCCAGGGGCGGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq012-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16G25C
# 15C26G
# 14G27C
# 13G28C
# 12G29C
# 11G30C
# 10A31T
# 9C32G
# 8C33G
# 7T34A
# 6G35C
# 5T36A
# 4A37T
# 3A38T
# 2C39G
# 1G40C
# seq012-2 - hexABC Sequence 012 - replica 2
#   Watson strand: GCAATGTCCAGGGGCGGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq012-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16G25C
# 15C26G
# 14G27C
# 13G28C
# 12G29C
# 11G30C
# 10A31T
# 9C32G
# 8C33G
# 7T34A
# 6G35C
# 5T36A
# 4A37T
# 3A38T
# 2C39G
# 1G40C
# seq013-1 - hexABC Sequence 013 - replica 1
#   Watson strand: GCACAAAGTCTCGGGCGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq013-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16C25G
# 15G26C
# 14G27C
# 13G28C
# 12C29G
# 11T30A
# 10C31G
# 9T32A
# 8G33C
# 7A34T
# 6A35T
# 5A36T
# 4C37G
# 490
# Percentages:
#   1: 0.2%
#   2: 1.02%
#   3: 98.78%
# Min and Max Lifetimes:
#   1: min = 1, max = 1
#   2: min = 1, max = 1
#   3: min = 9, max = 161
# 3A38T
# 2C39G
# 1G40C
# seq013-2 - hexABC Sequence 013 - replica 2
#   Watson strand: GCACAAAGTCTCGGGCGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq013-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16C25G
# 15G26C
# 14G27C
# 13G28C
# 12C29G
# 11T30A
# 10C31G
# 9T32A
# 8G33C
# 7A34T
# 6A35T
# 5A36T
# 4C37G
# 490
# Percentages:
#   2: 0.82%
#   3: 99.18%
# Min and Max Lifetimes:
#   2: min = 1, max = 1
#   3: min = 57, max = 127
# 3A38T
# 2C39G
# 1G40C
# seq014-1 - hexABC Sequence 014 - replica 1
#   Watson strand: GCACAGGTAGATTAGATAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq014-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17T24A
# 16A25T
# 15G26C
# 14A27T
# 13T28A
# 12T29A
# 11A30T
# 10G31C
# 9A32T
# 8T33A
# 7G34C
# 6G35C
# 5A36T
# 4C37G
# 490
# Percentages:
#   1: 0.41%
#   2: 1.02%
#   3: 98.57%
# Min and Max Lifetimes:
#   1: min = 1, max = 1
#   2: min = 1, max = 1
#   3: min = 8, max = 121
# 3A38T
# 2C39G
# 1G40C
# seq014-2 - hexABC Sequence 014 - replica 2
#   Watson strand: GCACAGGTAGATTAGATAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq014-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17T24A
# 16A25T
# 15G26C
# 14A27T
# 13T28A
# 12T29A
# 11A30T
# 10G31C
# 9A32T
# 8T33A
# 7G34C
# 6G35C
# 5A36T
# 4C37G
# 490
# Percentages:
#   0: 0.2%
#   2: 0.82%
#   3: 98.98%
# Min and Max Lifetimes:
#   0: min = 1, max = 1
#   2: min = 1, max = 1
#   3: min = 19, max = 154
# 3A38T
# 2C39G
# 1G40C
# seq015-1 - hexABC Sequence 015 - replica 1
#   Watson strand: GCACATGTCAGAATATTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq015-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16T25A
# 15A26T
# 14T27A
# 13A28T
# 12A29T
# 11G30C
# 10A31T
# 9C32G
# 8T33A
# 7G34C
# 6T35A
# 5A36T
# 4C37G
# 490
# Percentages:
#   2: 0.61%
#   3: 99.39%
# Min and Max Lifetimes:
#   2: min = 1, max = 1
#   3: min = 24, max = 207
# 3A38T
# 2C39G
# 1G40C
# seq015-2 - hexABC Sequence 015 - replica 2
#   Watson strand: GCACATGTCAGAATATTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq015-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16T25A
# 15A26T
# 14T27A
# 13A28T
# 12A29T
# 11G30C
# 10A31T
# 9C32G
# 8T33A
# 7G34C
# 6T35A
# 5A36T
# 4C37G
# 490
# Percentages:
#   3: 100.0%
# Min and Max Lifetimes:
#   3: min = 490, max = 490
# 3A38T
# 2C39G
# 1G40C
# seq016-1 - hexABC Sequence 016 - replica 1
#   Watson strand: GCACCCATTAAAAAGGCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq016-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16G25C
# 15G26C
# 14A27T
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9T32A
# 8T33A
# 7A34T
# 6C35G
# 5C36G
# 4C37G
# 490
# Percentages:
#   2: 1.22%
#   3: 98.78%
# Min and Max Lifetimes:
#   2: min = 1, max = 2
#   3: min = 14, max = 141
# 3A38T
# 2C39G
# 1G40C
# seq016-2 - hexABC Sequence 016 - replica 2
#   Watson strand: GCACCCATTAAAAAGGCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq016-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16G25C
# 15G26C
# 14A27T
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9T32A
# 8T33A
# 7A34T
# 6C35G
# 5C36G
# 4C37G
# 490
# Percentages:
#   2: 0.41%
#   3: 99.59%
# Min and Max Lifetimes:
#   2: min = 1, max = 1
#   3: min = 41, max = 389
# 3A38T
# 2C39G
# 1G40C
# seq017-1 - hexABC Sequence 017 - replica 1
#   Watson strand: GCACGCGTAAAAGCGCTAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq017-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17T24A
# 16C25G
# 15G26C
# 14C27G
# 13G28C
# 12A29T
# 11A30T
# 10A31T
# 9A32T
# 8T33A
# 7G34C
# 6C35G
# 5G36C
# 4C37G
# 490
# Percentages:
#   2: 0.82%
#   3: 99.18%
# Min and Max Lifetimes:
#   2: min = 1, max = 1
#   3: min = 18, max = 182
# 3A38T
# 2C39G
# 1G40C
# seq017-2 - hexABC Sequence 017 - replica 2
#   Watson strand: GCACGCGTAAAAGCGCTAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq017-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17T24A
# 16C25G
# 15G26C
# 14C27G
# 13G28C
# 12A29T
# 11A30T
# 10A31T
# 9A32T
# 8T33A
# 7G34C
# 6C35G
# 5G36C
# 4C37G
# 490
# Percentages:
#   3: 100.0%
# Min and Max Lifetimes:
#   3: min = 490, max = 490
# 3A38T
# 2C39G
# 1G40C
# seq018-1 - hexABC Sequence 018 - replica 1
#   Watson strand: GCACTAGTTTGCTGCAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq018-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15C26G
# 14G27C
# 13T28A
# 12C29G
# 11G30C
# 10T31A
# 9T32A
# 8T33A
# 7G34C
# 6A35T
# 5T36A
# 4C37G
# 490
# Percentages:
#   1: 0.2%
#   2: 0.61%
#   3: 99.18%
# Min and Max Lifetimes:
#   1: min = 1, max = 1
#   2: min = 1, max = 1
#   3: min = 69, max = 187
# 3A38T
# 2C39G
# 1G40C
# seq018-2 - hexABC Sequence 018 - replica 2
#   Watson strand: GCACTAGTTTGCTGCAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq018-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15C26G
# 14G27C
# 13T28A
# 12C29G
# 11G30C
# 10T31A
# 9T32A
# 8T33A
# 7G34C
# 6A35T
# 5T36A
# 4C37G
# 490
# Percentages:
#   1: 0.2%
#   2: 2.04%
#   3: 97.76%
# Min and Max Lifetimes:
#   1: min = 1, max = 1
#   2: min = 1, max = 1
#   3: min = 3, max = 136
# 3A38T
# 2C39G
# 1G40C
# seq019-1 - hexABC Sequence 019 - replica 1
#   Watson strand: GCACTCGTTTGATGCAGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq019-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16A25T
# 15C26G
# 14G27C
# 13T28A
# 12A29T
# 11G30C
# 10T31A
# 9T32A
# 8T33A
# 7G34C
# 6C35G
# 5T36A
# 4C37G
# 490
# Percentages:
#   2: 0.2%
#   3: 99.8%
# Min and Max Lifetimes:
#   2: min = 1, max = 1
#   3: min = 217, max = 272
# 3A38T
# 2C39G
# 1G40C
# seq019-2 - hexABC Sequence 019 - replica 2
#   Watson strand: GCACTCGTTTGATGCAGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq019-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16A25T
# 15C26G
# 14G27C
# 13T28A
# 12A29T
# 11G30C
# 10T31A
# 9T32A
# 8T33A
# 7G34C
# 6C35G
# 5T36A
# 4C37G
# 490
# Percentages:
#   2: 1.02%
#   3: 98.98%
# Min and Max Lifetimes:
#   2: min = 1, max = 1
#   3: min = 23, max = 235
# 3A38T
# 2C39G
# 1G40C
# seq020-1 - hexABC Sequence 020 - replica 1
#   Watson strand: GCAGAACAACGTCTGCCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq020-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16C25G
# 15G26C
# 14T27A
# 13C28G
# 12T29A
# 11G30C
# 10C31G
# 9A32T
# 8A33T
# 7C34G
# 6A35T
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq020-2 - hexABC Sequence 020 - replica 2
#   Watson strand: GCAGAACAACGTCTGCCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq020-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16C25G
# 15G26C
# 14T27A
# 13C28G
# 12T29A
# 11G30C
# 10C31G
# 9A32T
# 8A33T
# 7C34G
# 6A35T
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq021-1 - hexABC Sequence 021 - replica 1
#   Watson strand: GCAGACAGGAAAAACCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq021-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15C26G
# 14A27T
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9G32C
# 8G33C
# 7A34T
# 6C35G
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15C26G
# 14A27T
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9G32C
# 8G33C
# 7A34T
# 6C35G
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq021-2 - hexABC Sequence 021 - replica 2
#   Watson strand: GCAGACAGGAAAAACCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq021-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15C26G
# 14A27T
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9G32C
# 8G33C
# 7A34T
# 6C35G
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15C26G
# 14A27T
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9G32C
# 8G33C
# 7A34T
# 6C35G
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq022-1 - hexABC Sequence 022 - replica 1
#   Watson strand: GCAGAGCAGTCCATGAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq022-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15G26C
# 14T27A
# 13A28T
# 12C29G
# 11C30G
# 10T31A
# 9G32C
# 8A33T
# 7C34G
# 6G35C
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq022-2 - hexABC Sequence 022 - replica 2
#   Watson strand: GCAGAGCAGTCCATGAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq022-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15G26C
# 14T27A
# 13A28T
# 12C29G
# 11C30G
# 10T31A
# 9G32C
# 8A33T
# 7C34G
# 6G35C
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq023-1 - hexABC Sequence 023 - replica 1
#   Watson strand: GCAGATAACTGCCCAGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq023-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15A26T
# 14C27G
# 13C28G
# 12C29G
# 11G30C
# 10T31A
# 9C32G
# 8A33T
# 7A34T
# 6T35A
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15A26T
# 14C27G
# 13C28G
# 12C29G
# 11G30C
# 10T31A
# 9C32G
# 8A33T
# 7A34T
# 6T35A
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq023-2 - hexABC Sequence 023 - replica 2
#   Watson strand: GCAGATAACTGCCCAGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq023-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15A26T
# 14C27G
# 13C28G
# 12C29G
# 11G30C
# 10T31A
# 9C32G
# 8A33T
# 7A34T
# 6T35A
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15A26T
# 14C27G
# 13C28G
# 12C29G
# 11G30C
# 10T31A
# 9C32G
# 8A33T
# 7A34T
# 6T35A
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq024-1 - hexABC Sequence 024 - replica 1
#   Watson strand: GCAGATCTATTAGTTAACGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq024-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17A24T
# 16A25T
# 15T26A
# 14T27A
# 13G28C
# 12A29T
# 11T30A
# 10T31A
# 9A32T
# 8T33A
# 7C34G
# 6T35A
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq024-2 - hexABC Sequence 024 - replica 2
#   Watson strand: GCAGATCTATTAGTTAACGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq024-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17A24T
# 16A25T
# 15T26A
# 14T27A
# 13G28C
# 12A29T
# 11T30A
# 10T31A
# 9A32T
# 8T33A
# 7C34G
# 6T35A
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq025-1 - hexABC Sequence 025 - replica 1
#   Watson strand: GCAGCAAGATCATGTGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq025-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13T28A
# 12A29T
# 11C30G
# 10T31A
# 9A32T
# 8G33C
# 7A34T
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13T28A
# 12A29T
# 11C30G
# 10T31A
# 9A32T
# 8G33C
# 7A34T
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq025-2 - hexABC Sequence 025 - replica 2
#   Watson strand: GCAGCAAGATCATGTGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq025-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13T28A
# 12A29T
# 11C30G
# 10T31A
# 9A32T
# 8G33C
# 7A34T
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13T28A
# 12A29T
# 11C30G
# 10T31A
# 9A32T
# 8G33C
# 7A34T
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq026-1 - hexABC Sequence 026 - replica 1
#   Watson strand: GCAGCACGTAGGATCGAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq026-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16G25C
# 15C26G
# 14T27A
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9T32A
# 8G33C
# 7C34G
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq026-2 - hexABC Sequence 026 - replica 2
#   Watson strand: GCAGCACGTAGGATCGAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq026-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16G25C
# 15C26G
# 14T27A
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9T32A
# 8G33C
# 7C34G
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq027-1 - hexABC Sequence 027 - replica 1
#   Watson strand: GCAGCAGATATATAATGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq027-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16T25A
# 15A26T
# 14A27T
# 13T28A
# 12A29T
# 11T30A
# 10A31T
# 9T32A
# 8A33T
# 7G34C
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq027-2 - hexABC Sequence 027 - replica 2
#   Watson strand: GCAGCAGATATATAATGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq027-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16T25A
# 15A26T
# 14A27T
# 13T28A
# 12A29T
# 11T30A
# 10A31T
# 9T32A
# 8A33T
# 7G34C
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq028-1 - hexABC Sequence 028 - replica 1
#   Watson strand: GCAGCATTAGGAGATTTCGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq028-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17T24A
# 16T25A
# 15T26A
# 14A27T
# 13G28C
# 12A29T
# 11G30C
# 10G31C
# 9A32T
# 8T33A
# 7T34A
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq028-2 - hexABC Sequence 028 - replica 2
#   Watson strand: GCAGCATTAGGAGATTTCGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq028-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17T24A
# 16T25A
# 15T26A
# 14A27T
# 13G28C
# 12A29T
# 11G30C
# 10G31C
# 9A32T
# 8T33A
# 7T34A
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq029-1 - hexABC Sequence 029 - replica 1
#   Watson strand: GCAGCTTTAGAGATACAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq029-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16C25G
# 15A26T
# 14T27A
# 13A28T
# 12G29C
# 11A30T
# 10G31C
# 9A32T
# 8T33A
# 7T34A
# 6T35A
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq029-2 - hexABC Sequence 029 - replica 2
#   Watson strand: GCAGCTTTAGAGATACAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq029-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16C25G
# 15A26T
# 14T27A
# 13A28T
# 12G29C
# 11A30T
# 10G31C
# 9A32T
# 8T33A
# 7T34A
# 6T35A
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq030-1 - hexABC Sequence 030 - replica 1
#   Watson strand: GCAGGAATAGTCGTATCAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq030-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17C24G
# 16T25A
# 15A26T
# 14T27A
# 13G28C
# 12C29G
# 11T30A
# 10G31C
# 9A32T
# 8T33A
# 7A34T
# 6A35T
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq030-2 - hexABC Sequence 030 - replica 2
#   Watson strand: GCAGGAATAGTCGTATCAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq030-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17C24G
# 16T25A
# 15A26T
# 14T27A
# 13G28C
# 12C29G
# 11T30A
# 10G31C
# 9A32T
# 8T33A
# 7A34T
# 6A35T
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq031-1 - hexABC Sequence 031 - replica 1
#   Watson strand: GCAGGACTTGGATGTTAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq031-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16T25A
# 15T26A
# 14G27C
# 13T28A
# 12A29T
# 11G30C
# 10G31C
# 9T32A
# 8T33A
# 7C34G
# 6A35T
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq031-2 - hexABC Sequence 031 - replica 2
#   Watson strand: GCAGGACTTGGATGTTAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq031-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16T25A
# 15T26A
# 14G27C
# 13T28A
# 12A29T
# 11G30C
# 10G31C
# 9T32A
# 8T33A
# 7C34G
# 6A35T
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq032-1 - hexABC Sequence 032 - replica 1
#   Watson strand: GCAGGCGACTTACATGCAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq032-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17C24G
# 16G25C
# 15T26A
# 14A27T
# 13C28G
# 12A29T
# 11T30A
# 10T31A
# 9C32G
# 8A33T
# 7G34C
# 6C35G
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq032-2 - hexABC Sequence 032 - replica 2
#   Watson strand: GCAGGCGACTTACATGCAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq032-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17C24G
# 16G25C
# 15T26A
# 14A27T
# 13C28G
# 12A29T
# 11T30A
# 10T31A
# 9C32G
# 8A33T
# 7G34C
# 6C35G
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq033-1 - hexABC Sequence 033 - replica 1
#   Watson strand: GCAGGCTGCTGTTGTGGCGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq033-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13T28A
# 12T29A
# 11G30C
# 10T31A
# 9C32G
# 8G33C
# 7T34A
# 6C35G
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq033-2 - hexABC Sequence 033 - replica 2
#   Watson strand: GCAGGCTGCTGTTGTGGCGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq033-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13T28A
# 12T29A
# 11G30C
# 10T31A
# 9C32G
# 8G33C
# 7T34A
# 6C35G
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq034-1 - hexABC Sequence 034 - replica 1
#   Watson strand: GCAGGGCATATCGGGTAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq034-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16T25A
# 15G26C
# 14G27C
# 13G28C
# 12C29G
# 11T30A
# 10A31T
# 9T32A
# 8A33T
# 7C34G
# 6G35C
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq034-2 - hexABC Sequence 034 - replica 2
#   Watson strand: GCAGGGCATATCGGGTAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq034-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16T25A
# 15G26C
# 14G27C
# 13G28C
# 12C29G
# 11T30A
# 10A31T
# 9T32A
# 8A33T
# 7C34G
# 6G35C
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq035-1 - hexABC Sequence 035 - replica 1
#   Watson strand: GCAGGTACAGTCAGTGGCGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq035-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13A28T
# 12C29G
# 11T30A
# 10G31C
# 9A32T
# 8C33G
# 7A34T
# 6T35A
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq035-2 - hexABC Sequence 035 - replica 2
#   Watson strand: GCAGGTACAGTCAGTGGCGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq035-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13A28T
# 12C29G
# 11T30A
# 10G31C
# 9A32T
# 8C33G
# 7A34T
# 6T35A
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq036-1 - hexABC Sequence 036 - replica 1
#   Watson strand: GCAGTAGACGCCAATGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq036-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14A27T
# 13A28T
# 12C29G
# 11C30G
# 10G31C
# 9C32G
# 8A33T
# 7G34C
# 6A35T
# 5T36A
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14A27T
# 13A28T
# 12C29G
# 11C30G
# 10G31C
# 9C32G
# 8A33T
# 7G34C
# 6A35T
# 5T36A
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq036-2 - hexABC Sequence 036 - replica 2
#   Watson strand: GCAGTAGACGCCAATGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq036-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14A27T
# 13A28T
# 12C29G
# 11C30G
# 10G31C
# 9C32G
# 8A33T
# 7G34C
# 6A35T
# 5T36A
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14A27T
# 13A28T
# 12C29G
# 11C30G
# 10G31C
# 9C32G
# 8A33T
# 7G34C
# 6A35T
# 5T36A
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq037-1 - hexABC Sequence 037 - replica 1
#   Watson strand: GCATAACGTACTGTGCTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq037-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16C25G
# 15G26C
# 14T27A
# 13G28C
# 12T29A
# 11C30G
# 10A31T
# 9T32A
# 8G33C
# 7C34G
# 6A35T
# 5A36T
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq037-2 - hexABC Sequence 037 - replica 2
#   Watson strand: GCATAACGTACTGTGCTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq037-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16C25G
# 15G26C
# 14T27A
# 13G28C
# 12T29A
# 11C30G
# 10A31T
# 9T32A
# 8G33C
# 7C34G
# 6A35T
# 5A36T
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq038-1 - hexABC Sequence 038 - replica 1
#   Watson strand: GCATACCATAGACACAAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq038-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16A25T
# 15C26G
# 14A27T
# 13C28G
# 12A29T
# 11G30C
# 10A31T
# 9T32A
# 8A33T
# 7C34G
# 6C35G
# 5A36T
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq038-2 - hexABC Sequence 038 - replica 2
#   Watson strand: GCATACCATAGACACAAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq038-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16A25T
# 15C26G
# 14A27T
# 13C28G
# 12A29T
# 11G30C
# 10A31T
# 9T32A
# 8A33T
# 7C34G
# 6C35G
# 5A36T
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq039-1 - hexABC Sequence 039 - replica 1
#   Watson strand: GCATACGGTCGATGCGGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq039-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16G25C
# 15C26G
# 14G27C
# 13T28A
# 12A29T
# 11G30C
# 10C31G
# 9T32A
# 8G33C
# 7G34C
# 6C35G
# 5A36T
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq039-2 - hexABC Sequence 039 - replica 2
#   Watson strand: GCATACGGTCGATGCGGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq039-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16G25C
# 15C26G
# 14G27C
# 13T28A
# 12A29T
# 11G30C
# 10C31G
# 9T32A
# 8G33C
# 7G34C
# 6C35G
# 5A36T
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq040-1 - hexABC Sequence 040 - replica 1
#   Watson strand: GCATCAGAGCCGTGGCTAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq040-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17T24A
# 16C25G
# 15G26C
# 14G27C
# 13T28A
# 12G29C
# 11C30G
# 10C31G
# 9G32C
# 8A33T
# 7G34C
# 6A35T
# 5C36G
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq040-2 - hexABC Sequence 040 - replica 2
#   Watson strand: GCATCAGAGCCGTGGCTAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq040-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17T24A
# 16C25G
# 15G26C
# 14G27C
# 13T28A
# 12G29C
# 11C30G
# 10C31G
# 9G32C
# 8A33T
# 7G34C
# 6A35T
# 5C36G
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq041-1 - hexABC Sequence 041 - replica 1
#   Watson strand: GCATGTACGCTGGAGCACGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq041-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17A24T
# 16C25G
# 15G26C
# 14A27T
# 13G28C
# 12G29C
# 11T30A
# 10C31G
# 9G32C
# 8C33G
# 7A34T
# 6T35A
# 5G36C
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq041-2 - hexABC Sequence 041 - replica 2
#   Watson strand: GCATGTACGCTGGAGCACGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq041-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17A24T
# 16C25G
# 15G26C
# 14A27T
# 13G28C
# 12G29C
# 11T30A
# 10C31G
# 9G32C
# 8C33G
# 7A34T
# 6T35A
# 5G36C
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq042-1 - hexABC Sequence 042 - replica 1
#   Watson strand: GCATGTTGACAAACAGGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq042-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16G25C
# 15A26T
# 14C27G
# 13A28T
# 12A29T
# 11A30T
# 10C31G
# 9A32T
# 8G33C
# 7T34A
# 6T35A
# 5G36C
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq042-2 - hexABC Sequence 042 - replica 2
#   Watson strand: GCATGTTGACAAACAGGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq042-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16G25C
# 15A26T
# 14C27G
# 13A28T
# 12A29T
# 11A30T
# 10C31G
# 9A32T
# 8G33C
# 7T34A
# 6T35A
# 5G36C
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq043-1 - hexABC Sequence 043 - replica 1
#   Watson strand: GCATTACCAAGGGCCAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq043-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15C26G
# 14C27G
# 13G28C
# 12G29C
# 11G30C
# 10A31T
# 9A32T
# 8C33G
# 7C34G
# 6A35T
# 5T36A
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq043-2 - hexABC Sequence 043 - replica 2
#   Watson strand: GCATTACCAAGGGCCAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq043-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15C26G
# 14C27G
# 13G28C
# 12G29C
# 11G30C
# 10A31T
# 9A32T
# 8C33G
# 7C34G
# 6A35T
# 5T36A
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq044-1 - hexABC Sequence 044 - replica 1
#   Watson strand: GCATTTAGGCGGTGTAACGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq044-1/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17A24T
# 16A25T
# 15T26A
# 14G27C
# 13T28A
# 12G29C
# 11G30C
# 10C31G
# 9G32C
# 8G33C
# 7A34T
# 6T35A
# 5T36A
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq044-2 - hexABC Sequence 044 - replica 2
#   Watson strand: GCATTTAGGCGGTGTAACGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq044-2/analyses/hbonds?from=1&to=490
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17A24T
# 16A25T
# 15T26A
# 14G27C
# 13T28A
# 12G29C
# 11G30C
# 10C31G
# 9G32C
# 8G33C
# 7A34T
# 6T35A
# 5T36A
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq050-1 - hexABC Sequence 050 - replica 1
#   Watson strand: GCCAGGAGCGAATTTTATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq050-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16T25A
# 15T26A
# 14T27A
# 13T28A
# 12A29T
# 11A30T
# 10G31C
# 9C32G
# 8G33C
# 7A34T
# 6G35C
# 5G36C
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq050-2 - hexABC Sequence 050 - replica 2
#   Watson strand: GCCAGGAGCGAATTTTATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq050-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16T25A
# 15T26A
# 14T27A
# 13T28A
# 12A29T
# 11A30T
# 10G31C
# 9C32G
# 8G33C
# 7A34T
# 6G35C
# 5G36C
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq051-1 - hexABC Sequence 051 - replica 1
#   Watson strand: GCCAGGGCGTGTAGGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq051-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14G27C
# 13A28T
# 12T29A
# 11G30C
# 10T31A
# 9G32C
# 8C33G
# 7G34C
# 6G35C
# 5G36C
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq051-2 - hexABC Sequence 051 - replica 2
#   Watson strand: GCCAGGGCGTGTAGGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq051-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14G27C
# 13A28T
# 12T29A
# 11G30C
# 10T31A
# 9G32C
# 8C33G
# 7G34C
# 6G35C
# 5G36C
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq052-1 - hexABC Sequence 052 - replica 1
#   Watson strand: GCCATAAAGGGGAGGCGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq052-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15G26C
# 14G27C
# 13A28T
# 12G29C
# 11G30C
# 10G31C
# 9G32C
# 8A33T
# 7A34T
# 6A35T
# 5T36A
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq052-2 - hexABC Sequence 052 - replica 2
#   Watson strand: GCCATAAAGGGGAGGCGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq052-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15G26C
# 14G27C
# 13A28T
# 12G29C
# 11G30C
# 10G31C
# 9G32C
# 8A33T
# 7A34T
# 6A35T
# 5T36A
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq053-1 - hexABC Sequence 053 - replica 1
#   Watson strand: GCCATATGATGGAAGCTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq053-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16C25G
# 15G26C
# 14A27T
# 13A28T
# 12G29C
# 11G30C
# 10T31A
# 9A32T
# 8G33C
# 7T34A
# 6A35T
# 5T36A
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq053-2 - hexABC Sequence 053 - replica 2
#   Watson strand: GCCATATGATGGAAGCTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq053-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16C25G
# 15G26C
# 14A27T
# 13A28T
# 12G29C
# 11G30C
# 10T31A
# 9A32T
# 8G33C
# 7T34A
# 6A35T
# 5T36A
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq055-1 - hexABC Sequence 055 - replica 1
#   Watson strand: GCCATGAATGTAGAACGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq055-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15A26T
# 14A27T
# 13G28C
# 12A29T
# 11T30A
# 10G31C
# 9T32A
# 8A33T
# 7A34T
# 6G35C
# 5T36A
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq055-2 - hexABC Sequence 055 - replica 2
#   Watson strand: GCCATGAATGTAGAACGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq055-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15A26T
# 14A27T
# 13G28C
# 12A29T
# 11T30A
# 10G31C
# 9T32A
# 8A33T
# 7A34T
# 6G35C
# 5T36A
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq060-1 - hexABC Sequence 060 - replica 1
#   Watson strand: GCCCCACGCGCAAGGAGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq060-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16A25T
# 15G26C
# 14G27C
# 13A28T
# 12A29T
# 11C30G
# 10G31C
# 9C32G
# 8G33C
# 7C34G
# 6A35T
# 5C36G
# 4C37G
# 3C38G
# 2C39G
# 1G40C
# seq060-2 - hexABC Sequence 060 - replica 2
#   Watson strand: GCCCCACGCGCAAGGAGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq060-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16A25T
# 15G26C
# 14G27C
# 13A28T
# 12A29T
# 11C30G
# 10G31C
# 9C32G
# 8G33C
# 7C34G
# 6A35T
# 5C36G
# 4C37G
# 3C38G
# 2C39G
# 1G40C
# seq061-1 - hexABC Sequence 061 - replica 1
#   Watson strand: GCCCCGGGAGTAAACGTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq061-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16G25C
# 15C26G
# 14A27T
# 13A28T
# 12A29T
# 11T30A
# 10G31C
# 9A32T
# 8G33C
# 7G34C
# 6G35C
# 5C36G
# 4C37G
# 3C38G
# 2C39G
# 1G40C
# seq061-2 - hexABC Sequence 061 - replica 2
#   Watson strand: GCCCCGGGAGTAAACGTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq061-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16G25C
# 15C26G
# 14A27T
# 13A28T
# 12A29T
# 11T30A
# 10G31C
# 9A32T
# 8G33C
# 7G34C
# 6G35C
# 5C36G
# 4C37G
# 3C38G
# 2C39G
# 1G40C
# seq065-1 - hexABC Sequence 065 - replica 1
#   Watson strand: GCCGAACAGTGACACGTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq065-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16G25C
# 15C26G
# 14A27T
# 13C28G
# 12A29T
# 11G30C
# 10T31A
# 9G32C
# 8A33T
# 7C34G
# 6A35T
# 5A36T
# 4G37C
# 3C38G
# 2C39G
# 1G40C
# seq065-2 - hexABC Sequence 065 - replica 2
#   Watson strand: GCCGAACAGTGACACGTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq065-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16G25C
# 15C26G
# 14A27T
# 13C28G
# 12A29T
# 11G30C
# 10T31A
# 9G32C
# 8A33T
# 7C34G
# 6A35T
# 5A36T
# 4G37C
# 3C38G
# 2C39G
# 1G40C
# seq067-1 - hexABC Sequence 067 - replica 1
#   Watson strand: GCCGCGAGGGAAACGCTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq067-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16C25G
# 15G26C
# 14C27G
# 13A28T
# 12A29T
# 11A30T
# 10G31C
# 9G32C
# 8G33C
# 7A34T
# 6G35C
# 5C36G
# 4G37C
# 3C38G
# 2C39G
# 1G40C
# seq067-2 - hexABC Sequence 067 - replica 2
#   Watson strand: GCCGCGAGGGAAACGCTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq067-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16C25G
# 15G26C
# 14C27G
# 13A28T
# 12A29T
# 11A30T
# 10G31C
# 9G32C
# 8G33C
# 7A34T
# 6G35C
# 5C36G
# 4G37C
# 3C38G
# 2C39G
# 1G40C
# seq073-1 - hexABC Sequence 073 - replica 1
#   Watson strand: GCCGTATTGAGGATTCGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq073-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15T26A
# 14T27A
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9G32C
# 8T33A
# 7T34A
# 6A35T
# 5T36A
# 4G37C
# 3C38G
# 2C39G
# 1G40C
# seq073-2 - hexABC Sequence 073 - replica 2
#   Watson strand: GCCGTATTGAGGATTCGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq073-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15T26A
# 14T27A
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9G32C
# 8T33A
# 7T34A
# 6A35T
# 5T36A
# 4G37C
# 3C38G
# 2C39G
# 1G40C
# seq080-1 - hexABC Sequence 080 - replica 1
#   Watson strand: GCGAAACCCTGCAAGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq080-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14A27T
# 13A28T
# 12C29G
# 11G30C
# 10T31A
# 9C32G
# 8C33G
# 7C34G
# 6A35T
# 5A36T
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq080-2 - hexABC Sequence 080 - replica 2
#   Watson strand: GCGAAACCCTGCAAGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq080-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14A27T
# 13A28T
# 12C29G
# 11G30C
# 10T31A
# 9C32G
# 8C33G
# 7C34G
# 6A35T
# 5A36T
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq082-1 - hexABC Sequence 082 - replica 1
#   Watson strand: GCGAACATAGGGAGCTATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq082-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16T25A
# 15C26G
# 14G27C
# 13A28T
# 12G29C
# 11G30C
# 10G31C
# 9A32T
# 8T33A
# 7A34T
# 6C35G
# 5A36T
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq082-2 - hexABC Sequence 082 - replica 2
#   Watson strand: GCGAACATAGGGAGCTATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq082-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16T25A
# 15C26G
# 14G27C
# 13A28T
# 12G29C
# 11G30C
# 10G31C
# 9A32T
# 8T33A
# 7A34T
# 6C35G
# 5A36T
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq083-1 - hexABC Sequence 083 - replica 1
#   Watson strand: GCGAACGACCTTGTGAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq083-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15G26C
# 14T27A
# 13G28C
# 12T29A
# 11T30A
# 10C31G
# 9C32G
# 8A33T
# 7G34C
# 6C35G
# 5A36T
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq083-2 - hexABC Sequence 083 - replica 2
#   Watson strand: GCGAACGACCTTGTGAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq083-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15G26C
# 14T27A
# 13G28C
# 12T29A
# 11T30A
# 10C31G
# 9C32G
# 8A33T
# 7G34C
# 6C35G
# 5A36T
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq089-1 - hexABC Sequence 089 - replica 1
#   Watson strand: GCGAGGAGGAAGGGTAGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq089-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16A25T
# 15T26A
# 14G27C
# 13G28C
# 12G29C
# 11A30T
# 10A31T
# 9G32C
# 8G33C
# 7A34T
# 6G35C
# 5G36C
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq089-2 - hexABC Sequence 089 - replica 2
#   Watson strand: GCGAGGAGGAAGGGTAGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq089-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16A25T
# 15T26A
# 14G27C
# 13G28C
# 12G29C
# 11A30T
# 10A31T
# 9G32C
# 8G33C
# 7A34T
# 6G35C
# 5G36C
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq091-1 - hexABC Sequence 091 - replica 1
#   Watson strand: GCGATAGTATCCTGAAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq091-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15A26T
# 14G27C
# 13T28A
# 12C29G
# 11C30G
# 10T31A
# 9A32T
# 8T33A
# 7G34C
# 6A35T
# 5T36A
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq091-2 - hexABC Sequence 091 - replica 2
#   Watson strand: GCGATAGTATCCTGAAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq091-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15A26T
# 14G27C
# 13T28A
# 12C29G
# 11C30G
# 10T31A
# 9A32T
# 8T33A
# 7G34C
# 6A35T
# 5T36A
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq093-1 - hexABC Sequence 093 - replica 1
#   Watson strand: GCGCAATTGAAAATGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq093-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14T27A
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9G32C
# 8T33A
# 7T34A
# 6A35T
# 5A36T
# 4C37G
# 3G38C
# 2C39G
# 1G40C
# seq093-2 - hexABC Sequence 093 - replica 2
#   Watson strand: GCGCAATTGAAAATGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq093-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14T27A
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9G32C
# 8T33A
# 7T34A
# 6A35T
# 5A36T
# 4C37G
# 3G38C
# 2C39G
# 1G40C
# seq096-1 - hexABC Sequence 096 - replica 1
#   Watson strand: GCGCCGGCTAGGACCGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq096-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15C26G
# 14C27G
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9T32A
# 8C33G
# 7G34C
# 6G35C
# 5C36G
# 4C37G
# 3G38C
# 2C39G
# 1G40C
# seq096-2 - hexABC Sequence 096 - replica 2
#   Watson strand: GCGCCGGCTAGGACCGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq096-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15C26G
# 14C27G
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9T32A
# 8C33G
# 7G34C
# 6G35C
# 5C36G
# 4C37G
# 3G38C
# 2C39G
# 1G40C
# seq097-1 - hexABC Sequence 097 - replica 1
#   Watson strand: GCGCGCCGGATAATAATTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq097-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16A25T
# 15A26T
# 14T27A
# 13A28T
# 12A29T
# 11T30A
# 10A31T
# 9G32C
# 8G33C
# 7C34G
# 6C35G
# 5G36C
# 4C37G
# 3G38C
# 2C39G
# 1G40C
# seq097-2 - hexABC Sequence 097 - replica 2
#   Watson strand: GCGCGCCGGATAATAATTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq097-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16A25T
# 15A26T
# 14T27A
# 13A28T
# 12A29T
# 11T30A
# 10A31T
# 9G32C
# 8G33C
# 7C34G
# 6C35G
# 5G36C
# 4C37G
# 3G38C
# 2C39G
# 1G40C
# seq108-1 - hexABC Sequence 108 - replica 1
#   Watson strand: GCGGACGGAAGTATGTATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq108-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16T25A
# 15G26C
# 14T27A
# 13A28T
# 12T29A
# 11G30C
# 10A31T
# 9A32T
# 8G33C
# 7G34C
# 6C35G
# 5A36T
# 4G37C
# 3G38C
# 2C39G
# 1G40C
# seq108-2 - hexABC Sequence 108 - replica 2
#   Watson strand: GCGGACGGAAGTATGTATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq108-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16T25A
# 15G26C
# 14T27A
# 13A28T
# 12T29A
# 11G30C
# 10A31T
# 9A32T
# 8G33C
# 7G34C
# 6C35G
# 5A36T
# 4G37C
# 3G38C
# 2C39G
# 1G40C
# seq109-1 - hexABC Sequence 109 - replica 1
#   Watson strand: GCGGAGAATTGCGTGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq109-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14T27A
# 13G28C
# 12C29G
# 11G30C
# 10T31A
# 9T32A
# 8A33T
# 7A34T
# 6G35C
# 5A36T
# 4G37C
# 3G38C
# 2C39G
# 1G40C
# seq109-2 - hexABC Sequence 109 - replica 2
#   Watson strand: GCGGAGAATTGCGTGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq109-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14T27A
# 13G28C
# 12C29G
# 11G30C
# 10T31A
# 9T32A
# 8A33T
# 7A34T
# 6G35C
# 5A36T
# 4G37C
# 3G38C
# 2C39G
# 1G40C
# seq125-1 - hexABC Sequence 125 - replica 1
#   Watson strand: GCGGTAAGCGGGCAATGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq125-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16T25A
# 15A26T
# 14A27T
# 13C28G
# 12G29C
# 11G30C
# 10G31C
# 9C32G
# 8G33C
# 7A34T
# 6A35T
# 5T36A
# 4G37C
# 3G38C
# 2C39G
# 1G40C
# seq125-2 - hexABC Sequence 125 - replica 2
#   Watson strand: GCGGTAAGCGGGCAATGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq125-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16T25A
# 15A26T
# 14A27T
# 13C28G
# 12G29C
# 11G30C
# 10G31C
# 9C32G
# 8G33C
# 7A34T
# 6A35T
# 5T36A
# 4G37C
# 3G38C
# 2C39G
# 1G40C
# seq130-1 - hexABC Sequence 130 - replica 1
#   Watson strand: GCGTAACTCTTACGGGATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq130-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16G25C
# 15G26C
# 14G27C
# 13C28G
# 12A29T
# 11T30A
# 10T31A
# 9C32G
# 8T33A
# 7C34G
# 6A35T
# 5A36T
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq130-2 - hexABC Sequence 130 - replica 2
#   Watson strand: GCGTAACTCTTACGGGATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq130-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16G25C
# 15G26C
# 14G27C
# 13C28G
# 12A29T
# 11T30A
# 10T31A
# 9C32G
# 8T33A
# 7C34G
# 6A35T
# 5A36T
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq139-1 - hexABC Sequence 139 - replica 1
#   Watson strand: GCGTGACGGGTCGCTTGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq139-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16T25A
# 15T26A
# 14C27G
# 13G28C
# 12C29G
# 11T30A
# 10G31C
# 9G32C
# 8G33C
# 7C34G
# 6A35T
# 5G36C
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq139-2 - hexABC Sequence 139 - replica 2
#   Watson strand: GCGTGACGGGTCGCTTGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq139-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16T25A
# 15T26A
# 14C27G
# 13G28C
# 12C29G
# 11T30A
# 10G31C
# 9G32C
# 8G33C
# 7C34G
# 6A35T
# 5G36C
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq163-1 - hexABC Sequence 163 - replica 1
#   Watson strand: GCTCGACGACGTATGCGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq163-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15G26C
# 14T27A
# 13A28T
# 12T29A
# 11G30C
# 10C31G
# 9A32T
# 8G33C
# 7C34G
# 6A35T
# 5G36C
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq163-2 - hexABC Sequence 163 - replica 2
#   Watson strand: GCTCGACGACGTATGCGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq163-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15G26C
# 14T27A
# 13A28T
# 12T29A
# 11G30C
# 10C31G
# 9A32T
# 8G33C
# 7C34G
# 6A35T
# 5G36C
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq165-1 - hexABC Sequence 165 - replica 1
#   Watson strand: GCTCGCGAAGAAAGTACTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq165-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17C24G
# 16A25T
# 15T26A
# 14G27C
# 13A28T
# 12A29T
# 11A30T
# 10G31C
# 9A32T
# 8A33T
# 7G34C
# 6C35G
# 5G36C
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq165-2 - hexABC Sequence 165 - replica 2
#   Watson strand: GCTCGCGAAGAAAGTACTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq165-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17C24G
# 16A25T
# 15T26A
# 14G27C
# 13A28T
# 12A29T
# 11A30T
# 10G31C
# 9A32T
# 8A33T
# 7G34C
# 6C35G
# 5G36C
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq169-1 - hexABC Sequence 169 - replica 1
#   Watson strand: GCTGAGGCCGGTGAAACTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq169-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17C24G
# 16A25T
# 15A26T
# 14A27T
# 13G28C
# 12T29A
# 11G30C
# 10G31C
# 9C32G
# 8C33G
# 7G34C
# 6G35C
# 5A36T
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq169-2 - hexABC Sequence 169 - replica 2
#   Watson strand: GCTGAGGCCGGTGAAACTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq169-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17C24G
# 16A25T
# 15A26T
# 14A27T
# 13G28C
# 12T29A
# 11G30C
# 10G31C
# 9C32G
# 8C33G
# 7G34C
# 6G35C
# 5A36T
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq174-1 - hexABC Sequence 174 - replica 1
#   Watson strand: GCTGCGCAGAGTATTAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq174-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15T26A
# 14T27A
# 13A28T
# 12T29A
# 11G30C
# 10A31T
# 9G32C
# 8A33T
# 7C34G
# 6G35C
# 5C36G
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq174-2 - hexABC Sequence 174 - replica 2
#   Watson strand: GCTGCGCAGAGTATTAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq174-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15T26A
# 14T27A
# 13A28T
# 12T29A
# 11G30C
# 10A31T
# 9G32C
# 8A33T
# 7C34G
# 6G35C
# 5C36G
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq182-1 - hexABC Sequence 182 - replica 1
#   Watson strand: GCTGTGTGTTATTGGAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq182-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15G26C
# 14G27C
# 13T28A
# 12T29A
# 11A30T
# 10T31A
# 9T32A
# 8G33C
# 7T34A
# 6G35C
# 5T36A
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq182-2 - hexABC Sequence 182 - replica 2
#   Watson strand: GCTGTGTGTTATTGGAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq182-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15G26C
# 14G27C
# 13T28A
# 12T29A
# 11A30T
# 10T31A
# 9T32A
# 8G33C
# 7T34A
# 6G35C
# 5T36A
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq187-1 - hexABC Sequence 187 - replica 1
#   Watson strand: GCTTGGGGACTCTAGGCTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq187-1/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17C24G
# 16G25C
# 15G26C
# 14A27T
# 13T28A
# 12C29G
# 11T30A
# 10C31G
# 9A32T
# 8G33C
# 7G34C
# 6G35C
# 5G36C
# 4T37A
# 3T38A
# 2C39G
# 1G40C
# seq187-2 - hexABC Sequence 187 - replica 2
#   Watson strand: GCTTGGGGACTCTAGGCTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq187-2/analyses/hbonds?from=1&to=490
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17C24G
# 16G25C
# 15G26C
# 14A27T
# 13T28A
# 12C29G
# 11T30A
# 10C31G
# 9A32T
# 8G33C
# 7G34C
# 6G35C
# 5G36C
# 4T37A
# 3T38A
# 2C39G
# 1G40C
# FINAL NUMBERS:
# Percentages:
#   0: 0.01%
#   1: 0.07%
#   2: 0.76%
#   3: 99.15%

# %% [markdown]
# ### Plotting hydrogen bond values
#
# **Pie Chart** representing HBs statistics for the specific **trimer**. <br>
# Less than 3 HBs (for C,G) or 2 HBs (for A,T) means **unstable/broken base pairs**.

# %%
import plotly.graph_objects as go

# Filter and prep labels and values
labels = [f"{k} HBs" for k, v in percentages.items()]
values = list(percentages.values())

fig = go.Figure(data=[go.Pie(
    labels=labels,
    values=values,
    hole=0.4,  # Makes it a donut
    pull=[0.05 if v < 5 else 0 for v in values],  # Emphasize smaller slices
    textinfo='label+percent',
    marker=dict(colors=['#FFDD57', '#FF6B6B', '#4ECDC4', '#556270'])
)])

fig.update_layout(
    title_text=f"State Distribution for {trimer} trimer",
    title_font_size=20,
    showlegend=True,
    annotations=[
        dict(text=f"{trimer}", x=0.5, y=0.5, font_size=14, showarrow=False),
    ]
)

fig.show()

# %% [markdown]
# ## TRIMERS COMPARISON

# %% [markdown]
# ### Select the trimers for comparison
#
# Selecting the desired **trimers** from the list of all possible **DNA trimers** (e.g. GCC - GCG)

# %%
# Generate all possible DNA trimers
bases = ['A', 'T', 'C', 'G']
trimer_list = [''.join(p) for p in itertools.product(bases, repeat=3)]
trimer_pairs_list = [f"{a}-{b}" for a, b in itertools.combinations(trimer_list, 2)]

mdsel = ipywidgets.Dropdown(
    options=trimer_pairs_list,
    description='Sel. trimer pair:',
    disabled=False,
    value='GCC-GCG' # default value
)
display(mdsel)

# %% [markdown]
# ### Extract hydrogen bond values
#
# For each **trimer** found, extract the **hydrogen bond** values **along time** for the central nucleotide (e.g. G**C**G).
#
# * Endpoint used: https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/{id}/analyses/hbonds

# %%
from collections import Counter, defaultdict
from itertools import groupby

trimer1, trimer2 = mdsel.value.split('-')

results = find_seq_term(projects_metadata, trimer1)

aggregated_hbs_trimer1 = []
aggregated_hbs_lt_trimer1 = defaultdict(list)
for result in results:
    print(f"{result['id']} - {result['name']}")
    print(f"  Watson strand: {result['sequence']}")

    url_param = f"{API_BASE_URL}/projects/{result['id']}/analyses/hbonds?from=1&to=-1&factor=500"
    print(url_param)
    
    with urllib.request.urlopen(url_param) as response:
        hbs = json.loads(response.read().decode("utf-8"))
        
    for motif, pos in result['positions']:
        print(f"    ↳ found '{motif}' at position {pos}")

        # Only interested in terminal (flanking) nucleotides
        if (pos > 2 and pos < 19):
            continue
        
        pos_index = pos
        code = f"{pos_index}{motif[1]}"
        print("Code: " + code)

        # Complementary case
        if motif!=trimer:
            code = f"{pos_index}{motif[1]}"
            print("Code -rev-: " + code)
        
        for bp_item in hbs['hbonds']:
            
            print(bp_item['bp'])
            if (bp_item['bp'].startswith(code)):
                list_hbonds = bp_item['hbonds']
                aggregated_hbs_trimer1.extend(list_hbonds)
                
                # Percentages
                counts = Counter(list_hbonds)
                total = len(list_hbonds)
                percentages = {k: round((v / total) * 100, 2) for k, v in counts.items()}

                # Lifetimes
                lifetimes = defaultdict(list)
                for value, group in groupby(list_hbonds):
                    length = len(list(group))
                    lifetimes[value].append(length)
                    aggregated_hbs_lt_trimer1[value].extend([length])

                # Output
                print("Percentages:")
                for value in sorted(percentages):
                    print(f"  {value}: {percentages[value]}%")

                # Output min and max per state
                print("Min and Max Lifetimes:")
                for state in sorted(lifetimes):
                    durations = lifetimes[state]
                    print(f"  {state}: min = {min(durations)}, max = {max(durations)}")
    
print("FINAL NUMBERS:")

# Percentages
counts = Counter(aggregated_hbs_trimer1)
total = len(aggregated_hbs_trimer1)
percentages_trimer1 = {k: round((v / total) * 100, 2) for k, v in counts.items()}

# Output
print("Percentages Trimer 1:")
for value in sorted(percentages_trimer1):
    print(f"  {value}: {percentages_trimer1[value]}%")

    
###############
# TRIMER 2
###############
    
results = find_seq_term(projects_metadata, trimer2)

aggregated_hbs_trimer2 = []
aggregated_hbs_lt_trimer2 = defaultdict(list)
for result in results:
    print(f"{result['id']} - {result['name']}")
    print(f"  Watson strand: {result['sequence']}")
        
    url_param = f"{API_BASE_URL}/projects/{result['id']}/analyses/hbonds?from=1&to=-1&factor=500"
    print(url_param)
    
    with urllib.request.urlopen(url_param) as response:
        hbs = json.loads(response.read().decode("utf-8"))
        
    for motif, pos in result['positions']:
        print(f"    ↳ found '{motif}' at position {pos}")

        # Only interested in terminal (flanking) nucleotides
        if (pos > 2 and pos < 19):
            continue

        pos_index = pos
        code = f"{pos_index}{motif[1]}"
        print("Code: " + code)

        # Complementary case
        if motif!=trimer:
            code = f"{pos_index}{motif[1]}"
            print("Code -rev-: " + code)
        
        for bp_item in hbs['hbonds']:
            
            print(bp_item['bp'])
            if (bp_item['bp'].startswith(code)):
                list_hbonds = bp_item['hbonds']
                aggregated_hbs_trimer2.extend(list_hbonds)
                
                # Percentages
                counts = Counter(list_hbonds)
                total = len(list_hbonds)
                percentages = {k: round((v / total) * 100, 2) for k, v in counts.items()}

                # Lifetimes
                lifetimes = defaultdict(list)
                for value, group in groupby(list_hbonds):
                    length = len(list(group))
                    lifetimes[value].append(length)
                    aggregated_hbs_lt_trimer2[value].extend([length])

                # Output
                print("Percentages:")
                for value in sorted(percentages):
                    print(f"  {value}: {percentages[value]}%")

                # Output min and max per state
                print("Min and Max Lifetimes:")
                for state in sorted(lifetimes):
                    durations = lifetimes[state]
                    print(f"  {state}: min = {min(durations)}, max = {max(durations)}")
    
print("FINAL NUMBERS:")

# Percentages
counts = Counter(aggregated_hbs_trimer2)
total = len(aggregated_hbs_trimer2)
percentages_trimer2 = {k: round((v / total) * 100, 2) for k, v in counts.items()}

# Output
print("Percentages Trimer 2:")
for value in sorted(percentages_trimer2):
    print(f"  {value}: {percentages_trimer2[value]}%")
    
# Output min and max per state
print("Min and Max Lifetimes Trimer 1:")
for state in sorted(aggregated_hbs_lt_trimer1):
    durations = aggregated_hbs_lt_trimer1[state]
    print(f"  {state}: min = {min(durations)}, max = {max(durations)}")

# Output min and max per state
print("Min and Max Lifetimes Trimer 2:")
for state in sorted(aggregated_hbs_lt_trimer2):
    durations = aggregated_hbs_lt_trimer2[state]
    print(f"  {state}: min = {min(durations)}, max = {max(durations)}")
# Out:
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15T26A
# 14G27C
# 13T28A
# 12C29G
# 11C30G
# 10G31C
# 9A32T
# 8T33A
# 7A34T
# 6G35C
# 5T36A
# 4A37T
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15T26A
# 14G27C
# 13T28A
# 12C29G
# 11C30G
# 10G31C
# 9A32T
# 8T33A
# 7A34T
# 6G35C
# 5T36A
# 4A37T
# 3A38T
# 2C39G
# 1G40C
# seq012-1 - hexABC Sequence 012 - replica 1
#   Watson strand: GCAATGTCCAGGGGCGGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq012-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16G25C
# 15C26G
# 14G27C
# 13G28C
# 12G29C
# 11G30C
# 10A31T
# 9C32G
# 8C33G
# 7T34A
# 6G35C
# 5T36A
# 4A37T
# 3A38T
# 2C39G
# 1G40C
# seq012-2 - hexABC Sequence 012 - replica 2
#   Watson strand: GCAATGTCCAGGGGCGGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq012-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16G25C
# 15C26G
# 14G27C
# 13G28C
# 12G29C
# 11G30C
# 10A31T
# 9C32G
# 8C33G
# 7T34A
# 6G35C
# 5T36A
# 4A37T
# 3A38T
# 2C39G
# 1G40C
# seq013-1 - hexABC Sequence 013 - replica 1
#   Watson strand: GCACAAAGTCTCGGGCGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq013-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16C25G
# 15G26C
# 14G27C
# 13G28C
# 12C29G
# 11T30A
# 10C31G
# 9T32A
# 8G33C
# 7A34T
# 6A35T
# 5A36T
# 4C37G
# Percentages:
#   0: 0.01%
#   1: 0.16%
#   2: 0.94%
#   3: 98.89%
# Min and Max Lifetimes:
#   0: min = 1, max = 7
#   1: min = 1, max = 53
#   2: min = 1, max = 3
#   3: min = 1, max = 898
# 3A38T
# 2C39G
# 1G40C
# seq013-2 - hexABC Sequence 013 - replica 2
#   Watson strand: GCACAAAGTCTCGGGCGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq013-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16C25G
# 15G26C
# 14G27C
# 13G28C
# 12C29G
# 11T30A
# 10C31G
# 9T32A
# 8G33C
# 7A34T
# 6A35T
# 5A36T
# 4C37G
# Percentages:
#   0: 0.01%
#   1: 0.11%
#   2: 0.91%
#   3: 98.97%
# Min and Max Lifetimes:
#   0: min = 1, max = 25
#   1: min = 1, max = 16
#   2: min = 1, max = 2
#   3: min = 1, max = 977
# 3A38T
# 2C39G
# 1G40C
# seq014-1 - hexABC Sequence 014 - replica 1
#   Watson strand: GCACAGGTAGATTAGATAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq014-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17T24A
# 16A25T
# 15G26C
# 14A27T
# 13T28A
# 12T29A
# 11A30T
# 10G31C
# 9A32T
# 8T33A
# 7G34C
# 6G35C
# 5A36T
# 4C37G
# Percentages:
#   0: 0.03%
#   1: 0.15%
#   2: 0.87%
#   3: 98.95%
# Min and Max Lifetimes:
#   0: min = 1, max = 104
#   1: min = 1, max = 40
#   2: min = 1, max = 3
#   3: min = 1, max = 1023
# 3A38T
# 2C39G
# 1G40C
# seq014-2 - hexABC Sequence 014 - replica 2
#   Watson strand: GCACAGGTAGATTAGATAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq014-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17T24A
# 16A25T
# 15G26C
# 14A27T
# 13T28A
# 12T29A
# 11A30T
# 10G31C
# 9A32T
# 8T33A
# 7G34C
# 6G35C
# 5A36T
# 4C37G
# Percentages:
#   0: 0.12%
#   1: 0.15%
#   2: 0.95%
#   3: 98.79%
# Min and Max Lifetimes:
#   0: min = 1, max = 475
#   1: min = 1, max = 24
#   2: min = 1, max = 8
#   3: min = 1, max = 1032
# 3A38T
# 2C39G
# 1G40C
# seq015-1 - hexABC Sequence 015 - replica 1
#   Watson strand: GCACATGTCAGAATATTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq015-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16T25A
# 15A26T
# 14T27A
# 13A28T
# 12A29T
# 11G30C
# 10A31T
# 9C32G
# 8T33A
# 7G34C
# 6T35A
# 5A36T
# 4C37G
# Percentages:
#   0: 0.0%
#   1: 0.12%
#   2: 0.78%
#   3: 99.09%
# Min and Max Lifetimes:
#   0: min = 1, max = 4
#   1: min = 1, max = 37
#   2: min = 1, max = 4
#   3: min = 1, max = 981
# 3A38T
# 2C39G
# 1G40C
# seq015-2 - hexABC Sequence 015 - replica 2
#   Watson strand: GCACATGTCAGAATATTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq015-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16T25A
# 15A26T
# 14T27A
# 13A28T
# 12A29T
# 11G30C
# 10A31T
# 9C32G
# 8T33A
# 7G34C
# 6T35A
# 5A36T
# 4C37G
# Percentages:
#   0: 1.68%
#   1: 0.11%
#   2: 0.81%
#   3: 97.39%
# Min and Max Lifetimes:
#   0: min = 1, max = 4606
#   1: min = 1, max = 23
#   2: min = 1, max = 3
#   3: min = 1, max = 1073
# 3A38T
# 2C39G
# 1G40C
# seq016-1 - hexABC Sequence 016 - replica 1
#   Watson strand: GCACCCATTAAAAAGGCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq016-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16G25C
# 15G26C
# 14A27T
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9T32A
# 8T33A
# 7A34T
# 6C35G
# 5C36G
# 4C37G
# Percentages:
#   0: 0.01%
#   1: 0.09%
#   2: 0.53%
#   3: 99.38%
# Min and Max Lifetimes:
#   0: min = 1, max = 9
#   1: min = 1, max = 18
#   2: min = 1, max = 4
#   3: min = 1, max = 1639
# 3A38T
# 2C39G
# 1G40C
# seq016-2 - hexABC Sequence 016 - replica 2
#   Watson strand: GCACCCATTAAAAAGGCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq016-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16G25C
# 15G26C
# 14A27T
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9T32A
# 8T33A
# 7A34T
# 6C35G
# 5C36G
# 4C37G
# Percentages:
#   0: 0.01%
#   1: 0.07%
#   2: 0.5%
#   3: 99.43%
# Min and Max Lifetimes:
#   0: min = 1, max = 20
#   1: min = 1, max = 20
#   2: min = 1, max = 3
#   3: min = 1, max = 1814
# 3A38T
# 2C39G
# 1G40C
# seq017-1 - hexABC Sequence 017 - replica 1
#   Watson strand: GCACGCGTAAAAGCGCTAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq017-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17T24A
# 16C25G
# 15G26C
# 14C27G
# 13G28C
# 12A29T
# 11A30T
# 10A31T
# 9A32T
# 8T33A
# 7G34C
# 6C35G
# 5G36C
# 4C37G
# Percentages:
#   0: 0.04%
#   1: 0.13%
#   2: 0.69%
#   3: 99.14%
# Min and Max Lifetimes:
#   0: min = 1, max = 134
#   1: min = 1, max = 61
#   2: min = 1, max = 3
#   3: min = 1, max = 1193
# 3A38T
# 2C39G
# 1G40C
# seq017-2 - hexABC Sequence 017 - replica 2
#   Watson strand: GCACGCGTAAAAGCGCTAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq017-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17T24A
# 16C25G
# 15G26C
# 14C27G
# 13G28C
# 12A29T
# 11A30T
# 10A31T
# 9A32T
# 8T33A
# 7G34C
# 6C35G
# 5G36C
# 4C37G
# Percentages:
#   0: 0.02%
#   1: 0.16%
#   2: 0.72%
#   3: 99.1%
# Min and Max Lifetimes:
#   0: min = 1, max = 30
#   1: min = 1, max = 51
#   2: min = 1, max = 9
#   3: min = 1, max = 1402
# 3A38T
# 2C39G
# 1G40C
# seq018-1 - hexABC Sequence 018 - replica 1
#   Watson strand: GCACTAGTTTGCTGCAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq018-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15C26G
# 14G27C
# 13T28A
# 12C29G
# 11G30C
# 10T31A
# 9T32A
# 8T33A
# 7G34C
# 6A35T
# 5T36A
# 4C37G
# Percentages:
#   0: 0.0%
#   1: 0.04%
#   2: 1.04%
#   3: 98.92%
# Min and Max Lifetimes:
#   0: min = 1, max = 1
#   1: min = 1, max = 4
#   2: min = 1, max = 2
#   3: min = 1, max = 742
# 3A38T
# 2C39G
# 1G40C
# seq018-2 - hexABC Sequence 018 - replica 2
#   Watson strand: GCACTAGTTTGCTGCAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq018-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15C26G
# 14G27C
# 13T28A
# 12C29G
# 11G30C
# 10T31A
# 9T32A
# 8T33A
# 7G34C
# 6A35T
# 5T36A
# 4C37G
# Percentages:
#   0: 0.01%
#   1: 0.05%
#   2: 1.03%
#   3: 98.91%
# Min and Max Lifetimes:
#   0: min = 1, max = 55
#   1: min = 1, max = 10
#   2: min = 1, max = 3
#   3: min = 1, max = 909
# 3A38T
# 2C39G
# 1G40C
# seq019-1 - hexABC Sequence 019 - replica 1
#   Watson strand: GCACTCGTTTGATGCAGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq019-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16A25T
# 15C26G
# 14G27C
# 13T28A
# 12A29T
# 11G30C
# 10T31A
# 9T32A
# 8T33A
# 7G34C
# 6C35G
# 5T36A
# 4C37G
# Percentages:
#   0: 0.0%
#   1: 0.02%
#   2: 0.74%
#   3: 99.23%
# Min and Max Lifetimes:
#   0: min = 1, max = 1
#   1: min = 1, max = 14
#   2: min = 1, max = 3
#   3: min = 1, max = 1301
# 3A38T
# 2C39G
# 1G40C
# seq019-2 - hexABC Sequence 019 - replica 2
#   Watson strand: GCACTCGTTTGATGCAGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq019-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16A25T
# 15C26G
# 14G27C
# 13T28A
# 12A29T
# 11G30C
# 10T31A
# 9T32A
# 8T33A
# 7G34C
# 6C35G
# 5T36A
# 4C37G
# Percentages:
#   0: 0.0%
#   1: 0.03%
#   2: 0.73%
#   3: 99.24%
# Min and Max Lifetimes:
#   0: min = 1, max = 1
#   1: min = 1, max = 14
#   2: min = 1, max = 2
#   3: min = 1, max = 944
# 3A38T
# 2C39G
# 1G40C
# seq020-1 - hexABC Sequence 020 - replica 1
#   Watson strand: GCAGAACAACGTCTGCCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq020-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16C25G
# 15G26C
# 14T27A
# 13C28G
# 12T29A
# 11G30C
# 10C31G
# 9A32T
# 8A33T
# 7C34G
# 6A35T
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq020-2 - hexABC Sequence 020 - replica 2
#   Watson strand: GCAGAACAACGTCTGCCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq020-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16C25G
# 15G26C
# 14T27A
# 13C28G
# 12T29A
# 11G30C
# 10C31G
# 9A32T
# 8A33T
# 7C34G
# 6A35T
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq021-1 - hexABC Sequence 021 - replica 1
#   Watson strand: GCAGACAGGAAAAACCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq021-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15C26G
# 14A27T
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9G32C
# 8G33C
# 7A34T
# 6C35G
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15C26G
# 14A27T
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9G32C
# 8G33C
# 7A34T
# 6C35G
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq021-2 - hexABC Sequence 021 - replica 2
#   Watson strand: GCAGACAGGAAAAACCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq021-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15C26G
# 14A27T
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9G32C
# 8G33C
# 7A34T
# 6C35G
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15C26G
# 14A27T
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9G32C
# 8G33C
# 7A34T
# 6C35G
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq022-1 - hexABC Sequence 022 - replica 1
#   Watson strand: GCAGAGCAGTCCATGAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq022-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15G26C
# 14T27A
# 13A28T
# 12C29G
# 11C30G
# 10T31A
# 9G32C
# 8A33T
# 7C34G
# 6G35C
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq022-2 - hexABC Sequence 022 - replica 2
#   Watson strand: GCAGAGCAGTCCATGAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq022-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15G26C
# 14T27A
# 13A28T
# 12C29G
# 11C30G
# 10T31A
# 9G32C
# 8A33T
# 7C34G
# 6G35C
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq023-1 - hexABC Sequence 023 - replica 1
#   Watson strand: GCAGATAACTGCCCAGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq023-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15A26T
# 14C27G
# 13C28G
# 12C29G
# 11G30C
# 10T31A
# 9C32G
# 8A33T
# 7A34T
# 6T35A
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15A26T
# 14C27G
# 13C28G
# 12C29G
# 11G30C
# 10T31A
# 9C32G
# 8A33T
# 7A34T
# 6T35A
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq023-2 - hexABC Sequence 023 - replica 2
#   Watson strand: GCAGATAACTGCCCAGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq023-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15A26T
# 14C27G
# 13C28G
# 12C29G
# 11G30C
# 10T31A
# 9C32G
# 8A33T
# 7A34T
# 6T35A
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15A26T
# 14C27G
# 13C28G
# 12C29G
# 11G30C
# 10T31A
# 9C32G
# 8A33T
# 7A34T
# 6T35A
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq024-1 - hexABC Sequence 024 - replica 1
#   Watson strand: GCAGATCTATTAGTTAACGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq024-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17A24T
# 16A25T
# 15T26A
# 14T27A
# 13G28C
# 12A29T
# 11T30A
# 10T31A
# 9A32T
# 8T33A
# 7C34G
# 6T35A
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq024-2 - hexABC Sequence 024 - replica 2
#   Watson strand: GCAGATCTATTAGTTAACGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq024-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17A24T
# 16A25T
# 15T26A
# 14T27A
# 13G28C
# 12A29T
# 11T30A
# 10T31A
# 9A32T
# 8T33A
# 7C34G
# 6T35A
# 5A36T
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq025-1 - hexABC Sequence 025 - replica 1
#   Watson strand: GCAGCAAGATCATGTGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq025-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13T28A
# 12A29T
# 11C30G
# 10T31A
# 9A32T
# 8G33C
# 7A34T
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13T28A
# 12A29T
# 11C30G
# 10T31A
# 9A32T
# 8G33C
# 7A34T
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq025-2 - hexABC Sequence 025 - replica 2
#   Watson strand: GCAGCAAGATCATGTGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq025-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13T28A
# 12A29T
# 11C30G
# 10T31A
# 9A32T
# 8G33C
# 7A34T
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13T28A
# 12A29T
# 11C30G
# 10T31A
# 9A32T
# 8G33C
# 7A34T
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq026-1 - hexABC Sequence 026 - replica 1
#   Watson strand: GCAGCACGTAGGATCGAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq026-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16G25C
# 15C26G
# 14T27A
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9T32A
# 8G33C
# 7C34G
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq026-2 - hexABC Sequence 026 - replica 2
#   Watson strand: GCAGCACGTAGGATCGAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq026-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16G25C
# 15C26G
# 14T27A
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9T32A
# 8G33C
# 7C34G
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq027-1 - hexABC Sequence 027 - replica 1
#   Watson strand: GCAGCAGATATATAATGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq027-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16T25A
# 15A26T
# 14A27T
# 13T28A
# 12A29T
# 11T30A
# 10A31T
# 9T32A
# 8A33T
# 7G34C
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq027-2 - hexABC Sequence 027 - replica 2
#   Watson strand: GCAGCAGATATATAATGAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq027-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17G24C
# 16T25A
# 15A26T
# 14A27T
# 13T28A
# 12A29T
# 11T30A
# 10A31T
# 9T32A
# 8A33T
# 7G34C
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq028-1 - hexABC Sequence 028 - replica 1
#   Watson strand: GCAGCATTAGGAGATTTCGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq028-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17T24A
# 16T25A
# 15T26A
# 14A27T
# 13G28C
# 12A29T
# 11G30C
# 10G31C
# 9A32T
# 8T33A
# 7T34A
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq028-2 - hexABC Sequence 028 - replica 2
#   Watson strand: GCAGCATTAGGAGATTTCGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq028-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17T24A
# 16T25A
# 15T26A
# 14A27T
# 13G28C
# 12A29T
# 11G30C
# 10G31C
# 9A32T
# 8T33A
# 7T34A
# 6A35T
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq029-1 - hexABC Sequence 029 - replica 1
#   Watson strand: GCAGCTTTAGAGATACAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq029-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16C25G
# 15A26T
# 14T27A
# 13A28T
# 12G29C
# 11A30T
# 10G31C
# 9A32T
# 8T33A
# 7T34A
# 6T35A
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq029-2 - hexABC Sequence 029 - replica 2
#   Watson strand: GCAGCTTTAGAGATACAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq029-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16C25G
# 15A26T
# 14T27A
# 13A28T
# 12G29C
# 11A30T
# 10G31C
# 9A32T
# 8T33A
# 7T34A
# 6T35A
# 5C36G
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq030-1 - hexABC Sequence 030 - replica 1
#   Watson strand: GCAGGAATAGTCGTATCAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq030-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17C24G
# 16T25A
# 15A26T
# 14T27A
# 13G28C
# 12C29G
# 11T30A
# 10G31C
# 9A32T
# 8T33A
# 7A34T
# 6A35T
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq030-2 - hexABC Sequence 030 - replica 2
#   Watson strand: GCAGGAATAGTCGTATCAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq030-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17C24G
# 16T25A
# 15A26T
# 14T27A
# 13G28C
# 12C29G
# 11T30A
# 10G31C
# 9A32T
# 8T33A
# 7A34T
# 6A35T
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq031-1 - hexABC Sequence 031 - replica 1
#   Watson strand: GCAGGACTTGGATGTTAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq031-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16T25A
# 15T26A
# 14G27C
# 13T28A
# 12A29T
# 11G30C
# 10G31C
# 9T32A
# 8T33A
# 7C34G
# 6A35T
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq031-2 - hexABC Sequence 031 - replica 2
#   Watson strand: GCAGGACTTGGATGTTAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq031-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16T25A
# 15T26A
# 14G27C
# 13T28A
# 12A29T
# 11G30C
# 10G31C
# 9T32A
# 8T33A
# 7C34G
# 6A35T
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq032-1 - hexABC Sequence 032 - replica 1
#   Watson strand: GCAGGCGACTTACATGCAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq032-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17C24G
# 16G25C
# 15T26A
# 14A27T
# 13C28G
# 12A29T
# 11T30A
# 10T31A
# 9C32G
# 8A33T
# 7G34C
# 6C35G
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq032-2 - hexABC Sequence 032 - replica 2
#   Watson strand: GCAGGCGACTTACATGCAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq032-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17C24G
# 16G25C
# 15T26A
# 14A27T
# 13C28G
# 12A29T
# 11T30A
# 10T31A
# 9C32G
# 8A33T
# 7G34C
# 6C35G
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq033-1 - hexABC Sequence 033 - replica 1
#   Watson strand: GCAGGCTGCTGTTGTGGCGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq033-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13T28A
# 12T29A
# 11G30C
# 10T31A
# 9C32G
# 8G33C
# 7T34A
# 6C35G
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq033-2 - hexABC Sequence 033 - replica 2
#   Watson strand: GCAGGCTGCTGTTGTGGCGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq033-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13T28A
# 12T29A
# 11G30C
# 10T31A
# 9C32G
# 8G33C
# 7T34A
# 6C35G
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq034-1 - hexABC Sequence 034 - replica 1
#   Watson strand: GCAGGGCATATCGGGTAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq034-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16T25A
# 15G26C
# 14G27C
# 13G28C
# 12C29G
# 11T30A
# 10A31T
# 9T32A
# 8A33T
# 7C34G
# 6G35C
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq034-2 - hexABC Sequence 034 - replica 2
#   Watson strand: GCAGGGCATATCGGGTAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq034-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16T25A
# 15G26C
# 14G27C
# 13G28C
# 12C29G
# 11T30A
# 10A31T
# 9T32A
# 8A33T
# 7C34G
# 6G35C
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq035-1 - hexABC Sequence 035 - replica 1
#   Watson strand: GCAGGTACAGTCAGTGGCGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq035-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13A28T
# 12C29G
# 11T30A
# 10G31C
# 9A32T
# 8C33G
# 7A34T
# 6T35A
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq035-2 - hexABC Sequence 035 - replica 2
#   Watson strand: GCAGGTACAGTCAGTGGCGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq035-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17G24C
# 16G25C
# 15T26A
# 14G27C
# 13A28T
# 12C29G
# 11T30A
# 10G31C
# 9A32T
# 8C33G
# 7A34T
# 6T35A
# 5G36C
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq036-1 - hexABC Sequence 036 - replica 1
#   Watson strand: GCAGTAGACGCCAATGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq036-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14A27T
# 13A28T
# 12C29G
# 11C30G
# 10G31C
# 9C32G
# 8A33T
# 7G34C
# 6A35T
# 5T36A
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14A27T
# 13A28T
# 12C29G
# 11C30G
# 10G31C
# 9C32G
# 8A33T
# 7G34C
# 6A35T
# 5T36A
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq036-2 - hexABC Sequence 036 - replica 2
#   Watson strand: GCAGTAGACGCCAATGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq036-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14A27T
# 13A28T
# 12C29G
# 11C30G
# 10G31C
# 9C32G
# 8A33T
# 7G34C
# 6A35T
# 5T36A
# 4G37C
# 3A38T
# 2C39G
# 1G40C
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15T26A
# 14A27T
# 13A28T
# 12C29G
# 11C30G
# 10G31C
# 9C32G
# 8A33T
# 7G34C
# 6A35T
# 5T36A
# 4G37C
# 3A38T
# 2C39G
# 1G40C
# seq037-1 - hexABC Sequence 037 - replica 1
#   Watson strand: GCATAACGTACTGTGCTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq037-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16C25G
# 15G26C
# 14T27A
# 13G28C
# 12T29A
# 11C30G
# 10A31T
# 9T32A
# 8G33C
# 7C34G
# 6A35T
# 5A36T
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq037-2 - hexABC Sequence 037 - replica 2
#   Watson strand: GCATAACGTACTGTGCTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq037-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16C25G
# 15G26C
# 14T27A
# 13G28C
# 12T29A
# 11C30G
# 10A31T
# 9T32A
# 8G33C
# 7C34G
# 6A35T
# 5A36T
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq038-1 - hexABC Sequence 038 - replica 1
#   Watson strand: GCATACCATAGACACAAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq038-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16A25T
# 15C26G
# 14A27T
# 13C28G
# 12A29T
# 11G30C
# 10A31T
# 9T32A
# 8A33T
# 7C34G
# 6C35G
# 5A36T
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq038-2 - hexABC Sequence 038 - replica 2
#   Watson strand: GCATACCATAGACACAAAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq038-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17A24T
# 16A25T
# 15C26G
# 14A27T
# 13C28G
# 12A29T
# 11G30C
# 10A31T
# 9T32A
# 8A33T
# 7C34G
# 6C35G
# 5A36T
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq039-1 - hexABC Sequence 039 - replica 1
#   Watson strand: GCATACGGTCGATGCGGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq039-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16G25C
# 15C26G
# 14G27C
# 13T28A
# 12A29T
# 11G30C
# 10C31G
# 9T32A
# 8G33C
# 7G34C
# 6C35G
# 5A36T
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq039-2 - hexABC Sequence 039 - replica 2
#   Watson strand: GCATACGGTCGATGCGGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq039-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16G25C
# 15C26G
# 14G27C
# 13T28A
# 12A29T
# 11G30C
# 10C31G
# 9T32A
# 8G33C
# 7G34C
# 6C35G
# 5A36T
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq040-1 - hexABC Sequence 040 - replica 1
#   Watson strand: GCATCAGAGCCGTGGCTAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq040-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17T24A
# 16C25G
# 15G26C
# 14G27C
# 13T28A
# 12G29C
# 11C30G
# 10C31G
# 9G32C
# 8A33T
# 7G34C
# 6A35T
# 5C36G
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq040-2 - hexABC Sequence 040 - replica 2
#   Watson strand: GCATCAGAGCCGTGGCTAGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq040-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18A23T
# 17T24A
# 16C25G
# 15G26C
# 14G27C
# 13T28A
# 12G29C
# 11C30G
# 10C31G
# 9G32C
# 8A33T
# 7G34C
# 6A35T
# 5C36G
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq041-1 - hexABC Sequence 041 - replica 1
#   Watson strand: GCATGTACGCTGGAGCACGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq041-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17A24T
# 16C25G
# 15G26C
# 14A27T
# 13G28C
# 12G29C
# 11T30A
# 10C31G
# 9G32C
# 8C33G
# 7A34T
# 6T35A
# 5G36C
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq041-2 - hexABC Sequence 041 - replica 2
#   Watson strand: GCATGTACGCTGGAGCACGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq041-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17A24T
# 16C25G
# 15G26C
# 14A27T
# 13G28C
# 12G29C
# 11T30A
# 10C31G
# 9G32C
# 8C33G
# 7A34T
# 6T35A
# 5G36C
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq042-1 - hexABC Sequence 042 - replica 1
#   Watson strand: GCATGTTGACAAACAGGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq042-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16G25C
# 15A26T
# 14C27G
# 13A28T
# 12A29T
# 11A30T
# 10C31G
# 9A32T
# 8G33C
# 7T34A
# 6T35A
# 5G36C
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq042-2 - hexABC Sequence 042 - replica 2
#   Watson strand: GCATGTTGACAAACAGGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq042-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16G25C
# 15A26T
# 14C27G
# 13A28T
# 12A29T
# 11A30T
# 10C31G
# 9A32T
# 8G33C
# 7T34A
# 6T35A
# 5G36C
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq043-1 - hexABC Sequence 043 - replica 1
#   Watson strand: GCATTACCAAGGGCCAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq043-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15C26G
# 14C27G
# 13G28C
# 12G29C
# 11G30C
# 10A31T
# 9A32T
# 8C33G
# 7C34G
# 6A35T
# 5T36A
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq043-2 - hexABC Sequence 043 - replica 2
#   Watson strand: GCATTACCAAGGGCCAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq043-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15C26G
# 14C27G
# 13G28C
# 12G29C
# 11G30C
# 10A31T
# 9A32T
# 8C33G
# 7C34G
# 6A35T
# 5T36A
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq044-1 - hexABC Sequence 044 - replica 1
#   Watson strand: GCATTTAGGCGGTGTAACGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq044-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17A24T
# 16A25T
# 15T26A
# 14G27C
# 13T28A
# 12G29C
# 11G30C
# 10C31G
# 9G32C
# 8G33C
# 7A34T
# 6T35A
# 5T36A
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq044-2 - hexABC Sequence 044 - replica 2
#   Watson strand: GCATTTAGGCGGTGTAACGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq044-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GCA' at position 2
# Code: 4C
# 20C21G
# 19G22C
# 18C23G
# 17A24T
# 16A25T
# 15T26A
# 14G27C
# 13T28A
# 12G29C
# 11G30C
# 10C31G
# 9G32C
# 8G33C
# 7A34T
# 6T35A
# 5T36A
# 4T37A
# 3A38T
# 2C39G
# 1G40C
# seq050-1 - hexABC Sequence 050 - replica 1
#   Watson strand: GCCAGGAGCGAATTTTATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq050-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16T25A
# 15T26A
# 14T27A
# 13T28A
# 12A29T
# 11A30T
# 10G31C
# 9C32G
# 8G33C
# 7A34T
# 6G35C
# 5G36C
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq050-2 - hexABC Sequence 050 - replica 2
#   Watson strand: GCCAGGAGCGAATTTTATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq050-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16T25A
# 15T26A
# 14T27A
# 13T28A
# 12A29T
# 11A30T
# 10G31C
# 9C32G
# 8G33C
# 7A34T
# 6G35C
# 5G36C
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq051-1 - hexABC Sequence 051 - replica 1
#   Watson strand: GCCAGGGCGTGTAGGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq051-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14G27C
# 13A28T
# 12T29A
# 11G30C
# 10T31A
# 9G32C
# 8C33G
# 7G34C
# 6G35C
# 5G36C
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq051-2 - hexABC Sequence 051 - replica 2
#   Watson strand: GCCAGGGCGTGTAGGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq051-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14G27C
# 13A28T
# 12T29A
# 11G30C
# 10T31A
# 9G32C
# 8C33G
# 7G34C
# 6G35C
# 5G36C
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq052-1 - hexABC Sequence 052 - replica 1
#   Watson strand: GCCATAAAGGGGAGGCGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq052-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15G26C
# 14G27C
# 13A28T
# 12G29C
# 11G30C
# 10G31C
# 9G32C
# 8A33T
# 7A34T
# 6A35T
# 5T36A
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq052-2 - hexABC Sequence 052 - replica 2
#   Watson strand: GCCATAAAGGGGAGGCGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq052-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15G26C
# 14G27C
# 13A28T
# 12G29C
# 11G30C
# 10G31C
# 9G32C
# 8A33T
# 7A34T
# 6A35T
# 5T36A
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq053-1 - hexABC Sequence 053 - replica 1
#   Watson strand: GCCATATGATGGAAGCTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq053-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16C25G
# 15G26C
# 14A27T
# 13A28T
# 12G29C
# 11G30C
# 10T31A
# 9A32T
# 8G33C
# 7T34A
# 6A35T
# 5T36A
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq053-2 - hexABC Sequence 053 - replica 2
#   Watson strand: GCCATATGATGGAAGCTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq053-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16C25G
# 15G26C
# 14A27T
# 13A28T
# 12G29C
# 11G30C
# 10T31A
# 9A32T
# 8G33C
# 7T34A
# 6A35T
# 5T36A
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq055-1 - hexABC Sequence 055 - replica 1
#   Watson strand: GCCATGAATGTAGAACGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq055-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15A26T
# 14A27T
# 13G28C
# 12A29T
# 11T30A
# 10G31C
# 9T32A
# 8A33T
# 7A34T
# 6G35C
# 5T36A
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq055-2 - hexABC Sequence 055 - replica 2
#   Watson strand: GCCATGAATGTAGAACGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq055-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15A26T
# 14A27T
# 13G28C
# 12A29T
# 11T30A
# 10G31C
# 9T32A
# 8A33T
# 7A34T
# 6G35C
# 5T36A
# 4A37T
# 3C38G
# 2C39G
# 1G40C
# seq060-1 - hexABC Sequence 060 - replica 1
#   Watson strand: GCCCCACGCGCAAGGAGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq060-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16A25T
# 15G26C
# 14G27C
# 13A28T
# 12A29T
# 11C30G
# 10G31C
# 9C32G
# 8G33C
# 7C34G
# 6A35T
# 5C36G
# 4C37G
# 3C38G
# 2C39G
# 1G40C
# seq060-2 - hexABC Sequence 060 - replica 2
#   Watson strand: GCCCCACGCGCAAGGAGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq060-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16A25T
# 15G26C
# 14G27C
# 13A28T
# 12A29T
# 11C30G
# 10G31C
# 9C32G
# 8G33C
# 7C34G
# 6A35T
# 5C36G
# 4C37G
# 3C38G
# 2C39G
# 1G40C
# seq061-1 - hexABC Sequence 061 - replica 1
#   Watson strand: GCCCCGGGAGTAAACGTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq061-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16G25C
# 15C26G
# 14A27T
# 13A28T
# 12A29T
# 11T30A
# 10G31C
# 9A32T
# 8G33C
# 7G34C
# 6G35C
# 5C36G
# 4C37G
# 3C38G
# 2C39G
# 1G40C
# seq061-2 - hexABC Sequence 061 - replica 2
#   Watson strand: GCCCCGGGAGTAAACGTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq061-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16G25C
# 15C26G
# 14A27T
# 13A28T
# 12A29T
# 11T30A
# 10G31C
# 9A32T
# 8G33C
# 7G34C
# 6G35C
# 5C36G
# 4C37G
# 3C38G
# 2C39G
# 1G40C
# seq065-1 - hexABC Sequence 065 - replica 1
#   Watson strand: GCCGAACAGTGACACGTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq065-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16G25C
# 15C26G
# 14A27T
# 13C28G
# 12A29T
# 11G30C
# 10T31A
# 9G32C
# 8A33T
# 7C34G
# 6A35T
# 5A36T
# 4G37C
# 3C38G
# 2C39G
# 1G40C
# seq065-2 - hexABC Sequence 065 - replica 2
#   Watson strand: GCCGAACAGTGACACGTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq065-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16G25C
# 15C26G
# 14A27T
# 13C28G
# 12A29T
# 11G30C
# 10T31A
# 9G32C
# 8A33T
# 7C34G
# 6A35T
# 5A36T
# 4G37C
# 3C38G
# 2C39G
# 1G40C
# seq067-1 - hexABC Sequence 067 - replica 1
#   Watson strand: GCCGCGAGGGAAACGCTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq067-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16C25G
# 15G26C
# 14C27G
# 13A28T
# 12A29T
# 11A30T
# 10G31C
# 9G32C
# 8G33C
# 7A34T
# 6G35C
# 5C36G
# 4G37C
# 3C38G
# 2C39G
# 1G40C
# seq067-2 - hexABC Sequence 067 - replica 2
#   Watson strand: GCCGCGAGGGAAACGCTTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq067-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16C25G
# 15G26C
# 14C27G
# 13A28T
# 12A29T
# 11A30T
# 10G31C
# 9G32C
# 8G33C
# 7A34T
# 6G35C
# 5C36G
# 4G37C
# 3C38G
# 2C39G
# 1G40C
# seq073-1 - hexABC Sequence 073 - replica 1
#   Watson strand: GCCGTATTGAGGATTCGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq073-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15T26A
# 14T27A
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9G32C
# 8T33A
# 7T34A
# 6A35T
# 5T36A
# 4G37C
# 3C38G
# 2C39G
# 1G40C
# seq073-2 - hexABC Sequence 073 - replica 2
#   Watson strand: GCCGTATTGAGGATTCGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq073-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15T26A
# 14T27A
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9G32C
# 8T33A
# 7T34A
# 6A35T
# 5T36A
# 4G37C
# 3C38G
# 2C39G
# 1G40C
# seq080-1 - hexABC Sequence 080 - replica 1
#   Watson strand: GCGAAACCCTGCAAGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq080-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14A27T
# 13A28T
# 12C29G
# 11G30C
# 10T31A
# 9C32G
# 8C33G
# 7C34G
# 6A35T
# 5A36T
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq080-2 - hexABC Sequence 080 - replica 2
#   Watson strand: GCGAAACCCTGCAAGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq080-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14A27T
# 13A28T
# 12C29G
# 11G30C
# 10T31A
# 9C32G
# 8C33G
# 7C34G
# 6A35T
# 5A36T
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq082-1 - hexABC Sequence 082 - replica 1
#   Watson strand: GCGAACATAGGGAGCTATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq082-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16T25A
# 15C26G
# 14G27C
# 13A28T
# 12G29C
# 11G30C
# 10G31C
# 9A32T
# 8T33A
# 7A34T
# 6C35G
# 5A36T
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq082-2 - hexABC Sequence 082 - replica 2
#   Watson strand: GCGAACATAGGGAGCTATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq082-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16T25A
# 15C26G
# 14G27C
# 13A28T
# 12G29C
# 11G30C
# 10G31C
# 9A32T
# 8T33A
# 7A34T
# 6C35G
# 5A36T
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq083-1 - hexABC Sequence 083 - replica 1
#   Watson strand: GCGAACGACCTTGTGAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq083-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15G26C
# 14T27A
# 13G28C
# 12T29A
# 11T30A
# 10C31G
# 9C32G
# 8A33T
# 7G34C
# 6C35G
# 5A36T
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq083-2 - hexABC Sequence 083 - replica 2
#   Watson strand: GCGAACGACCTTGTGAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq083-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15G26C
# 14T27A
# 13G28C
# 12T29A
# 11T30A
# 10C31G
# 9C32G
# 8A33T
# 7G34C
# 6C35G
# 5A36T
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq089-1 - hexABC Sequence 089 - replica 1
#   Watson strand: GCGAGGAGGAAGGGTAGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq089-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16A25T
# 15T26A
# 14G27C
# 13G28C
# 12G29C
# 11A30T
# 10A31T
# 9G32C
# 8G33C
# 7A34T
# 6G35C
# 5G36C
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq089-2 - hexABC Sequence 089 - replica 2
#   Watson strand: GCGAGGAGGAAGGGTAGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq089-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16A25T
# 15T26A
# 14G27C
# 13G28C
# 12G29C
# 11A30T
# 10A31T
# 9G32C
# 8G33C
# 7A34T
# 6G35C
# 5G36C
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq091-1 - hexABC Sequence 091 - replica 1
#   Watson strand: GCGATAGTATCCTGAAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq091-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15A26T
# 14G27C
# 13T28A
# 12C29G
# 11C30G
# 10T31A
# 9A32T
# 8T33A
# 7G34C
# 6A35T
# 5T36A
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq091-2 - hexABC Sequence 091 - replica 2
#   Watson strand: GCGATAGTATCCTGAAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq091-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15A26T
# 14G27C
# 13T28A
# 12C29G
# 11C30G
# 10T31A
# 9A32T
# 8T33A
# 7G34C
# 6A35T
# 5T36A
# 4A37T
# 3G38C
# 2C39G
# 1G40C
# seq093-1 - hexABC Sequence 093 - replica 1
#   Watson strand: GCGCAATTGAAAATGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq093-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14T27A
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9G32C
# 8T33A
# 7T34A
# 6A35T
# 5A36T
# 4C37G
# 3G38C
# 2C39G
# 1G40C
# seq093-2 - hexABC Sequence 093 - replica 2
#   Watson strand: GCGCAATTGAAAATGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq093-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14T27A
# 13A28T
# 12A29T
# 11A30T
# 10A31T
# 9G32C
# 8T33A
# 7T34A
# 6A35T
# 5A36T
# 4C37G
# 3G38C
# 2C39G
# 1G40C
# seq096-1 - hexABC Sequence 096 - replica 1
#   Watson strand: GCGCCGGCTAGGACCGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq096-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15C26G
# 14C27G
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9T32A
# 8C33G
# 7G34C
# 6G35C
# 5C36G
# 4C37G
# 3G38C
# 2C39G
# 1G40C
# seq096-2 - hexABC Sequence 096 - replica 2
#   Watson strand: GCGCCGGCTAGGACCGGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq096-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16G25C
# 15C26G
# 14C27G
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9T32A
# 8C33G
# 7G34C
# 6G35C
# 5C36G
# 4C37G
# 3G38C
# 2C39G
# 1G40C
# seq097-1 - hexABC Sequence 097 - replica 1
#   Watson strand: GCGCGCCGGATAATAATTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq097-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16A25T
# 15A26T
# 14T27A
# 13A28T
# 12A29T
# 11T30A
# 10A31T
# 9G32C
# 8G33C
# 7C34G
# 6C35G
# 5G36C
# 4C37G
# 3G38C
# 2C39G
# 1G40C
# seq097-2 - hexABC Sequence 097 - replica 2
#   Watson strand: GCGCGCCGGATAATAATTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq097-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17T24A
# 16A25T
# 15A26T
# 14T27A
# 13A28T
# 12A29T
# 11T30A
# 10A31T
# 9G32C
# 8G33C
# 7C34G
# 6C35G
# 5G36C
# 4C37G
# 3G38C
# 2C39G
# 1G40C
# seq108-1 - hexABC Sequence 108 - replica 1
#   Watson strand: GCGGACGGAAGTATGTATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq108-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16T25A
# 15G26C
# 14T27A
# 13A28T
# 12T29A
# 11G30C
# 10A31T
# 9A32T
# 8G33C
# 7G34C
# 6C35G
# 5A36T
# 4G37C
# 3G38C
# 2C39G
# 1G40C
# seq108-2 - hexABC Sequence 108 - replica 2
#   Watson strand: GCGGACGGAAGTATGTATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq108-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16T25A
# 15G26C
# 14T27A
# 13A28T
# 12T29A
# 11G30C
# 10A31T
# 9A32T
# 8G33C
# 7G34C
# 6C35G
# 5A36T
# 4G37C
# 3G38C
# 2C39G
# 1G40C
# seq109-1 - hexABC Sequence 109 - replica 1
#   Watson strand: GCGGAGAATTGCGTGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq109-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14T27A
# 13G28C
# 12C29G
# 11G30C
# 10T31A
# 9T32A
# 8A33T
# 7A34T
# 6G35C
# 5A36T
# 4G37C
# 3G38C
# 2C39G
# 1G40C
# seq109-2 - hexABC Sequence 109 - replica 2
#   Watson strand: GCGGAGAATTGCGTGCATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq109-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16C25G
# 15G26C
# 14T27A
# 13G28C
# 12C29G
# 11G30C
# 10T31A
# 9T32A
# 8A33T
# 7A34T
# 6G35C
# 5A36T
# 4G37C
# 3G38C
# 2C39G
# 1G40C
# seq125-1 - hexABC Sequence 125 - replica 1
#   Watson strand: GCGGTAAGCGGGCAATGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq125-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16T25A
# 15A26T
# 14A27T
# 13C28G
# 12G29C
# 11G30C
# 10G31C
# 9C32G
# 8G33C
# 7A34T
# 6A35T
# 5T36A
# 4G37C
# 3G38C
# 2C39G
# 1G40C
# seq125-2 - hexABC Sequence 125 - replica 2
#   Watson strand: GCGGTAAGCGGGCAATGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq125-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16T25A
# 15A26T
# 14A27T
# 13C28G
# 12G29C
# 11G30C
# 10G31C
# 9C32G
# 8G33C
# 7A34T
# 6A35T
# 5T36A
# 4G37C
# 3G38C
# 2C39G
# 1G40C
# seq130-1 - hexABC Sequence 130 - replica 1
#   Watson strand: GCGTAACTCTTACGGGATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq130-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16G25C
# 15G26C
# 14G27C
# 13C28G
# 12A29T
# 11T30A
# 10T31A
# 9C32G
# 8T33A
# 7C34G
# 6A35T
# 5A36T
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq130-2 - hexABC Sequence 130 - replica 2
#   Watson strand: GCGTAACTCTTACGGGATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq130-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16G25C
# 15G26C
# 14G27C
# 13C28G
# 12A29T
# 11T30A
# 10T31A
# 9C32G
# 8T33A
# 7C34G
# 6A35T
# 5A36T
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq139-1 - hexABC Sequence 139 - replica 1
#   Watson strand: GCGTGACGGGTCGCTTGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq139-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16T25A
# 15T26A
# 14C27G
# 13G28C
# 12C29G
# 11T30A
# 10G31C
# 9G32C
# 8G33C
# 7C34G
# 6A35T
# 5G36C
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq139-2 - hexABC Sequence 139 - replica 2
#   Watson strand: GCGTGACGGGTCGCTTGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq139-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16T25A
# 15T26A
# 14C27G
# 13G28C
# 12C29G
# 11T30A
# 10G31C
# 9G32C
# 8G33C
# 7C34G
# 6A35T
# 5G36C
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq163-1 - hexABC Sequence 163 - replica 1
#   Watson strand: GCTCGACGACGTATGCGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq163-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15G26C
# 14T27A
# 13A28T
# 12T29A
# 11G30C
# 10C31G
# 9A32T
# 8G33C
# 7C34G
# 6A35T
# 5G36C
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq163-2 - hexABC Sequence 163 - replica 2
#   Watson strand: GCTCGACGACGTATGCGTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq163-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17G24C
# 16C25G
# 15G26C
# 14T27A
# 13A28T
# 12T29A
# 11G30C
# 10C31G
# 9A32T
# 8G33C
# 7C34G
# 6A35T
# 5G36C
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq165-1 - hexABC Sequence 165 - replica 1
#   Watson strand: GCTCGCGAAGAAAGTACTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq165-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17C24G
# 16A25T
# 15T26A
# 14G27C
# 13A28T
# 12A29T
# 11A30T
# 10G31C
# 9A32T
# 8A33T
# 7G34C
# 6C35G
# 5G36C
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq165-2 - hexABC Sequence 165 - replica 2
#   Watson strand: GCTCGCGAAGAAAGTACTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq165-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17C24G
# 16A25T
# 15T26A
# 14G27C
# 13A28T
# 12A29T
# 11A30T
# 10G31C
# 9A32T
# 8A33T
# 7G34C
# 6C35G
# 5G36C
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq169-1 - hexABC Sequence 169 - replica 1
#   Watson strand: GCTGAGGCCGGTGAAACTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq169-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17C24G
# 16A25T
# 15A26T
# 14A27T
# 13G28C
# 12T29A
# 11G30C
# 10G31C
# 9C32G
# 8C33G
# 7G34C
# 6G35C
# 5A36T
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq169-2 - hexABC Sequence 169 - replica 2
#   Watson strand: GCTGAGGCCGGTGAAACTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq169-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17C24G
# 16A25T
# 15A26T
# 14A27T
# 13G28C
# 12T29A
# 11G30C
# 10G31C
# 9C32G
# 8C33G
# 7G34C
# 6G35C
# 5A36T
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq174-1 - hexABC Sequence 174 - replica 1
#   Watson strand: GCTGCGCAGAGTATTAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq174-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15T26A
# 14T27A
# 13A28T
# 12T29A
# 11G30C
# 10A31T
# 9G32C
# 8A33T
# 7C34G
# 6G35C
# 5C36G
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq174-2 - hexABC Sequence 174 - replica 2
#   Watson strand: GCTGCGCAGAGTATTAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq174-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15T26A
# 14T27A
# 13A28T
# 12T29A
# 11G30C
# 10A31T
# 9G32C
# 8A33T
# 7C34G
# 6G35C
# 5C36G
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq182-1 - hexABC Sequence 182 - replica 1
#   Watson strand: GCTGTGTGTTATTGGAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq182-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15G26C
# 14G27C
# 13T28A
# 12T29A
# 11A30T
# 10T31A
# 9T32A
# 8G33C
# 7T34A
# 6G35C
# 5T36A
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq182-2 - hexABC Sequence 182 - replica 2
#   Watson strand: GCTGTGTGTTATTGGAATGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq182-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18T23A
# 17A24T
# 16A25T
# 15G26C
# 14G27C
# 13T28A
# 12T29A
# 11A30T
# 10T31A
# 9T32A
# 8G33C
# 7T34A
# 6G35C
# 5T36A
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq187-1 - hexABC Sequence 187 - replica 1
#   Watson strand: GCTTGGGGACTCTAGGCTGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq187-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'TGC' at position 19
# Code: 21G
# ...
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq135-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16A25T
# 15T26A
# 14T27A
# 13G28C
# 12G29C
# 11T30A
# 10T31A
# 9G32C
# 8G33C
# 7T34A
# 6C35G
# 5C36G
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq136-1 - hexABC Sequence 136 - replica 1
#   Watson strand: GCGTCGACATAATCGATGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq136-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16A25T
# 15G26C
# 14C27G
# 13T28A
# 12A29T
# 11A30T
# 10T31A
# 9A32T
# 8C33G
# 7A34T
# 6G35C
# 5C36G
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq136-2 - hexABC Sequence 136 - replica 2
#   Watson strand: GCGTCGACATAATCGATGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq136-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16A25T
# 15G26C
# 14C27G
# 13T28A
# 12A29T
# 11A30T
# 10T31A
# 9A32T
# 8C33G
# 7A34T
# 6G35C
# 5C36G
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq137-1 - hexABC Sequence 137 - replica 1
#   Watson strand: GCGTCGGTCAATGAAGTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq137-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16G25C
# 15A26T
# 14A27T
# 13G28C
# 12T29A
# 11A30T
# 10A31T
# 9C32G
# 8T33A
# 7G34C
# 6G35C
# 5C36G
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq137-2 - hexABC Sequence 137 - replica 2
#   Watson strand: GCGTCGGTCAATGAAGTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq137-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16G25C
# 15A26T
# 14A27T
# 13G28C
# 12T29A
# 11A30T
# 10A31T
# 9C32G
# 8T33A
# 7G34C
# 6G35C
# 5C36G
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq141-1 - hexABC Sequence 141 - replica 1
#   Watson strand: GCGTGGGCCGCCATCGTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq141-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16G25C
# 15C26G
# 14T27A
# 13A28T
# 12C29G
# 11C30G
# 10G31C
# 9C32G
# 8C33G
# 7G34C
# 6G35C
# 5G36C
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq141-2 - hexABC Sequence 141 - replica 2
#   Watson strand: GCGTGGGCCGCCATCGTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq141-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16G25C
# 15C26G
# 14T27A
# 13A28T
# 12C29G
# 11C30G
# 10G31C
# 9C32G
# 8C33G
# 7G34C
# 6G35C
# 5G36C
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq142-1 - hexABC Sequence 142 - replica 1
#   Watson strand: GCGTGTCCTCTGGAAAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq142-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15A26T
# 14A27T
# 13G28C
# 12G29C
# 11T30A
# 10C31G
# 9T32A
# 8C33G
# 7C34G
# 6T35A
# 5G36C
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq142-2 - hexABC Sequence 142 - replica 2
#   Watson strand: GCGTGTCCTCTGGAAAGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq142-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16A25T
# 15A26T
# 14A27T
# 13G28C
# 12G29C
# 11T30A
# 10C31G
# 9T32A
# 8C33G
# 7C34G
# 6T35A
# 5G36C
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq145-1 - hexABC Sequence 145 - replica 1
#   Watson strand: GCGTTACTTATGAGATCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq145-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16T25A
# 15A26T
# 14G27C
# 13A28T
# 12G29C
# 11T30A
# 10A31T
# 9T32A
# 8T33A
# 7C34G
# 6A35T
# 5T36A
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq145-2 - hexABC Sequence 145 - replica 2
#   Watson strand: GCGTTACTTATGAGATCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq145-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16T25A
# 15A26T
# 14G27C
# 13A28T
# 12G29C
# 11T30A
# 10A31T
# 9T32A
# 8T33A
# 7C34G
# 6A35T
# 5T36A
# 4T37A
# 3G38C
# 2C39G
# 1G40C
# seq152-1 - hexABC Sequence 152 - replica 1
#   Watson strand: GCTAATTAAGTTCCGGAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq152-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16G25C
# 15G26C
# 14C27G
# 13C28G
# 12T29A
# 11T30A
# 10G31C
# 9A32T
# 8A33T
# 7T34A
# 6T35A
# 5A36T
# 4A37T
# 3T38A
# 2C39G
# 1G40C
# seq152-2 - hexABC Sequence 152 - replica 2
#   Watson strand: GCTAATTAAGTTCCGGAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq152-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16G25C
# 15G26C
# 14C27G
# 13C28G
# 12T29A
# 11T30A
# 10G31C
# 9A32T
# 8A33T
# 7T34A
# 6T35A
# 5A36T
# 4A37T
# 3T38A
# 2C39G
# 1G40C
# seq157-1 - hexABC Sequence 157 - replica 1
#   Watson strand: GCTAGCACTGGCGCGCGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq157-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16C25G
# 15G26C
# 14C27G
# 13G28C
# 12C29G
# 11G30C
# 10G31C
# 9T32A
# 8C33G
# 7A34T
# 6C35G
# 5G36C
# 4A37T
# 3T38A
# 2C39G
# 1G40C
# seq157-2 - hexABC Sequence 157 - replica 2
#   Watson strand: GCTAGCACTGGCGCGCGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq157-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16C25G
# 15G26C
# 14C27G
# 13G28C
# 12C29G
# 11G30C
# 10G31C
# 9T32A
# 8C33G
# 7A34T
# 6C35G
# 5G36C
# 4A37T
# 3T38A
# 2C39G
# 1G40C
# seq161-1 - hexABC Sequence 161 - replica 1
#   Watson strand: GCTCAGCGAGTTGCCTGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq161-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16T25A
# 15C26G
# 14C27G
# 13G28C
# 12T29A
# 11T30A
# 10G31C
# 9A32T
# 8G33C
# 7C34G
# 6G35C
# 5A36T
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq161-2 - hexABC Sequence 161 - replica 2
#   Watson strand: GCTCAGCGAGTTGCCTGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq161-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16T25A
# 15C26G
# 14C27G
# 13G28C
# 12T29A
# 11T30A
# 10G31C
# 9A32T
# 8G33C
# 7C34G
# 6G35C
# 5A36T
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq162-1 - hexABC Sequence 162 - replica 1
#   Watson strand: GCTCCTAGGTGGCGATCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq162-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16T25A
# 15A26T
# 14G27C
# 13C28G
# 12G29C
# 11G30C
# 10T31A
# 9G32C
# 8G33C
# 7A34T
# 6T35A
# 5C36G
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq162-2 - hexABC Sequence 162 - replica 2
#   Watson strand: GCTCCTAGGTGGCGATCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq162-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16T25A
# 15A26T
# 14G27C
# 13C28G
# 12G29C
# 11G30C
# 10T31A
# 9G32C
# 8G33C
# 7A34T
# 6T35A
# 5C36G
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq164-1 - hexABC Sequence 164 - replica 1
#   Watson strand: GCTCGCAGGTGTCGGACGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq164-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16A25T
# 15G26C
# 14G27C
# 13C28G
# 12T29A
# 11G30C
# 10T31A
# 9G32C
# 8G33C
# 7A34T
# 6C35G
# 5G36C
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq164-2 - hexABC Sequence 164 - replica 2
#   Watson strand: GCTCGCAGGTGTCGGACGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq164-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16A25T
# 15G26C
# 14G27C
# 13C28G
# 12T29A
# 11G30C
# 10T31A
# 9G32C
# 8G33C
# 7A34T
# 6C35G
# 5G36C
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq167-1 - hexABC Sequence 167 - replica 1
#   Watson strand: GCTCGCGTCGCGGTAACGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq167-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16A25T
# 15A26T
# 14T27A
# 13G28C
# 12G29C
# 11C30G
# 10G31C
# 9C32G
# 8T33A
# 7G34C
# 6C35G
# 5G36C
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq167-2 - hexABC Sequence 167 - replica 2
#   Watson strand: GCTCGCGTCGCGGTAACGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq167-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16A25T
# 15A26T
# 14T27A
# 13G28C
# 12G29C
# 11C30G
# 10G31C
# 9C32G
# 8T33A
# 7G34C
# 6C35G
# 5G36C
# 4C37G
# 3T38A
# 2C39G
# 1G40C
# seq173-1 - hexABC Sequence 173 - replica 1
#   Watson strand: GCTGCGACAATGCGAACGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq173-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16A25T
# 15A26T
# 14G27C
# 13C28G
# 12G29C
# 11T30A
# 10A31T
# 9A32T
# 8C33G
# 7A34T
# 6G35C
# 5C36G
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq173-2 - hexABC Sequence 173 - replica 2
#   Watson strand: GCTGCGACAATGCGAACGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq173-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16A25T
# 15A26T
# 14G27C
# 13C28G
# 12G29C
# 11T30A
# 10A31T
# 9A32T
# 8C33G
# 7A34T
# 6G35C
# 5C36G
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq175-1 - hexABC Sequence 175 - replica 1
#   Watson strand: GCTGCGTATAGGAACCTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq175-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16C25G
# 15C26G
# 14A27T
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9T32A
# 8A33T
# 7T34A
# 6G35C
# 5C36G
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq175-2 - hexABC Sequence 175 - replica 2
#   Watson strand: GCTGCGTATAGGAACCTGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq175-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17T24A
# 16C25G
# 15C26G
# 14A27T
# 13A28T
# 12G29C
# 11G30C
# 10A31T
# 9T32A
# 8A33T
# 7T34A
# 6G35C
# 5C36G
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq177-1 - hexABC Sequence 177 - replica 1
#   Watson strand: GCTGGCATTCGGTTTGGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq177-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16G25C
# 15T26A
# 14T27A
# 13T28A
# 12G29C
# 11G30C
# 10C31G
# 9T32A
# 8T33A
# 7A34T
# 6C35G
# 5G36C
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq177-2 - hexABC Sequence 177 - replica 2
#   Watson strand: GCTGGCATTCGGTTTGGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq177-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16G25C
# 15T26A
# 14T27A
# 13T28A
# 12G29C
# 11G30C
# 10C31G
# 9T32A
# 8T33A
# 7A34T
# 6C35G
# 5G36C
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq178-1 - hexABC Sequence 178 - replica 1
#   Watson strand: GCTGGGTGATCCACAGAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq178-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16G25C
# 15A26T
# 14C27G
# 13A28T
# 12C29G
# 11C30G
# 10T31A
# 9A32T
# 8G33C
# 7T34A
# 6G35C
# 5G36C
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq178-2 - hexABC Sequence 178 - replica 2
#   Watson strand: GCTGGGTGATCCACAGAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq178-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16G25C
# 15A26T
# 14C27G
# 13A28T
# 12C29G
# 11C30G
# 10T31A
# 9A32T
# 8G33C
# 7T34A
# 6G35C
# 5G36C
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq180-1 - hexABC Sequence 180 - replica 1
#   Watson strand: GCTGTATGGATTACTGGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq180-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16G25C
# 15T26A
# 14C27G
# 13A28T
# 12T29A
# 11T30A
# 10A31T
# 9G32C
# 8G33C
# 7T34A
# 6A35T
# 5T36A
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq180-2 - hexABC Sequence 180 - replica 2
#   Watson strand: GCTGTATGGATTACTGGGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq180-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17G24C
# 16G25C
# 15T26A
# 14C27G
# 13A28T
# 12T29A
# 11T30A
# 10A31T
# 9G32C
# 8G33C
# 7T34A
# 6A35T
# 5T36A
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq181-1 - hexABC Sequence 181 - replica 1
#   Watson strand: GCTGTCTGGTCCGTAGAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq181-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16G25C
# 15A26T
# 14T27A
# 13G28C
# 12C29G
# 11C30G
# 10T31A
# 9G32C
# 8G33C
# 7T34A
# 6C35G
# 5T36A
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq181-2 - hexABC Sequence 181 - replica 2
#   Watson strand: GCTGTCTGGTCCGTAGAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq181-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16G25C
# 15A26T
# 14T27A
# 13G28C
# 12C29G
# 11C30G
# 10T31A
# 9G32C
# 8G33C
# 7T34A
# 6C35G
# 5T36A
# 4G37C
# 3T38A
# 2C39G
# 1G40C
# seq183-1 - hexABC Sequence 183 - replica 1
#   Watson strand: GCTTAAGGTTTAGTGCAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq183-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16C25G
# 15G26C
# 14T27A
# 13G28C
# 12A29T
# 11T30A
# 10T31A
# 9T32A
# 8G33C
# 7G34C
# 6A35T
# 5A36T
# 4T37A
# 3T38A
# 2C39G
# 1G40C
# seq183-2 - hexABC Sequence 183 - replica 2
#   Watson strand: GCTTAAGGTTTAGTGCAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq183-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16C25G
# 15G26C
# 14T27A
# 13G28C
# 12A29T
# 11T30A
# 10T31A
# 9T32A
# 8G33C
# 7G34C
# 6A35T
# 5A36T
# 4T37A
# 3T38A
# 2C39G
# 1G40C
# seq186-1 - hexABC Sequence 186 - replica 1
#   Watson strand: GCTTGCTTAAAGAATCAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq186-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16C25G
# 15T26A
# 14A27T
# 13A28T
# 12G29C
# 11A30T
# 10A31T
# 9A32T
# 8T33A
# 7T34A
# 6C35G
# 5G36C
# 4T37A
# 3T38A
# 2C39G
# 1G40C
# seq186-2 - hexABC Sequence 186 - replica 2
#   Watson strand: GCTTGCTTAAAGAATCAGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq186-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17A24T
# 16C25G
# 15T26A
# 14A27T
# 13A28T
# 12G29C
# 11A30T
# 10A31T
# 9A32T
# 8T33A
# 7T34A
# 6C35G
# 5G36C
# 4T37A
# 3T38A
# 2C39G
# 1G40C
# seq188-1 - hexABC Sequence 188 - replica 1
#   Watson strand: GCTTTATCGAGCTGAGCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq188-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16G25C
# 15A26T
# 14G27C
# 13T28A
# 12C29G
# 11G30C
# 10A31T
# 9G32C
# 8C33G
# 7T34A
# 6A35T
# 5T36A
# 4T37A
# 3T38A
# 2C39G
# 1G40C
# seq188-2 - hexABC Sequence 188 - replica 2
#   Watson strand: GCTTTATCGAGCTGAGCGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq188-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16G25C
# 15A26T
# 14G27C
# 13T28A
# 12C29G
# 11G30C
# 10A31T
# 9G32C
# 8C33G
# 7T34A
# 6A35T
# 5T36A
# 4T37A
# 3T38A
# 2C39G
# 1G40C
# seq190-1 - hexABC Sequence 190 - replica 1
#   Watson strand: GCTTTTAGCGGTTGAACGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq190-1/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16A25T
# 15A26T
# 14G27C
# 13T28A
# 12T29A
# 11G30C
# 10G31C
# 9C32G
# 8G33C
# 7A34T
# 6T35A
# 5T36A
# 4T37A
# 3T38A
# 2C39G
# 1G40C
# seq190-2 - hexABC Sequence 190 - replica 2
#   Watson strand: GCTTTTAGCGGTTGAACGGC
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq190-2/analyses/hbonds?from=1&to=-1
#     ↳ found 'GGC' at position 19
# Code: 21G
# Code -rev-: 21G
# 20C21G
# 19G22C
# 18G23C
# 17C24G
# 16A25T
# 15A26T
# 14G27C
# 13T28A
# 12T29A
# 11G30C
# 10G31C
# 9C32G
# 8G33C
# 7A34T
# 6T35A
# 5T36A
# 4T37A
# 3T38A
# 2C39G
# 1G40C
# FINAL NUMBERS:
# Percentages Trimer 2:
#   0: 0.01%
#   1: 0.08%
#   2: 0.55%
#   3: 99.36%
# Min and Max Lifetimes Trimer 1:
#   0: min = 1, max = 4606
#   1: min = 1, max = 61
#   2: min = 1, max = 9
#   3: min = 1, max = 1814
# Min and Max Lifetimes Trimer 2:
#   0: min = 1, max = 167
#   1: min = 1, max = 58
#   2: min = 1, max = 5
#   3: min = 1, max = 2486

# %% [markdown]
# ### Plotting hydrogen bond values
#
# **Pie Charts** representing HBs statistics for the specific **trimers**. <br>
# Less than 3 HBs (for C,G) or 2 HBs (for A,T) means **unstable/broken base pairs**.

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

color_map = {
    0: '#1f77b4',  # blue
    1: '#ff7f0e',  # orange
    2: '#2ca02c',  # green
    3: '#d62728'   # red
}

labels_1 = [f"{k} HBs" for k in percentages_trimer1]
values_1 = list(percentages_trimer1.values())
colors_1 = [color_map[k] for k in percentages_trimer1]

labels_2 = [f"{k} HBs" for k in percentages_trimer2]
values_2 = list(percentages_trimer2.values())
colors_2 = [color_map[k] for k in percentages_trimer2]

# Create subplot layout for 2 pies
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])

fig.add_trace(go.Pie(
    labels=labels_1,
    values=values_1,
    hole=0.4,
    textinfo='label+percent',
    marker=dict(colors=colors_1),
    pull=[0.05 if v < 5 else 0 for v in values_1],
    name="Study 1"
), row=1, col=1)

fig.add_trace(go.Pie(
    labels=labels_2,
    values=values_2,
    hole=0.4,
    textinfo='label+percent',
    marker=dict(colors=colors_2),
    pull=[0.05 if v < 5 else 0 for v in values_2],
    name="Study 2"
), row=1, col=2)


# Add titles
tit = f"{trimer1}-{trimer2}"
fig.update_layout(
    title={
        'text': tit,
        'x': 0.45,  # Left-align
        'y': 0.98,
        'xanchor': 'left',
        'yanchor': 'top',
        'font': dict(size=22)
    },
    annotations=[
        dict(text=f"{trimer1}", x=0.205, y=0.5, font_size=14, showarrow=False),
        dict(text=f"{trimer2}", x=0.795, y=0.5, font_size=14, showarrow=False)
    ]
)

fig.show()

# %% [markdown]
# ### Plotting hydrogen bond lifetimes
#
# **Histograms** representing HBs lifetimes for the specific **trimers**. <br>

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

states = sorted(aggregated_hbs_lt_trimer1.keys())
n_states = len(states)

# Set up subplots: one row, multiple columns
fig = make_subplots(rows=1, cols=n_states, subplot_titles=[f"{s} HBs" for s in states])

# Add one histogram per state
for i, state in enumerate(states):
    lifetimes = aggregated_hbs_lt_trimer1[state]
    fig.add_trace(
        go.Histogram(
            x=lifetimes,
            nbinsx=min(20, max(lifetimes) - min(lifetimes) + 1),
            marker_color='#1f77b4',
            name=f"{state} HBs",
            showlegend=False
        ),
        row=1,
        col=i+1
    )

# Layout polish
fig.update_layout(
    title_text=f"Lifetime Distributions per State - {trimer1}",
    height=400,
    width=300 * n_states,
    bargap=0.1,
    margin=dict(t=50, r=20, l=20, b=40)
)

# Add axis labels uniformly
for i in range(n_states):
    fig.update_xaxes(title_text="Lifetime (frames)", row=1, col=i+1)
    fig.update_yaxes(title_text="Frequency", row=1, col=1)

fig.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

states = sorted(aggregated_hbs_lt_trimer2.keys())
n_states = len(states)

# Set up subplots: one row, multiple columns
fig = make_subplots(rows=1, cols=n_states, subplot_titles=[f"{s} HBs" for s in states])

# Add one histogram per state
for i, state in enumerate(states):
    lifetimes = aggregated_hbs_lt_trimer2[state]
    fig.add_trace(
        go.Histogram(
            x=lifetimes,
            nbinsx=min(20, max(lifetimes) - min(lifetimes) + 1),
            marker_color='#1f77b4',
            name=f"{state} HBs",
            showlegend=False
        ),
        row=1,
        col=i+1
    )

# Layout polish
fig.update_layout(
     title_text=f"Lifetime Distributions per State - {trimer2}",
    height=400,
    width=300 * n_states,
    bargap=0.1,
    margin=dict(t=50, r=20, l=20, b=40)
)

# Add axis labels uniformly
for i in range(n_states):
    fig.update_xaxes(title_text="Lifetime (frames)", row=1, col=i+1)
    fig.update_yaxes(title_text="Frequency", row=1, col=1)

fig.show()
