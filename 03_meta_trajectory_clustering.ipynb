# %% [markdown]
# ### Meta-trajectories
# ***
#
# **Jupyter Notebook** designed to demonstrate the power of the **hexABC REST-API programmatic interface**.
#
# The **REST API** is used to extract **trajectory fragments** and construct **meta-trajectories**. These **meta-trajectories** can then be analyzed to generate **meta-analyses** that are not directly available in the database.
#
# The workflow is powered by the [hexABC database REST API](https://mmb.irbbarcelona.org/webdev3/hexABC/rest)
# ***

# %% [markdown]
# ### Importing auxiliary libraries

# %%
import requests
import urllib
import json
import plotly
import itertools
import ipywidgets
import nglview
from IPython.display import display
from math import ceil

# %% [markdown]
# ## Initializing colab
# The two cells below are used only in case this notebook is executed via **Google Colab**. Take into account that, for running conda on **Google Colab**, the **condacolab** library must be installed. As [explained here](https://pypi.org/project/condacolab/), the installation requires a **kernel restart**, so when running this notebook in **Google Colab**, don't run all cells until this **installation** is properly **finished** and the **kernel** has **restarted**.

# %%
# Only executed when using google colab
import sys
if 'google.colab' in sys.modules:
  import subprocess
  from pathlib import Path
  try:
    subprocess.run(["conda", "-V"], check=True)
  except FileNotFoundError:
    subprocess.run([sys.executable, "-m", "pip", "install", "condacolab"], check=True)
    import condacolab
    condacolab.install()
    # Clone repository
    repo_URL = "https://github.com/mmb-irb/hexabc-meta-analyses.git"
    repo_name = Path(repo_URL).name.split('.')[0]
    if not Path(repo_name).exists():
      subprocess.run(["mamba", "install", "-y", "git"], check=True)
      subprocess.run(["git", "clone", repo_URL], check=True)
      print("⏬ Repository properly cloned.")
    # Install environment
    print("⏳ Creating environment...")
    env_file_path = f"{repo_name}/conda_env/environment.yml"
    subprocess.run(["mamba", "env", "update", "-n", "base", "-f", env_file_path], check=True)
    print("🎨 Install NGLView dependencies...")
    subprocess.run(["mamba", "install", "-y", "-c", "conda-forge", "nglview==3.0.8", "ipywidgets=7.7.2"], check=True)
    print("👍 Conda environment successfully created and updated.")

# %%
# Enable widgets for colab
if 'google.colab' in sys.modules:
  from google.colab import output
  output.enable_custom_widget_manager()

# %% [markdown]
# ### Defining auxiliary functions

# %%
#
# find_seq: finding MD simulations containing a sequence fragment; Returns metadata for the systems found.
#
def find_seq(json_data, pattern):
    complement_map = {'A': 'T', 'T': 'A', 'C': 'G', 'G': 'C'}
    complement = ''.join(complement_map[base] for base in reversed(pattern))

    matching_projects = []

    for project in json_data:
        watson_seq = project.get('sequences', [None])[0]

        if watson_seq and len(watson_seq) > 4:
            trimmed_seq = watson_seq[2:-2]  # Skip first and last 2 bases (flanking regions)
            positions = []

            #for motif in [pattern, complement]:
            for motif in [pattern]:
                pos = trimmed_seq.find(motif)
                while pos != -1:
                    # Adjust position relative to original sequence
                    positions.append((motif, pos + 2))
                    pos = trimmed_seq.find(motif, pos + 1)

            if positions:
                matching_projects.append({
                    'id': project['id'],
                    'name': project['name'],
                    'sequence': watson_seq,
                    'positions': positions
                })

    return matching_projects

# %% [markdown]
# ### Base REST-API URL

# %%
API_BASE_URL = "https://mmb.irbbarcelona.org/webdev3/hexABC/api"

# %% [markdown]
# ### Getting projects info
#
# Retrieving all the **projects metadata** from the **hexABC database**.
#
# * Endpoint used: https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects

# %%
url_get_projects = f'{API_BASE_URL}/projects?limit=1000'
with urllib.request.urlopen(url_get_projects) as response:
    r_projects = json.loads(response.read().decode("utf-8"))
print(json.dumps(r_projects, indent=4))
# Out:
# {
#     "total": 380,
#     "projects": [
#         {
#             "id": "seq001-1",
#             "accession": "seq001-1",
#             "name": "hexABC Sequence 001 - replica 1",
#             "sequences": [
#                 "GCAAACTTGTATATGTGTGC",
#                 "GCACACATATACAAGTTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq001-2",
#             "accession": "seq001-2",
#             "name": "hexABC Sequence 001 - replica 2",
#             "sequences": [
#                 "GCAAACTTGTATATGTGTGC",
#                 "GCACACATATACAAGTTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq002-1",
#             "accession": "seq002-1",
#             "name": "hexABC Sequence 002 - replica 1",
#             "sequences": [
#                 "GCAAAGACTGGTGCTTTCGC",
#                 "GCGAAAGCACCAGTCTTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq002-2",
#             "accession": "seq002-2",
#             "name": "hexABC Sequence 002 - replica 2",
#             "sequences": [
#                 "GCAAAGACTGGTGCTTTCGC",
#                 "GCGAAAGCACCAGTCTTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq003-1",
#             "accession": "seq003-1",
#             "name": "hexABC Sequence 003 - replica 1",
#             "sequences": [
#                 "GCAAAGGATGAGTGAACAGC",
#                 "GCTGTTCACTCATCCTTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq003-2",
#             "accession": "seq003-2",
#             "name": "hexABC Sequence 003 - replica 2",
#             "sequences": [
#                 "GCAAAGGATGAGTGAACAGC",
#                 "GCTGTTCACTCATCCTTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq004-1",
#             "accession": "seq004-1",
#             "name": "hexABC Sequence 004 - replica 1",
#             "sequences": [
#                 "GCAAATTTGGAGTCTAGAGC",
#                 "GCTCTAGACTCCAAATTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq004-2",
#             "accession": "seq004-2",
#             "name": "hexABC Sequence 004 - replica 2",
#             "sequences": [
#                 "GCAAATTTGGAGTCTAGAGC",
#                 "GCTCTAGACTCCAAATTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq005-1",
#             "accession": "seq005-1",
#             "name": "hexABC Sequence 005 - replica 1",
#             "sequences": [
#                 "GCAACAGAACCCCGACGGGC",
#                 "GCCCGTCGGGGTTCTGTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq005-2",
#             "accession": "seq005-2",
#             "name": "hexABC Sequence 005 - replica 2",
#             "sequences": [
#                 "GCAACAGAACCCCGACGGGC",
#                 "GCCCGTCGGGGTTCTGTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq006-1",
#             "accession": "seq006-1",
#             "name": "hexABC Sequence 006 - replica 1",
#             "sequences": [
#                 "GCAACATTTCGCCGAGGAGC",
#                 "GCTCCTCGGCGAAATGTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq006-2",
#             "accession": "seq006-2",
#             "name": "hexABC Sequence 006 - replica 2",
#             "sequences": [
#                 "GCAACATTTCGCCGAGGAGC",
#                 "GCTCCTCGGCGAAATGTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq007-1",
#             "accession": "seq007-1",
#             "name": "hexABC Sequence 007 - replica 1",
#             "sequences": [
#                 "GCAACGCAGTGTTGGACGGC",
#                 "GCCGTCCAACACTGCGTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq007-2",
#             "accession": "seq007-2",
#             "name": "hexABC Sequence 007 - replica 2",
#             "sequences": [
#                 "GCAACGCAGTGTTGGACGGC",
#                 "GCCGTCCAACACTGCGTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq008-1",
#             "accession": "seq008-1",
#             "name": "hexABC Sequence 008 - replica 1",
#             "sequences": [
#                 "GCAAGCTAGTCCGCAAAGGC",
#                 "GCCTTTGCGGACTAGCTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq008-2",
#             "accession": "seq008-2",
#             "name": "hexABC Sequence 008 - replica 2",
#             "sequences": [
#                 "GCAAGCTAGTCCGCAAAGGC",
#                 "GCCTTTGCGGACTAGCTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq009-1",
#             "accession": "seq009-1",
#             "name": "hexABC Sequence 009 - replica 1",
#             "sequences": [
#                 "GCAAGGCCTATTGCTAGCGC",
#                 "GCGCTAGCAATAGGCCTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq009-2",
#             "accession": "seq009-2",
#             "name": "hexABC Sequence 009 - replica 2",
#             "sequences": [
#                 "GCAAGGCCTATTGCTAGCGC",
#                 "GCGCTAGCAATAGGCCTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq010-1",
#             "accession": "seq010-1",
#             "name": "hexABC Sequence 010 - replica 1",
#             "sequences": [
#                 "GCAAGTGGGAAGAGAAATGC",
#                 "GCATTTCTCTTCCCACTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq010-2",
#             "accession": "seq010-2",
#             "name": "hexABC Sequence 010 - replica 2",
#             "sequences": [
#                 "GCAAGTGGGAAGAGAAATGC",
#                 "GCATTTCTCTTCCCACTTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq011-1",
#             "accession": "seq011-1",
#             "name": "hexABC Sequence 011 - replica 1",
#             "sequences": [
#                 "GCAATGATAGCCTGTAATGC",
#                 "GCATTACAGGCTATCATTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq011-2",
#             "accession": "seq011-2",
#             "name": "hexABC Sequence 011 - replica 2",
#             "sequences": [
#                 "GCAATGATAGCCTGTAATGC",
#                 "GCATTACAGGCTATCATTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq012-1",
#             "accession": "seq012-1",
#             "name": "hexABC Sequence 012 - replica 1",
#             "sequences": [
#                 "GCAATGTCCAGGGGCGGAGC",
#                 "GCTCCGCCCCTGGACATTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq012-2",
#             "accession": "seq012-2",
#             "name": "hexABC Sequence 012 - replica 2",
#             "sequences": [
#                 "GCAATGTCCAGGGGCGGAGC",
#                 "GCTCCGCCCCTGGACATTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq013-1",
#             "accession": "seq013-1",
#             "name": "hexABC Sequence 013 - replica 1",
#             "sequences": [
#                 "GCACAAAGTCTCGGGCGAGC",
#                 "GCTCGCCCGAGACTTTGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq013-2",
#             "accession": "seq013-2",
#             "name": "hexABC Sequence 013 - replica 2",
#             "sequences": [
#                 "GCACAAAGTCTCGGGCGAGC",
#                 "GCTCGCCCGAGACTTTGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq014-1",
#             "accession": "seq014-1",
#             "name": "hexABC Sequence 014 - replica 1",
#             "sequences": [
#                 "GCACAGGTAGATTAGATAGC",
#                 "GCTATCTAATCTACCTGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq014-2",
#             "accession": "seq014-2",
#             "name": "hexABC Sequence 014 - replica 2",
#             "sequences": [
#                 "GCACAGGTAGATTAGATAGC",
#                 "GCTATCTAATCTACCTGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq015-1",
#             "accession": "seq015-1",
#             "name": "hexABC Sequence 015 - replica 1",
#             "sequences": [
#                 "GCACATGTCAGAATATTGGC",
#                 "GCCAATATTCTGACATGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq015-2",
#             "accession": "seq015-2",
#             "name": "hexABC Sequence 015 - replica 2",
#             "sequences": [
#                 "GCACATGTCAGAATATTGGC",
#                 "GCCAATATTCTGACATGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq016-1",
#             "accession": "seq016-1",
#             "name": "hexABC Sequence 016 - replica 1",
#             "sequences": [
#                 "GCACCCATTAAAAAGGCGGC",
#                 "GCCGCCTTTTTAATGGGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq016-2",
#             "accession": "seq016-2",
#             "name": "hexABC Sequence 016 - replica 2",
#             "sequences": [
#                 "GCACCCATTAAAAAGGCGGC",
#                 "GCCGCCTTTTTAATGGGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq017-1",
#             "accession": "seq017-1",
#             "name": "hexABC Sequence 017 - replica 1",
#             "sequences": [
#                 "GCACGCGTAAAAGCGCTAGC",
#                 "GCTAGCGCTTTTACGCGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq017-2",
#             "accession": "seq017-2",
#             "name": "hexABC Sequence 017 - replica 2",
#             "sequences": [
#                 "GCACGCGTAAAAGCGCTAGC",
#                 "GCTAGCGCTTTTACGCGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq018-1",
#             "accession": "seq018-1",
#             "name": "hexABC Sequence 018 - replica 1",
#             "sequences": [
#                 "GCACTAGTTTGCTGCAGGGC",
#                 "GCCCTGCAGCAAACTAGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq018-2",
#             "accession": "seq018-2",
#             "name": "hexABC Sequence 018 - replica 2",
#             "sequences": [
#                 "GCACTAGTTTGCTGCAGGGC",
#                 "GCCCTGCAGCAAACTAGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq019-1",
#             "accession": "seq019-1",
#             "name": "hexABC Sequence 019 - replica 1",
#             "sequences": [
#                 "GCACTCGTTTGATGCAGAGC",
#                 "GCTCTGCATCAAACGAGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq019-2",
#             "accession": "seq019-2",
#             "name": "hexABC Sequence 019 - replica 2",
#             "sequences": [
#                 "GCACTCGTTTGATGCAGAGC",
#                 "GCTCTGCATCAAACGAGTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq020-1",
#             "accession": "seq020-1",
#             "name": "hexABC Sequence 020 - replica 1",
#             "sequences": [
#                 "GCAGAACAACGTCTGCCGGC",
#                 "GCCGGCAGACGTTGTTCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq020-2",
#             "accession": "seq020-2",
#             "name": "hexABC Sequence 020 - replica 2",
#             "sequences": [
#                 "GCAGAACAACGTCTGCCGGC",
#                 "GCCGGCAGACGTTGTTCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq021-1",
#             "accession": "seq021-1",
#             "name": "hexABC Sequence 021 - replica 1",
#             "sequences": [
#                 "GCAGACAGGAAAAACCATGC",
#                 "GCATGGTTTTTCCTGTCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq021-2",
#             "accession": "seq021-2",
#             "name": "hexABC Sequence 021 - replica 2",
#             "sequences": [
#                 "GCAGACAGGAAAAACCATGC",
#                 "GCATGGTTTTTCCTGTCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq022-1",
#             "accession": "seq022-1",
#             "name": "hexABC Sequence 022 - replica 1",
#             "sequences": [
#                 "GCAGAGCAGTCCATGAGGGC",
#                 "GCCCTCATGGACTGCTCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq022-2",
#             "accession": "seq022-2",
#             "name": "hexABC Sequence 022 - replica 2",
#             "sequences": [
#                 "GCAGAGCAGTCCATGAGGGC",
#                 "GCCCTCATGGACTGCTCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq023-1",
#             "accession": "seq023-1",
#             "name": "hexABC Sequence 023 - replica 1",
#             "sequences": [
#                 "GCAGATAACTGCCCAGGTGC",
#                 "GCACCTGGGCAGTTATCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq023-2",
#             "accession": "seq023-2",
#             "name": "hexABC Sequence 023 - replica 2",
#             "sequences": [
#                 "GCAGATAACTGCCCAGGTGC",
#                 "GCACCTGGGCAGTTATCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq024-1",
#             "accession": "seq024-1",
#             "name": "hexABC Sequence 024 - replica 1",
#             "sequences": [
#                 "GCAGATCTATTAGTTAACGC",
#                 "GCGTTAACTAATAGATCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq024-2",
#             "accession": "seq024-2",
#             "name": "hexABC Sequence 024 - replica 2",
#             "sequences": [
#                 "GCAGATCTATTAGTTAACGC",
#                 "GCGTTAACTAATAGATCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq025-1",
#             "accession": "seq025-1",
#             "name": "hexABC Sequence 025 - replica 1",
#             "sequences": [
#                 "GCAGCAAGATCATGTGGTGC",
#                 "GCACCACATGATCTTGCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq025-2",
#             "accession": "seq025-2",
#             "name": "hexABC Sequence 025 - replica 2",
#             "sequences": [
#                 "GCAGCAAGATCATGTGGTGC",
#                 "GCACCACATGATCTTGCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq026-1",
#             "accession": "seq026-1",
#             "name": "hexABC Sequence 026 - replica 1",
#             "sequences": [
#                 "GCAGCACGTAGGATCGAAGC",
#                 "GCTTCGATCCTACGTGCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq026-2",
#             "accession": "seq026-2",
#             "name": "hexABC Sequence 026 - replica 2",
#             "sequences": [
#                 "GCAGCACGTAGGATCGAAGC",
#                 "GCTTCGATCCTACGTGCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq027-1",
#             "accession": "seq027-1",
#             "name": "hexABC Sequence 027 - replica 1",
#             "sequences": [
#                 "GCAGCAGATATATAATGAGC",
#                 "GCTCATTATATATCTGCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq027-2",
#             "accession": "seq027-2",
#             "name": "hexABC Sequence 027 - replica 2",
#             "sequences": [
#                 "GCAGCAGATATATAATGAGC",
#                 "GCTCATTATATATCTGCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq028-1",
#             "accession": "seq028-1",
#             "name": "hexABC Sequence 028 - replica 1",
#             "sequences": [
#                 "GCAGCATTAGGAGATTTCGC",
#                 "GCGAAATCTCCTAATGCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq028-2",
#             "accession": "seq028-2",
#             "name": "hexABC Sequence 028 - replica 2",
#             "sequences": [
#                 "GCAGCATTAGGAGATTTCGC",
#                 "GCGAAATCTCCTAATGCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq029-1",
#             "accession": "seq029-1",
#             "name": "hexABC Sequence 029 - replica 1",
#             "sequences": [
#                 "GCAGCTTTAGAGATACAGGC",
#                 "GCCTGTATCTCTAAAGCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq029-2",
#             "accession": "seq029-2",
#             "name": "hexABC Sequence 029 - replica 2",
#             "sequences": [
#                 "GCAGCTTTAGAGATACAGGC",
#                 "GCCTGTATCTCTAAAGCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq030-1",
#             "accession": "seq030-1",
#             "name": "hexABC Sequence 030 - replica 1",
#             "sequences": [
#                 "GCAGGAATAGTCGTATCAGC",
#                 "GCTGATACGACTATTCCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq030-2",
#             "accession": "seq030-2",
#             "name": "hexABC Sequence 030 - replica 2",
#             "sequences": [
#                 "GCAGGAATAGTCGTATCAGC",
#                 "GCTGATACGACTATTCCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq031-1",
#             "accession": "seq031-1",
#             "name": "hexABC Sequence 031 - replica 1",
#             "sequences": [
#                 "GCAGGACTTGGATGTTAAGC",
#                 "GCTTAACATCCAAGTCCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq031-2",
#             "accession": "seq031-2",
#             "name": "hexABC Sequence 031 - replica 2",
#             "sequences": [
#                 "GCAGGACTTGGATGTTAAGC",
#                 "GCTTAACATCCAAGTCCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq032-1",
#             "accession": "seq032-1",
#             "name": "hexABC Sequence 032 - replica 1",
#             "sequences": [
#                 "GCAGGCGACTTACATGCAGC",
#                 "GCTGCATGTAAGTCGCCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq032-2",
#             "accession": "seq032-2",
#             "name": "hexABC Sequence 032 - replica 2",
#             "sequences": [
#                 "GCAGGCGACTTACATGCAGC",
#                 "GCTGCATGTAAGTCGCCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq033-1",
#             "accession": "seq033-1",
#             "name": "hexABC Sequence 033 - replica 1",
#             "sequences": [
#                 "GCAGGCTGCTGTTGTGGCGC",
#                 "GCGCCACAACAGCAGCCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq033-2",
#             "accession": "seq033-2",
#             "name": "hexABC Sequence 033 - replica 2",
#             "sequences": [
#                 "GCAGGCTGCTGTTGTGGCGC",
#                 "GCGCCACAACAGCAGCCTGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
# ...
#             "name": "hexABC Sequence 040 - replica 1",
#             "sequences": [
#                 "GCATCAGAGCCGTGGCTAGC",
#                 "GCTAGCCACGGCTCTGATGC"
#             ],
#             "analyses": [
#                 "helical-cp",
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq040-2",
#             "accession": "seq040-2",
#             "name": "hexABC Sequence 040 - replica 2",
#             "sequences": [
#                 "GCATCAGAGCCGTGGCTAGC",
#                 "GCTAGCCACGGCTCTGATGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq041-1",
#             "accession": "seq041-1",
#             "name": "hexABC Sequence 041 - replica 1",
#             "sequences": [
#                 "GCATGTACGCTGGAGCACGC",
#                 "GCGTGCTCCAGCGTACATGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq041-2",
#             "accession": "seq041-2",
#             "name": "hexABC Sequence 041 - replica 2",
#             "sequences": [
#                 "GCATGTACGCTGGAGCACGC",
#                 "GCGTGCTCCAGCGTACATGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq042-1",
#             "accession": "seq042-1",
#             "name": "hexABC Sequence 042 - replica 1",
#             "sequences": [
#                 "GCATGTTGACAAACAGGGGC",
#                 "GCCCCTGTTTGTCAACATGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq042-2",
#             "accession": "seq042-2",
#             "name": "hexABC Sequence 042 - replica 2",
#             "sequences": [
#                 "GCATGTTGACAAACAGGGGC",
#                 "GCCCCTGTTTGTCAACATGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq043-1",
#             "accession": "seq043-1",
#             "name": "hexABC Sequence 043 - replica 1",
#             "sequences": [
#                 "GCATTACCAAGGGCCAGGGC",
#                 "GCCCTGGCCCTTGGTAATGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq043-2",
#             "accession": "seq043-2",
#             "name": "hexABC Sequence 043 - replica 2",
#             "sequences": [
#                 "GCATTACCAAGGGCCAGGGC",
#                 "GCCCTGGCCCTTGGTAATGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq044-1",
#             "accession": "seq044-1",
#             "name": "hexABC Sequence 044 - replica 1",
#             "sequences": [
#                 "GCATTTAGGCGGTGTAACGC",
#                 "GCGTTACACCGCCTAAATGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq044-2",
#             "accession": "seq044-2",
#             "name": "hexABC Sequence 044 - replica 2",
#             "sequences": [
#                 "GCATTTAGGCGGTGTAACGC",
#                 "GCGTTACACCGCCTAAATGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq045-1",
#             "accession": "seq045-1",
#             "name": "hexABC Sequence 045 - replica 1",
#             "sequences": [
#                 "GCCAAAACGGTATGAAAGGC",
#                 "GCCTTTCATACCGTTTTGGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq045-2",
#             "accession": "seq045-2",
#             "name": "hexABC Sequence 045 - replica 2",
#             "sequences": [
#                 "GCCAAAACGGTATGAAAGGC",
#                 "GCCTTTCATACCGTTTTGGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq046-1",
#             "accession": "seq046-1",
#             "name": "hexABC Sequence 046 - replica 1",
#             "sequences": [
#                 "GCCAAGCTCTCGAAGCAGGC",
#                 "GCCTGCTTCGAGAGCTTGGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq046-2",
#             "accession": "seq046-2",
#             "name": "hexABC Sequence 046 - replica 2",
#             "sequences": [
#                 "GCCAAGCTCTCGAAGCAGGC",
#                 "GCCTGCTTCGAGAGCTTGGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq047-1",
#             "accession": "seq047-1",
#             "name": "hexABC Sequence 047 - replica 1",
#             "sequences": [
#                 "GCCACTCGGAAATTAGCAGC",
#                 "GCTGCTAATTTCCGAGTGGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq047-2",
#             "accession": "seq047-2",
#             "name": "hexABC Sequence 047 - replica 2",
#             "sequences": [
#                 "GCCACTCGGAAATTAGCAGC",
#                 "GCTGCTAATTTCCGAGTGGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq048-1",
#             "accession": "seq048-1",
#             "name": "hexABC Sequence 048 - replica 1",
#             "sequences": [
#                 "GCCAGAGAGTGCCTCGACGC",
#                 "GCGTCGAGGCACTCTCTGGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq048-2",
#             "accession": "seq048-2",
#             "name": "hexABC Sequence 048 - replica 2",
#             "sequences": [
#                 "GCCAGAGAGTGCCTCGACGC",
#                 "GCGTCGAGGCACTCTCTGGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq049-1",
#             "accession": "seq049-1",
#             "name": "hexABC Sequence 049 - replica 1",
#             "sequences": [
#                 "GCCAGCTGTAGCGCATGCGC",
#                 "GCGCATGCGCTACAGCTGGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq049-2",
#             "accession": "seq049-2",
#             "name": "hexABC Sequence 049 - replica 2",
#             "sequences": [
#                 "GCCAGCTGTAGCGCATGCGC",
#                 "GCGCATGCGCTACAGCTGGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq050-1",
#             "accession": "seq050-1",
#             "name": "hexABC Sequence 050 - replica 1",
#             "sequences": [
#                 "GCCAGGAGCGAATTTTATGC",
#                 "GCATAAAATTCGCTCCTGGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         },
#         {
#             "id": "seq050-2",
#             "accession": "seq050-2",
#             "name": "hexABC Sequence 050 - replica 2",
#             "sequences": [
#                 "GCCAGGAGCGAATTTTATGC",
#                 "GCATAAAATTCGCTCCTGGC"
#             ],
#             "analyses": [
#                 "clusters",
#                 "clusters-00",
#                 "clusters-01",
#                 "dist-perres",
#                 "energies",
#                 "fluctuation",
#                 "hbonds",
#                 "interactions",
#                 "pca",
#                 "rgyr",
#                 "rmsd-pairwise",
#                 "rmsd-perres",
#                 "rmsds",
#                 "sasa",
#                 "helical"
#             ]
#         }
#     ]
# }

# %% [markdown]
# ### Pagination
#
# If the number of **projects** exceeds the default limit (50), **pagination** is needed. In this case, we need to loop over the returned pages to store all the desired information.

# %%
# Set a list to store all the mined metadata
projects_metadata = []

# Set a list to store all the mined accession values
accessions = []

# Get the number of projects from the previous response
n_projects = r_projects['total']

# Set the limit of projects per page
limit = 100

# Calculate the expected number of pages
pages = ceil(n_projects / limit)

# Iterate over pages
for page in range(1, pages + 1):
    
    print(f'Requesting page {page}/{pages}', end='\r')
    
    # Set the URL for the projects endpoint
    # Include both limit and page parameters
    paginated_url = f'{API_BASE_URL}/projects?limit={limit}&page={page}'
    
    # Query the API
    with urllib.request.urlopen(paginated_url) as resp:
        response = json.loads(resp.read().decode("utf-8"))
        
        # Mine target data
        projects = response['projects']
        project_accessions = [ project['accession'] for project in projects]
        accessions += project_accessions
        projects_metadata = [*projects_metadata, *projects]
    
print(f'We have obtained metadata information for {len(accessions)} simulations')
# Out:
# We have obtained metadata information for 380 simulations

# %% [markdown]
# ## TRIMERS

# %% [markdown]
# ### Select the trimers
#
# Selecting the desired **trimers** from the list of all possible **DNA trimers** (e.g. AAA)

# %%
# Generate all possible DNA trimers
bases = ['A', 'T', 'C', 'G']
trimer_list = [''.join(p) for p in itertools.product(bases, repeat=3)]

mdsel = ipywidgets.Dropdown(
    options=trimer_list,
    description='Sel. trimer:',
    disabled=False,
    value='AAA' # default value
)
display(mdsel)
# Out:
# Dropdown(description='Sel. trimer:', options=('AAA', 'AAT', 'AAC', 'AAG', 'ATA', 'ATT', 'ATC', 'ATG', 'ACA', '…

# %% [markdown]
# ### Searching for trimers
#
# Looking for specific **trimeric sequence** within the **dataset**.

# %%
trimer = mdsel.value
results = find_seq(projects_metadata, trimer)

for result in results:
    print(f"{result['id']} - {result['name']}")
    print(f"  Watson strand: {result['sequence']}")
    for motif, pos in result['positions']:
        print(f"    ↳ found '{motif}' at position {pos}")
# Out:
# seq004-1 - hexABC Sequence 004 - replica 1
#   Watson strand: GCAAATTTGGAGTCTAGAGC
#     ↳ found 'AAT' at position 3
# seq004-2 - hexABC Sequence 004 - replica 2
#   Watson strand: GCAAATTTGGAGTCTAGAGC
#     ↳ found 'AAT' at position 3
# seq010-1 - hexABC Sequence 010 - replica 1
#   Watson strand: GCAAGTGGGAAGAGAAATGC
#     ↳ found 'AAT' at position 15
# seq010-2 - hexABC Sequence 010 - replica 2
#   Watson strand: GCAAGTGGGAAGAGAAATGC
#     ↳ found 'AAT' at position 15
# seq011-1 - hexABC Sequence 011 - replica 1
#   Watson strand: GCAATGATAGCCTGTAATGC
#     ↳ found 'AAT' at position 2
#     ↳ found 'AAT' at position 15
# seq011-2 - hexABC Sequence 011 - replica 2
#   Watson strand: GCAATGATAGCCTGTAATGC
#     ↳ found 'AAT' at position 2
#     ↳ found 'AAT' at position 15
# seq012-1 - hexABC Sequence 012 - replica 1
#   Watson strand: GCAATGTCCAGGGGCGGAGC
#     ↳ found 'AAT' at position 2
# seq012-2 - hexABC Sequence 012 - replica 2
#   Watson strand: GCAATGTCCAGGGGCGGAGC
#     ↳ found 'AAT' at position 2
# seq015-1 - hexABC Sequence 015 - replica 1
#   Watson strand: GCACATGTCAGAATATTGGC
#     ↳ found 'AAT' at position 11
# seq015-2 - hexABC Sequence 015 - replica 2
#   Watson strand: GCACATGTCAGAATATTGGC
#     ↳ found 'AAT' at position 11
# seq027-1 - hexABC Sequence 027 - replica 1
#   Watson strand: GCAGCAGATATATAATGAGC
#     ↳ found 'AAT' at position 13
# seq027-2 - hexABC Sequence 027 - replica 2
#   Watson strand: GCAGCAGATATATAATGAGC
#     ↳ found 'AAT' at position 13
# seq030-1 - hexABC Sequence 030 - replica 1
#   Watson strand: GCAGGAATAGTCGTATCAGC
#     ↳ found 'AAT' at position 5
# seq030-2 - hexABC Sequence 030 - replica 2
#   Watson strand: GCAGGAATAGTCGTATCAGC
#     ↳ found 'AAT' at position 5
# seq036-1 - hexABC Sequence 036 - replica 1
#   Watson strand: GCAGTAGACGCCAATGGTGC
#     ↳ found 'AAT' at position 12
# seq036-2 - hexABC Sequence 036 - replica 2
#   Watson strand: GCAGTAGACGCCAATGGTGC
#     ↳ found 'AAT' at position 12
# seq047-1 - hexABC Sequence 047 - replica 1
#   Watson strand: GCCACTCGGAAATTAGCAGC
#     ↳ found 'AAT' at position 10
# seq047-2 - hexABC Sequence 047 - replica 2
#   Watson strand: GCCACTCGGAAATTAGCAGC
#     ↳ found 'AAT' at position 10
# seq050-1 - hexABC Sequence 050 - replica 1
#   Watson strand: GCCAGGAGCGAATTTTATGC
#     ↳ found 'AAT' at position 10
# seq050-2 - hexABC Sequence 050 - replica 2
#   Watson strand: GCCAGGAGCGAATTTTATGC
#     ↳ found 'AAT' at position 10
# seq055-1 - hexABC Sequence 055 - replica 1
#   Watson strand: GCCATGAATGTAGAACGTGC
#     ↳ found 'AAT' at position 6
# seq055-2 - hexABC Sequence 055 - replica 2
#   Watson strand: GCCATGAATGTAGAACGTGC
#     ↳ found 'AAT' at position 6
# seq056-1 - hexABC Sequence 056 - replica 1
#   Watson strand: GCCCAAAATCGCAACAAGGC
#     ↳ found 'AAT' at position 6
# seq056-2 - hexABC Sequence 056 - replica 2
#   Watson strand: GCCCAAAATCGCAACAAGGC
#     ↳ found 'AAT' at position 6
# seq068-1 - hexABC Sequence 068 - replica 1
#   Watson strand: GCCGCGATAGAATGGAGGGC
#     ↳ found 'AAT' at position 10
# seq068-2 - hexABC Sequence 068 - replica 2
#   Watson strand: GCCGCGATAGAATGGAGGGC
#     ↳ found 'AAT' at position 10
# seq071-1 - hexABC Sequence 071 - replica 1
#   Watson strand: GCCGGGAACGGGGAATTAGC
#     ↳ found 'AAT' at position 13
# seq071-2 - hexABC Sequence 071 - replica 2
#   Watson strand: GCCGGGAACGGGGAATTAGC
#     ↳ found 'AAT' at position 13
# seq083-1 - hexABC Sequence 083 - replica 1
#   Watson strand: GCGAACGACCTTGTGAATGC
#     ↳ found 'AAT' at position 15
# seq083-2 - hexABC Sequence 083 - replica 2
#   Watson strand: GCGAACGACCTTGTGAATGC
#     ↳ found 'AAT' at position 15
# seq085-1 - hexABC Sequence 085 - replica 1
#   Watson strand: GCGAATTCAAAGGTGCACGC
#     ↳ found 'AAT' at position 3
# seq085-2 - hexABC Sequence 085 - replica 2
#   Watson strand: GCGAATTCAAAGGTGCACGC
#     ↳ found 'AAT' at position 3
# seq091-1 - hexABC Sequence 091 - replica 1
#   Watson strand: GCGATAGTATCCTGAAATGC
#     ↳ found 'AAT' at position 15
# seq091-2 - hexABC Sequence 091 - replica 2
#   Watson strand: GCGATAGTATCCTGAAATGC
#     ↳ found 'AAT' at position 15
# seq093-1 - hexABC Sequence 093 - replica 1
#   Watson strand: GCGCAATTGAAAATGCATGC
#     ↳ found 'AAT' at position 4
#     ↳ found 'AAT' at position 11
# seq093-2 - hexABC Sequence 093 - replica 2
#   Watson strand: GCGCAATTGAAAATGCATGC
#     ↳ found 'AAT' at position 4
#     ↳ found 'AAT' at position 11
# seq097-1 - hexABC Sequence 097 - replica 1
#   Watson strand: GCGCGCCGGATAATAATTGC
#     ↳ found 'AAT' at position 11
#     ↳ found 'AAT' at position 14
# seq097-2 - hexABC Sequence 097 - replica 2
#   Watson strand: GCGCGCCGGATAATAATTGC
#     ↳ found 'AAT' at position 11
#     ↳ found 'AAT' at position 14
# seq098-1 - hexABC Sequence 098 - replica 1
#   Watson strand: GCGCGGAATCGGAGAGACGC
#     ↳ found 'AAT' at position 6
# seq098-2 - hexABC Sequence 098 - replica 2
#   Watson strand: GCGCGGAATCGGAGAGACGC
#     ↳ found 'AAT' at position 6
# seq104-1 - hexABC Sequence 104 - replica 1
#   Watson strand: GCGGAATGACTTCGTGACGC
#     ↳ found 'AAT' at position 4
# seq104-2 - hexABC Sequence 104 - replica 2
#   Watson strand: GCGGAATGACTTCGTGACGC
#     ↳ found 'AAT' at position 4
# seq109-1 - hexABC Sequence 109 - replica 1
#   Watson strand: GCGGAGAATTGCGTGCATGC
#     ↳ found 'AAT' at position 6
# seq109-2 - hexABC Sequence 109 - replica 2
#   Watson strand: GCGGAGAATTGCGTGCATGC
#     ↳ found 'AAT' at position 6
# seq110-1 - hexABC Sequence 110 - replica 1
#   Watson strand: GCGGAGGTAAATCCGTGCGC
#     ↳ found 'AAT' at position 9
# seq110-2 - hexABC Sequence 110 - replica 2
#   Watson strand: GCGGAGGTAAATCCGTGCGC
#     ↳ found 'AAT' at position 9
# seq115-1 - hexABC Sequence 115 - replica 1
#   Watson strand: GCGGCGCCCAATTTAAAAGC
#     ↳ found 'AAT' at position 9
# seq115-2 - hexABC Sequence 115 - replica 2
#   Watson strand: GCGGCGCCCAATTTAAAAGC
#     ↳ found 'AAT' at position 9
# seq125-1 - hexABC Sequence 125 - replica 1
#   Watson strand: GCGGTAAGCGGGCAATGTGC
#     ↳ found 'AAT' at position 13
# seq125-2 - hexABC Sequence 125 - replica 2
#   Watson strand: GCGGTAAGCGGGCAATGTGC
#     ↳ found 'AAT' at position 13
# seq129-1 - hexABC Sequence 129 - replica 1
#   Watson strand: GCGTAACAATCTGAGTAGGC
#     ↳ found 'AAT' at position 7
# seq129-2 - hexABC Sequence 129 - replica 2
#   Watson strand: GCGTAACAATCTGAGTAGGC
#     ↳ found 'AAT' at position 7
# seq131-1 - hexABC Sequence 131 - replica 1
#   Watson strand: GCGTAATATGGGCTGGCAGC
#     ↳ found 'AAT' at position 4
# seq131-2 - hexABC Sequence 131 - replica 2
#   Watson strand: GCGTAATATGGGCTGGCAGC
#     ↳ found 'AAT' at position 4
# seq132-1 - hexABC Sequence 132 - replica 1
#   Watson strand: GCGTAATTGTGCGGTCTAGC
#     ↳ found 'AAT' at position 4
# seq132-2 - hexABC Sequence 132 - replica 2
#   Watson strand: GCGTAATTGTGCGGTCTAGC
#     ↳ found 'AAT' at position 4
# seq136-1 - hexABC Sequence 136 - replica 1
#   Watson strand: GCGTCGACATAATCGATGGC
#     ↳ found 'AAT' at position 10
# seq136-2 - hexABC Sequence 136 - replica 2
#   Watson strand: GCGTCGACATAATCGATGGC
#     ↳ found 'AAT' at position 10
# seq137-1 - hexABC Sequence 137 - replica 1
#   Watson strand: GCGTCGGTCAATGAAGTGGC
#     ↳ found 'AAT' at position 9
# seq137-2 - hexABC Sequence 137 - replica 2
#   Watson strand: GCGTCGGTCAATGAAGTGGC
#     ↳ found 'AAT' at position 9
# seq144-1 - hexABC Sequence 144 - replica 1
#   Watson strand: GCGTTAATCACGGGCTCAGC
#     ↳ found 'AAT' at position 5
# seq144-2 - hexABC Sequence 144 - replica 2
#   Watson strand: GCGTTAATCACGGGCTCAGC
#     ↳ found 'AAT' at position 5
# seq150-1 - hexABC Sequence 150 - replica 1
#   Watson strand: GCTAAATATAGTTGGGTAGC
#     ↳ found 'AAT' at position 4
# seq150-2 - hexABC Sequence 150 - replica 2
#   Watson strand: GCTAAATATAGTTGGGTAGC
#     ↳ found 'AAT' at position 4
# seq152-1 - hexABC Sequence 152 - replica 1
#   Watson strand: GCTAATTAAGTTCCGGAGGC
#     ↳ found 'AAT' at position 3
# seq152-2 - hexABC Sequence 152 - replica 2
#   Watson strand: GCTAATTAAGTTCCGGAGGC
#     ↳ found 'AAT' at position 3
# seq155-1 - hexABC Sequence 155 - replica 1
#   Watson strand: GCTACGTAATGTGAGCTCGC
#     ↳ found 'AAT' at position 7
# seq155-2 - hexABC Sequence 155 - replica 2
#   Watson strand: GCTACGTAATGTGAGCTCGC
#     ↳ found 'AAT' at position 7
# seq159-1 - hexABC Sequence 159 - replica 1
#   Watson strand: GCTCAAGAACTGAATACCGC
#     ↳ found 'AAT' at position 12
# seq159-2 - hexABC Sequence 159 - replica 2
#   Watson strand: GCTCAAGAACTGAATACCGC
#     ↳ found 'AAT' at position 12
# seq173-1 - hexABC Sequence 173 - replica 1
#   Watson strand: GCTGCGACAATGCGAACGGC
#     ↳ found 'AAT' at position 8
# seq173-2 - hexABC Sequence 173 - replica 2
#   Watson strand: GCTGCGACAATGCGAACGGC
#     ↳ found 'AAT' at position 8
# seq174-1 - hexABC Sequence 174 - replica 1
#   Watson strand: GCTGCGCAGAGTATTAATGC
#     ↳ found 'AAT' at position 15
# seq174-2 - hexABC Sequence 174 - replica 2
#   Watson strand: GCTGCGCAGAGTATTAATGC
#     ↳ found 'AAT' at position 15
# seq182-1 - hexABC Sequence 182 - replica 1
#   Watson strand: GCTGTGTGTTATTGGAATGC
#     ↳ found 'AAT' at position 15
# seq182-2 - hexABC Sequence 182 - replica 2
#   Watson strand: GCTGTGTGTTATTGGAATGC
#     ↳ found 'AAT' at position 15
# seq184-1 - hexABC Sequence 184 - replica 1
#   Watson strand: GCTTATGCAAAAAATAGCGC
#     ↳ found 'AAT' at position 12
# seq184-2 - hexABC Sequence 184 - replica 2
#   Watson strand: GCTTATGCAAAAAATAGCGC
#     ↳ found 'AAT' at position 12
# seq185-1 - hexABC Sequence 185 - replica 1
#   Watson strand: GCTTCGAATAAATGGCCAGC
#     ↳ found 'AAT' at position 6
#     ↳ found 'AAT' at position 10
# seq185-2 - hexABC Sequence 185 - replica 2
#   Watson strand: GCTTCGAATAAATGGCCAGC
#     ↳ found 'AAT' at position 6
#     ↳ found 'AAT' at position 10
# seq186-1 - hexABC Sequence 186 - replica 1
#   Watson strand: GCTTGCTTAAAGAATCAGGC
#     ↳ found 'AAT' at position 12
# seq186-2 - hexABC Sequence 186 - replica 2
#   Watson strand: GCTTGCTTAAAGAATCAGGC
#     ↳ found 'AAT' at position 12
# seq189-1 - hexABC Sequence 189 - replica 1
#   Watson strand: GCTTTGGCAAATAAGGAAGC
#     ↳ found 'AAT' at position 9
# seq189-2 - hexABC Sequence 189 - replica 2
#   Watson strand: GCTTTGGCAAATAAGGAAGC
#     ↳ found 'AAT' at position 9

# %% [markdown]
# ### Extract trajectories fragments
#
# For each **trimer** found, extract the **trajectory fragment** for the specific central **base pair** of the **trimer** (e.g. A**A**T). <br> Building a **meta-trajectory** from all the fragments.
#
# Endpoints used:
# * https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/{id}/structure
# * https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/{id}/trajectory

# %%
import os
from glob import glob

# Clean existing sub-trajectories
old_traj_files = sorted(glob("*_backbone.xtc"))
for f in old_traj_files:
    os.remove(f)
        
# Base topology
entry = results[0]
pos = entry['positions'][0][1] 
#ini = pos + 3 # pentamer case
ini = pos + 2 # trimer case
#ini = pos + 1 # monomer case
end = 40 - ini + 1

url_param = f"{API_BASE_URL}/projects/{entry['id']}/structure?selection={ini}%20or%20{end}"

print(url_param)

with urllib.request.urlopen(url_param) as response:
    struct = response.read()

# Filename 
topology = f"{entry['sequence']}_backbone.pdb"

# Write the binary content to disk
with open(topology, 'wb') as f:
    f.write(struct)

print(f"Structure saved as {topology}")

for result in results:
    print(f"{result['id']} - {result['name']}")
    print(f"  Watson strand: {result['sequence']}")
    
    for motif, pos in result['positions']:
        print(f"    ↳ found '{motif}' at position {pos}")

        #ini = pos + 3 # pentamer case
        ini = pos + 2 # trimer case
        #ini = pos + 1 # monomer case
        end = 40 - ini + 1
        url_param = f"{API_BASE_URL}/projects/{result['id']}/trajectory?format=xtc&frames=1:450000:500&selection={ini}%20or%20{end}"
        
        print(url_param)
        
        with urllib.request.urlopen(url_param) as response:
            traj = response.read()
    
        # Filename 
        filename = f"{result['id']}_{pos}_backbone.xtc"
        
        # Write the binary content to disk
        with open(filename, 'wb') as f:
            f.write(traj)
        
        print(f"Trajectory saved as {filename}")
# Out:
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq004-1/structure?selection=5%20or%2036
# Structure saved as GCAAATTTGGAGTCTAGAGC_backbone.pdb
# seq004-1 - hexABC Sequence 004 - replica 1
#   Watson strand: GCAAATTTGGAGTCTAGAGC
#     ↳ found 'AAT' at position 3
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq004-1/trajectory?format=xtc&frames=1:450000:500&selection=5%20or%2036
# Trajectory saved as seq004-1_3_backbone.xtc
# seq004-2 - hexABC Sequence 004 - replica 2
#   Watson strand: GCAAATTTGGAGTCTAGAGC
#     ↳ found 'AAT' at position 3
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq004-2/trajectory?format=xtc&frames=1:450000:500&selection=5%20or%2036
# Trajectory saved as seq004-2_3_backbone.xtc
# seq010-1 - hexABC Sequence 010 - replica 1
#   Watson strand: GCAAGTGGGAAGAGAAATGC
#     ↳ found 'AAT' at position 15
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq010-1/trajectory?format=xtc&frames=1:450000:500&selection=17%20or%2024
# Trajectory saved as seq010-1_15_backbone.xtc
# seq010-2 - hexABC Sequence 010 - replica 2
#   Watson strand: GCAAGTGGGAAGAGAAATGC
#     ↳ found 'AAT' at position 15
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq010-2/trajectory?format=xtc&frames=1:450000:500&selection=17%20or%2024
# Trajectory saved as seq010-2_15_backbone.xtc
# seq011-1 - hexABC Sequence 011 - replica 1
#   Watson strand: GCAATGATAGCCTGTAATGC
#     ↳ found 'AAT' at position 2
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq011-1/trajectory?format=xtc&frames=1:450000:500&selection=4%20or%2037
# Trajectory saved as seq011-1_2_backbone.xtc
#     ↳ found 'AAT' at position 15
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq011-1/trajectory?format=xtc&frames=1:450000:500&selection=17%20or%2024
# Trajectory saved as seq011-1_15_backbone.xtc
# seq011-2 - hexABC Sequence 011 - replica 2
#   Watson strand: GCAATGATAGCCTGTAATGC
#     ↳ found 'AAT' at position 2
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq011-2/trajectory?format=xtc&frames=1:450000:500&selection=4%20or%2037
# Trajectory saved as seq011-2_2_backbone.xtc
#     ↳ found 'AAT' at position 15
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq011-2/trajectory?format=xtc&frames=1:450000:500&selection=17%20or%2024
# Trajectory saved as seq011-2_15_backbone.xtc
# seq012-1 - hexABC Sequence 012 - replica 1
#   Watson strand: GCAATGTCCAGGGGCGGAGC
#     ↳ found 'AAT' at position 2
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq012-1/trajectory?format=xtc&frames=1:450000:500&selection=4%20or%2037
# Trajectory saved as seq012-1_2_backbone.xtc
# seq012-2 - hexABC Sequence 012 - replica 2
#   Watson strand: GCAATGTCCAGGGGCGGAGC
#     ↳ found 'AAT' at position 2
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq012-2/trajectory?format=xtc&frames=1:450000:500&selection=4%20or%2037
# Trajectory saved as seq012-2_2_backbone.xtc
# seq015-1 - hexABC Sequence 015 - replica 1
#   Watson strand: GCACATGTCAGAATATTGGC
#     ↳ found 'AAT' at position 11
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq015-1/trajectory?format=xtc&frames=1:450000:500&selection=13%20or%2028
# Trajectory saved as seq015-1_11_backbone.xtc
# seq015-2 - hexABC Sequence 015 - replica 2
#   Watson strand: GCACATGTCAGAATATTGGC
#     ↳ found 'AAT' at position 11
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq015-2/trajectory?format=xtc&frames=1:450000:500&selection=13%20or%2028
# Trajectory saved as seq015-2_11_backbone.xtc
# seq027-1 - hexABC Sequence 027 - replica 1
#   Watson strand: GCAGCAGATATATAATGAGC
#     ↳ found 'AAT' at position 13
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq027-1/trajectory?format=xtc&frames=1:450000:500&selection=15%20or%2026
# Trajectory saved as seq027-1_13_backbone.xtc
# seq027-2 - hexABC Sequence 027 - replica 2
#   Watson strand: GCAGCAGATATATAATGAGC
#     ↳ found 'AAT' at position 13
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq027-2/trajectory?format=xtc&frames=1:450000:500&selection=15%20or%2026
# Trajectory saved as seq027-2_13_backbone.xtc
# seq030-1 - hexABC Sequence 030 - replica 1
#   Watson strand: GCAGGAATAGTCGTATCAGC
#     ↳ found 'AAT' at position 5
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq030-1/trajectory?format=xtc&frames=1:450000:500&selection=7%20or%2034
# Trajectory saved as seq030-1_5_backbone.xtc
# seq030-2 - hexABC Sequence 030 - replica 2
#   Watson strand: GCAGGAATAGTCGTATCAGC
#     ↳ found 'AAT' at position 5
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq030-2/trajectory?format=xtc&frames=1:450000:500&selection=7%20or%2034
# Trajectory saved as seq030-2_5_backbone.xtc
# seq036-1 - hexABC Sequence 036 - replica 1
#   Watson strand: GCAGTAGACGCCAATGGTGC
#     ↳ found 'AAT' at position 12
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq036-1/trajectory?format=xtc&frames=1:450000:500&selection=14%20or%2027
# Trajectory saved as seq036-1_12_backbone.xtc
# seq036-2 - hexABC Sequence 036 - replica 2
#   Watson strand: GCAGTAGACGCCAATGGTGC
#     ↳ found 'AAT' at position 12
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq036-2/trajectory?format=xtc&frames=1:450000:500&selection=14%20or%2027
# Trajectory saved as seq036-2_12_backbone.xtc
# seq047-1 - hexABC Sequence 047 - replica 1
#   Watson strand: GCCACTCGGAAATTAGCAGC
#     ↳ found 'AAT' at position 10
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq047-1/trajectory?format=xtc&frames=1:450000:500&selection=12%20or%2029
# Trajectory saved as seq047-1_10_backbone.xtc
# seq047-2 - hexABC Sequence 047 - replica 2
#   Watson strand: GCCACTCGGAAATTAGCAGC
#     ↳ found 'AAT' at position 10
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq047-2/trajectory?format=xtc&frames=1:450000:500&selection=12%20or%2029
# Trajectory saved as seq047-2_10_backbone.xtc
# seq050-1 - hexABC Sequence 050 - replica 1
#   Watson strand: GCCAGGAGCGAATTTTATGC
#     ↳ found 'AAT' at position 10
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq050-1/trajectory?format=xtc&frames=1:450000:500&selection=12%20or%2029
# Trajectory saved as seq050-1_10_backbone.xtc
# seq050-2 - hexABC Sequence 050 - replica 2
#   Watson strand: GCCAGGAGCGAATTTTATGC
#     ↳ found 'AAT' at position 10
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq050-2/trajectory?format=xtc&frames=1:450000:500&selection=12%20or%2029
# Trajectory saved as seq050-2_10_backbone.xtc
# seq055-1 - hexABC Sequence 055 - replica 1
#   Watson strand: GCCATGAATGTAGAACGTGC
#     ↳ found 'AAT' at position 6
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq055-1/trajectory?format=xtc&frames=1:450000:500&selection=8%20or%2033
# Trajectory saved as seq055-1_6_backbone.xtc
# seq055-2 - hexABC Sequence 055 - replica 2
#   Watson strand: GCCATGAATGTAGAACGTGC
#     ↳ found 'AAT' at position 6
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq055-2/trajectory?format=xtc&frames=1:450000:500&selection=8%20or%2033
# Trajectory saved as seq055-2_6_backbone.xtc
# seq056-1 - hexABC Sequence 056 - replica 1
#   Watson strand: GCCCAAAATCGCAACAAGGC
#     ↳ found 'AAT' at position 6
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq056-1/trajectory?format=xtc&frames=1:450000:500&selection=8%20or%2033
# Trajectory saved as seq056-1_6_backbone.xtc
# seq056-2 - hexABC Sequence 056 - replica 2
#   Watson strand: GCCCAAAATCGCAACAAGGC
#     ↳ found 'AAT' at position 6
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq056-2/trajectory?format=xtc&frames=1:450000:500&selection=8%20or%2033
# Trajectory saved as seq056-2_6_backbone.xtc
# seq068-1 - hexABC Sequence 068 - replica 1
#   Watson strand: GCCGCGATAGAATGGAGGGC
#     ↳ found 'AAT' at position 10
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq068-1/trajectory?format=xtc&frames=1:450000:500&selection=12%20or%2029
# Trajectory saved as seq068-1_10_backbone.xtc
# seq068-2 - hexABC Sequence 068 - replica 2
#   Watson strand: GCCGCGATAGAATGGAGGGC
#     ↳ found 'AAT' at position 10
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq068-2/trajectory?format=xtc&frames=1:450000:500&selection=12%20or%2029
# Trajectory saved as seq068-2_10_backbone.xtc
# seq071-1 - hexABC Sequence 071 - replica 1
#   Watson strand: GCCGGGAACGGGGAATTAGC
#     ↳ found 'AAT' at position 13
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq071-1/trajectory?format=xtc&frames=1:450000:500&selection=15%20or%2026
# Trajectory saved as seq071-1_13_backbone.xtc
# seq071-2 - hexABC Sequence 071 - replica 2
#   Watson strand: GCCGGGAACGGGGAATTAGC
#     ↳ found 'AAT' at position 13
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq071-2/trajectory?format=xtc&frames=1:450000:500&selection=15%20or%2026
# Trajectory saved as seq071-2_13_backbone.xtc
# seq083-1 - hexABC Sequence 083 - replica 1
#   Watson strand: GCGAACGACCTTGTGAATGC
#     ↳ found 'AAT' at position 15
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq083-1/trajectory?format=xtc&frames=1:450000:500&selection=17%20or%2024
# Trajectory saved as seq083-1_15_backbone.xtc
# seq083-2 - hexABC Sequence 083 - replica 2
#   Watson strand: GCGAACGACCTTGTGAATGC
#     ↳ found 'AAT' at position 15
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq083-2/trajectory?format=xtc&frames=1:450000:500&selection=17%20or%2024
# Trajectory saved as seq083-2_15_backbone.xtc
# seq085-1 - hexABC Sequence 085 - replica 1
#   Watson strand: GCGAATTCAAAGGTGCACGC
#     ↳ found 'AAT' at position 3
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq085-1/trajectory?format=xtc&frames=1:450000:500&selection=5%20or%2036
# Trajectory saved as seq085-1_3_backbone.xtc
# seq085-2 - hexABC Sequence 085 - replica 2
#   Watson strand: GCGAATTCAAAGGTGCACGC
#     ↳ found 'AAT' at position 3
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq085-2/trajectory?format=xtc&frames=1:450000:500&selection=5%20or%2036
# Trajectory saved as seq085-2_3_backbone.xtc
# seq091-1 - hexABC Sequence 091 - replica 1
#   Watson strand: GCGATAGTATCCTGAAATGC
#     ↳ found 'AAT' at position 15
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq091-1/trajectory?format=xtc&frames=1:450000:500&selection=17%20or%2024
# Trajectory saved as seq091-1_15_backbone.xtc
# seq091-2 - hexABC Sequence 091 - replica 2
#   Watson strand: GCGATAGTATCCTGAAATGC
#     ↳ found 'AAT' at position 15
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq091-2/trajectory?format=xtc&frames=1:450000:500&selection=17%20or%2024
# Trajectory saved as seq091-2_15_backbone.xtc
# seq093-1 - hexABC Sequence 093 - replica 1
#   Watson strand: GCGCAATTGAAAATGCATGC
#     ↳ found 'AAT' at position 4
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq093-1/trajectory?format=xtc&frames=1:450000:500&selection=6%20or%2035
# Trajectory saved as seq093-1_4_backbone.xtc
#     ↳ found 'AAT' at position 11
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq093-1/trajectory?format=xtc&frames=1:450000:500&selection=13%20or%2028
# Trajectory saved as seq093-1_11_backbone.xtc
# seq093-2 - hexABC Sequence 093 - replica 2
#   Watson strand: GCGCAATTGAAAATGCATGC
#     ↳ found 'AAT' at position 4
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq093-2/trajectory?format=xtc&frames=1:450000:500&selection=6%20or%2035
# Trajectory saved as seq093-2_4_backbone.xtc
#     ↳ found 'AAT' at position 11
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq093-2/trajectory?format=xtc&frames=1:450000:500&selection=13%20or%2028
# Trajectory saved as seq093-2_11_backbone.xtc
# seq097-1 - hexABC Sequence 097 - replica 1
#   Watson strand: GCGCGCCGGATAATAATTGC
#     ↳ found 'AAT' at position 11
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq097-1/trajectory?format=xtc&frames=1:450000:500&selection=13%20or%2028
# Trajectory saved as seq097-1_11_backbone.xtc
#     ↳ found 'AAT' at position 14
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq097-1/trajectory?format=xtc&frames=1:450000:500&selection=16%20or%2025
# Trajectory saved as seq097-1_14_backbone.xtc
# seq097-2 - hexABC Sequence 097 - replica 2
#   Watson strand: GCGCGCCGGATAATAATTGC
#     ↳ found 'AAT' at position 11
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq097-2/trajectory?format=xtc&frames=1:450000:500&selection=13%20or%2028
# Trajectory saved as seq097-2_11_backbone.xtc
#     ↳ found 'AAT' at position 14
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq097-2/trajectory?format=xtc&frames=1:450000:500&selection=16%20or%2025
# Trajectory saved as seq097-2_14_backbone.xtc
# seq098-1 - hexABC Sequence 098 - replica 1
#   Watson strand: GCGCGGAATCGGAGAGACGC
#     ↳ found 'AAT' at position 6
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq098-1/trajectory?format=xtc&frames=1:450000:500&selection=8%20or%2033
# Trajectory saved as seq098-1_6_backbone.xtc
# seq098-2 - hexABC Sequence 098 - replica 2
#   Watson strand: GCGCGGAATCGGAGAGACGC
#     ↳ found 'AAT' at position 6
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq098-2/trajectory?format=xtc&frames=1:450000:500&selection=8%20or%2033
# Trajectory saved as seq098-2_6_backbone.xtc
# seq104-1 - hexABC Sequence 104 - replica 1
#   Watson strand: GCGGAATGACTTCGTGACGC
#     ↳ found 'AAT' at position 4
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq104-1/trajectory?format=xtc&frames=1:450000:500&selection=6%20or%2035
# Trajectory saved as seq104-1_4_backbone.xtc
# seq104-2 - hexABC Sequence 104 - replica 2
#   Watson strand: GCGGAATGACTTCGTGACGC
#     ↳ found 'AAT' at position 4
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq104-2/trajectory?format=xtc&frames=1:450000:500&selection=6%20or%2035
# Trajectory saved as seq104-2_4_backbone.xtc
# seq109-1 - hexABC Sequence 109 - replica 1
#   Watson strand: GCGGAGAATTGCGTGCATGC
#     ↳ found 'AAT' at position 6
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq109-1/trajectory?format=xtc&frames=1:450000:500&selection=8%20or%2033
# Trajectory saved as seq109-1_6_backbone.xtc
# seq109-2 - hexABC Sequence 109 - replica 2
#   Watson strand: GCGGAGAATTGCGTGCATGC
#     ↳ found 'AAT' at position 6
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq109-2/trajectory?format=xtc&frames=1:450000:500&selection=8%20or%2033
# Trajectory saved as seq109-2_6_backbone.xtc
# seq110-1 - hexABC Sequence 110 - replica 1
#   Watson strand: GCGGAGGTAAATCCGTGCGC
#     ↳ found 'AAT' at position 9
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq110-1/trajectory?format=xtc&frames=1:450000:500&selection=11%20or%2030
# Trajectory saved as seq110-1_9_backbone.xtc
# seq110-2 - hexABC Sequence 110 - replica 2
#   Watson strand: GCGGAGGTAAATCCGTGCGC
#     ↳ found 'AAT' at position 9
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq110-2/trajectory?format=xtc&frames=1:450000:500&selection=11%20or%2030
# Trajectory saved as seq110-2_9_backbone.xtc
# seq115-1 - hexABC Sequence 115 - replica 1
#   Watson strand: GCGGCGCCCAATTTAAAAGC
#     ↳ found 'AAT' at position 9
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq115-1/trajectory?format=xtc&frames=1:450000:500&selection=11%20or%2030
# Trajectory saved as seq115-1_9_backbone.xtc
# seq115-2 - hexABC Sequence 115 - replica 2
#   Watson strand: GCGGCGCCCAATTTAAAAGC
#     ↳ found 'AAT' at position 9
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq115-2/trajectory?format=xtc&frames=1:450000:500&selection=11%20or%2030
# Trajectory saved as seq115-2_9_backbone.xtc
# seq125-1 - hexABC Sequence 125 - replica 1
#   Watson strand: GCGGTAAGCGGGCAATGTGC
#     ↳ found 'AAT' at position 13
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq125-1/trajectory?format=xtc&frames=1:450000:500&selection=15%20or%2026
# Trajectory saved as seq125-1_13_backbone.xtc
# seq125-2 - hexABC Sequence 125 - replica 2
#   Watson strand: GCGGTAAGCGGGCAATGTGC
#     ↳ found 'AAT' at position 13
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq125-2/trajectory?format=xtc&frames=1:450000:500&selection=15%20or%2026
# Trajectory saved as seq125-2_13_backbone.xtc
# seq129-1 - hexABC Sequence 129 - replica 1
#   Watson strand: GCGTAACAATCTGAGTAGGC
#     ↳ found 'AAT' at position 7
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq129-1/trajectory?format=xtc&frames=1:450000:500&selection=9%20or%2032
# Trajectory saved as seq129-1_7_backbone.xtc
# seq129-2 - hexABC Sequence 129 - replica 2
#   Watson strand: GCGTAACAATCTGAGTAGGC
#     ↳ found 'AAT' at position 7
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq129-2/trajectory?format=xtc&frames=1:450000:500&selection=9%20or%2032
# Trajectory saved as seq129-2_7_backbone.xtc
# seq131-1 - hexABC Sequence 131 - replica 1
#   Watson strand: GCGTAATATGGGCTGGCAGC
#     ↳ found 'AAT' at position 4
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq131-1/trajectory?format=xtc&frames=1:450000:500&selection=6%20or%2035
# Trajectory saved as seq131-1_4_backbone.xtc
# seq131-2 - hexABC Sequence 131 - replica 2
#   Watson strand: GCGTAATATGGGCTGGCAGC
#     ↳ found 'AAT' at position 4
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq131-2/trajectory?format=xtc&frames=1:450000:500&selection=6%20or%2035
# Trajectory saved as seq131-2_4_backbone.xtc
# seq132-1 - hexABC Sequence 132 - replica 1
#   Watson strand: GCGTAATTGTGCGGTCTAGC
#     ↳ found 'AAT' at position 4
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq132-1/trajectory?format=xtc&frames=1:450000:500&selection=6%20or%2035
# Trajectory saved as seq132-1_4_backbone.xtc
# seq132-2 - hexABC Sequence 132 - replica 2
#   Watson strand: GCGTAATTGTGCGGTCTAGC
#     ↳ found 'AAT' at position 4
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq132-2/trajectory?format=xtc&frames=1:450000:500&selection=6%20or%2035
# Trajectory saved as seq132-2_4_backbone.xtc
# seq136-1 - hexABC Sequence 136 - replica 1
#   Watson strand: GCGTCGACATAATCGATGGC
#     ↳ found 'AAT' at position 10
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq136-1/trajectory?format=xtc&frames=1:450000:500&selection=12%20or%2029
# Trajectory saved as seq136-1_10_backbone.xtc
# seq136-2 - hexABC Sequence 136 - replica 2
#   Watson strand: GCGTCGACATAATCGATGGC
#     ↳ found 'AAT' at position 10
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq136-2/trajectory?format=xtc&frames=1:450000:500&selection=12%20or%2029
# Trajectory saved as seq136-2_10_backbone.xtc
# seq137-1 - hexABC Sequence 137 - replica 1
#   Watson strand: GCGTCGGTCAATGAAGTGGC
#     ↳ found 'AAT' at position 9
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq137-1/trajectory?format=xtc&frames=1:450000:500&selection=11%20or%2030
# Trajectory saved as seq137-1_9_backbone.xtc
# seq137-2 - hexABC Sequence 137 - replica 2
#   Watson strand: GCGTCGGTCAATGAAGTGGC
#     ↳ found 'AAT' at position 9
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq137-2/trajectory?format=xtc&frames=1:450000:500&selection=11%20or%2030
# Trajectory saved as seq137-2_9_backbone.xtc
# seq144-1 - hexABC Sequence 144 - replica 1
#   Watson strand: GCGTTAATCACGGGCTCAGC
#     ↳ found 'AAT' at position 5
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq144-1/trajectory?format=xtc&frames=1:450000:500&selection=7%20or%2034
# Trajectory saved as seq144-1_5_backbone.xtc
# seq144-2 - hexABC Sequence 144 - replica 2
#   Watson strand: GCGTTAATCACGGGCTCAGC
#     ↳ found 'AAT' at position 5
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq144-2/trajectory?format=xtc&frames=1:450000:500&selection=7%20or%2034
# Trajectory saved as seq144-2_5_backbone.xtc
# seq150-1 - hexABC Sequence 150 - replica 1
#   Watson strand: GCTAAATATAGTTGGGTAGC
#     ↳ found 'AAT' at position 4
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq150-1/trajectory?format=xtc&frames=1:450000:500&selection=6%20or%2035
# Trajectory saved as seq150-1_4_backbone.xtc
# seq150-2 - hexABC Sequence 150 - replica 2
#   Watson strand: GCTAAATATAGTTGGGTAGC
#     ↳ found 'AAT' at position 4
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq150-2/trajectory?format=xtc&frames=1:450000:500&selection=6%20or%2035
# Trajectory saved as seq150-2_4_backbone.xtc
# seq152-1 - hexABC Sequence 152 - replica 1
#   Watson strand: GCTAATTAAGTTCCGGAGGC
#     ↳ found 'AAT' at position 3
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq152-1/trajectory?format=xtc&frames=1:450000:500&selection=5%20or%2036
# Trajectory saved as seq152-1_3_backbone.xtc
# seq152-2 - hexABC Sequence 152 - replica 2
#   Watson strand: GCTAATTAAGTTCCGGAGGC
#     ↳ found 'AAT' at position 3
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq152-2/trajectory?format=xtc&frames=1:450000:500&selection=5%20or%2036
# Trajectory saved as seq152-2_3_backbone.xtc
# seq155-1 - hexABC Sequence 155 - replica 1
#   Watson strand: GCTACGTAATGTGAGCTCGC
#     ↳ found 'AAT' at position 7
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq155-1/trajectory?format=xtc&frames=1:450000:500&selection=9%20or%2032
# Trajectory saved as seq155-1_7_backbone.xtc
# seq155-2 - hexABC Sequence 155 - replica 2
#   Watson strand: GCTACGTAATGTGAGCTCGC
#     ↳ found 'AAT' at position 7
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq155-2/trajectory?format=xtc&frames=1:450000:500&selection=9%20or%2032
# Trajectory saved as seq155-2_7_backbone.xtc
# seq159-1 - hexABC Sequence 159 - replica 1
#   Watson strand: GCTCAAGAACTGAATACCGC
#     ↳ found 'AAT' at position 12
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq159-1/trajectory?format=xtc&frames=1:450000:500&selection=14%20or%2027
# Trajectory saved as seq159-1_12_backbone.xtc
# seq159-2 - hexABC Sequence 159 - replica 2
#   Watson strand: GCTCAAGAACTGAATACCGC
#     ↳ found 'AAT' at position 12
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq159-2/trajectory?format=xtc&frames=1:450000:500&selection=14%20or%2027
# Trajectory saved as seq159-2_12_backbone.xtc
# seq173-1 - hexABC Sequence 173 - replica 1
#   Watson strand: GCTGCGACAATGCGAACGGC
#     ↳ found 'AAT' at position 8
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq173-1/trajectory?format=xtc&frames=1:450000:500&selection=10%20or%2031
# Trajectory saved as seq173-1_8_backbone.xtc
# seq173-2 - hexABC Sequence 173 - replica 2
#   Watson strand: GCTGCGACAATGCGAACGGC
#     ↳ found 'AAT' at position 8
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq173-2/trajectory?format=xtc&frames=1:450000:500&selection=10%20or%2031
# Trajectory saved as seq173-2_8_backbone.xtc
# seq174-1 - hexABC Sequence 174 - replica 1
#   Watson strand: GCTGCGCAGAGTATTAATGC
#     ↳ found 'AAT' at position 15
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq174-1/trajectory?format=xtc&frames=1:450000:500&selection=17%20or%2024
# Trajectory saved as seq174-1_15_backbone.xtc
# seq174-2 - hexABC Sequence 174 - replica 2
#   Watson strand: GCTGCGCAGAGTATTAATGC
#     ↳ found 'AAT' at position 15
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq174-2/trajectory?format=xtc&frames=1:450000:500&selection=17%20or%2024
# Trajectory saved as seq174-2_15_backbone.xtc
# seq182-1 - hexABC Sequence 182 - replica 1
#   Watson strand: GCTGTGTGTTATTGGAATGC
#     ↳ found 'AAT' at position 15
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq182-1/trajectory?format=xtc&frames=1:450000:500&selection=17%20or%2024
# Trajectory saved as seq182-1_15_backbone.xtc
# seq182-2 - hexABC Sequence 182 - replica 2
#   Watson strand: GCTGTGTGTTATTGGAATGC
#     ↳ found 'AAT' at position 15
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq182-2/trajectory?format=xtc&frames=1:450000:500&selection=17%20or%2024
# Trajectory saved as seq182-2_15_backbone.xtc
# seq184-1 - hexABC Sequence 184 - replica 1
#   Watson strand: GCTTATGCAAAAAATAGCGC
#     ↳ found 'AAT' at position 12
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq184-1/trajectory?format=xtc&frames=1:450000:500&selection=14%20or%2027
# Trajectory saved as seq184-1_12_backbone.xtc
# seq184-2 - hexABC Sequence 184 - replica 2
#   Watson strand: GCTTATGCAAAAAATAGCGC
#     ↳ found 'AAT' at position 12
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq184-2/trajectory?format=xtc&frames=1:450000:500&selection=14%20or%2027
# Trajectory saved as seq184-2_12_backbone.xtc
# seq185-1 - hexABC Sequence 185 - replica 1
#   Watson strand: GCTTCGAATAAATGGCCAGC
#     ↳ found 'AAT' at position 6
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq185-1/trajectory?format=xtc&frames=1:450000:500&selection=8%20or%2033
# Trajectory saved as seq185-1_6_backbone.xtc
#     ↳ found 'AAT' at position 10
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq185-1/trajectory?format=xtc&frames=1:450000:500&selection=12%20or%2029
# Trajectory saved as seq185-1_10_backbone.xtc
# seq185-2 - hexABC Sequence 185 - replica 2
#   Watson strand: GCTTCGAATAAATGGCCAGC
#     ↳ found 'AAT' at position 6
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq185-2/trajectory?format=xtc&frames=1:450000:500&selection=8%20or%2033
# Trajectory saved as seq185-2_6_backbone.xtc
#     ↳ found 'AAT' at position 10
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq185-2/trajectory?format=xtc&frames=1:450000:500&selection=12%20or%2029
# Trajectory saved as seq185-2_10_backbone.xtc
# seq186-1 - hexABC Sequence 186 - replica 1
#   Watson strand: GCTTGCTTAAAGAATCAGGC
#     ↳ found 'AAT' at position 12
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq186-1/trajectory?format=xtc&frames=1:450000:500&selection=14%20or%2027
# Trajectory saved as seq186-1_12_backbone.xtc
# seq186-2 - hexABC Sequence 186 - replica 2
#   Watson strand: GCTTGCTTAAAGAATCAGGC
#     ↳ found 'AAT' at position 12
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq186-2/trajectory?format=xtc&frames=1:450000:500&selection=14%20or%2027
# Trajectory saved as seq186-2_12_backbone.xtc
# seq189-1 - hexABC Sequence 189 - replica 1
#   Watson strand: GCTTTGGCAAATAAGGAAGC
#     ↳ found 'AAT' at position 9
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq189-1/trajectory?format=xtc&frames=1:450000:500&selection=11%20or%2030
# Trajectory saved as seq189-1_9_backbone.xtc
# seq189-2 - hexABC Sequence 189 - replica 2
#   Watson strand: GCTTTGGCAAATAAGGAAGC
#     ↳ found 'AAT' at position 9
# https://mmb.irbbarcelona.org/webdev3/hexABC/api/projects/seq189-2/trajectory?format=xtc&frames=1:450000:500&selection=11%20or%2030
# Trajectory saved as seq189-2_9_backbone.xtc

# %% [markdown]
# ### Building a meta-trajectory
#
# Taking all the **trajectory fragments**, putting them all together and aligning all frames to the first one. The resulting file is the meta-trajectory with all conformations of the specific central base-pair of the specific trimer found in the whole hexABC dataset.
#
# Combining all **trajectory fragments** into a **single file** and **aligning** every frame to the first one yields a **meta-trajectory**. This **meta-trajectory** captures all **conformations** of the specific **central base pair** within the specified **trimer**, as observed across the entire **hexABC dataset**.

# %%
import MDAnalysis as mda
from MDAnalysis.coordinates.XTC import XTCWriter
from MDAnalysis.analysis import align

# Grab all trajectory files you saved
traj_files = sorted(glob("*_backbone.xtc"))

# Load initial universe and get reference positions
u = mda.Universe(topology, traj_files[0])

# Output writer
with XTCWriter("meta_trajectory.xtc", n_atoms=u.atoms.n_atoms) as writer:
    for traj_file in traj_files:
        print(f"Appending: {traj_file}")
        u.load_new(traj_file)
        for ts in u.trajectory:
            writer.write(u.atoms)

# Load your meta-trajectory
u = mda.Universe(topology, "meta_trajectory.xtc")

# Align to first frame using "backbone" or your preferred atom group
aligner = align.AlignTraj(u, u, select="all", in_memory=True)
aligner.run()

# Write aligned frames using a writer
with XTCWriter("meta_trajectory_aligned.xtc", n_atoms=u.atoms.n_atoms) as writer:
    for ts in u.trajectory:
        writer.write(u.atoms)
# Out:
# /opt/anaconda3/envs/hexABC_DB/lib/python3.12/site-packages/MDAnalysis/coordinates/XDR.py:253: UserWarning: Reload offsets from trajectory
#  ctime or size or n_atoms did not match
#   warnings.warn(
# Appending: seq004-1_3_backbone.xtc
# Appending: seq004-2_3_backbone.xtc
# Appending: seq010-1_15_backbone.xtc
# Appending: seq010-2_15_backbone.xtc
# Appending: seq011-1_15_backbone.xtc
# Appending: seq011-1_2_backbone.xtc
# Appending: seq011-2_15_backbone.xtc
# Appending: seq011-2_2_backbone.xtc
# Appending: seq012-1_2_backbone.xtc
# Appending: seq012-2_2_backbone.xtc
# Appending: seq015-1_11_backbone.xtc
# Appending: seq015-2_11_backbone.xtc
# Appending: seq027-1_13_backbone.xtc
# Appending: seq027-2_13_backbone.xtc
# Appending: seq030-1_5_backbone.xtc
# Appending: seq030-2_5_backbone.xtc
# Appending: seq036-1_12_backbone.xtc
# Appending: seq036-2_12_backbone.xtc
# Appending: seq047-1_10_backbone.xtc
# Appending: seq047-2_10_backbone.xtc
# Appending: seq050-1_10_backbone.xtc
# Appending: seq050-2_10_backbone.xtc
# Appending: seq055-1_6_backbone.xtc
# Appending: seq055-2_6_backbone.xtc
# Appending: seq056-1_6_backbone.xtc
# Appending: seq056-2_6_backbone.xtc
# Appending: seq068-1_10_backbone.xtc
# Appending: seq068-2_10_backbone.xtc
# Appending: seq071-1_13_backbone.xtc
# Appending: seq071-2_13_backbone.xtc
# Appending: seq083-1_15_backbone.xtc
# Appending: seq083-2_15_backbone.xtc
# Appending: seq085-1_3_backbone.xtc
# Appending: seq085-2_3_backbone.xtc
# Appending: seq091-1_15_backbone.xtc
# Appending: seq091-2_15_backbone.xtc
# Appending: seq093-1_11_backbone.xtc
# Appending: seq093-1_4_backbone.xtc
# Appending: seq093-2_11_backbone.xtc
# Appending: seq093-2_4_backbone.xtc
# Appending: seq097-1_11_backbone.xtc
# Appending: seq097-1_14_backbone.xtc
# Appending: seq097-2_11_backbone.xtc
# Appending: seq097-2_14_backbone.xtc
# Appending: seq098-1_6_backbone.xtc
# Appending: seq098-2_6_backbone.xtc
# Appending: seq104-1_4_backbone.xtc
# Appending: seq104-2_4_backbone.xtc
# Appending: seq109-1_6_backbone.xtc
# Appending: seq109-2_6_backbone.xtc
# Appending: seq110-1_9_backbone.xtc
# Appending: seq110-2_9_backbone.xtc
# Appending: seq115-1_9_backbone.xtc
# Appending: seq115-2_9_backbone.xtc
# Appending: seq125-1_13_backbone.xtc
# Appending: seq125-2_13_backbone.xtc
# Appending: seq129-1_7_backbone.xtc
# Appending: seq129-2_7_backbone.xtc
# Appending: seq131-1_4_backbone.xtc
# Appending: seq131-2_4_backbone.xtc
# Appending: seq132-1_4_backbone.xtc
# Appending: seq132-2_4_backbone.xtc
# Appending: seq136-1_10_backbone.xtc
# Appending: seq136-2_10_backbone.xtc
# Appending: seq137-1_9_backbone.xtc
# Appending: seq137-2_9_backbone.xtc
# Appending: seq144-1_5_backbone.xtc
# Appending: seq144-2_5_backbone.xtc
# Appending: seq150-1_4_backbone.xtc
# Appending: seq150-2_4_backbone.xtc
# Appending: seq152-1_3_backbone.xtc
# Appending: seq152-2_3_backbone.xtc
# Appending: seq155-1_7_backbone.xtc
# Appending: seq155-2_7_backbone.xtc
# Appending: seq159-1_12_backbone.xtc
# Appending: seq159-2_12_backbone.xtc
# Appending: seq173-1_8_backbone.xtc
# Appending: seq173-2_8_backbone.xtc
# Appending: seq174-1_15_backbone.xtc
# Appending: seq174-2_15_backbone.xtc
# Appending: seq182-1_15_backbone.xtc
# Appending: seq182-2_15_backbone.xtc
# Appending: seq184-1_12_backbone.xtc
# Appending: seq184-2_12_backbone.xtc
# Appending: seq185-1_10_backbone.xtc
# Appending: seq185-1_6_backbone.xtc
# Appending: seq185-2_10_backbone.xtc
# Appending: seq185-2_6_backbone.xtc
# Appending: seq186-1_12_backbone.xtc
# Appending: seq186-2_12_backbone.xtc
# Appending: seq189-1_9_backbone.xtc
# Appending: seq189-2_9_backbone.xtc

# %% [markdown]
# ### Visualize meta-trajectory
#
# Representing the **meta-trajectory** with **NGLview**

# %%
# Show trajectory
view = nglview.show_simpletraj(nglview.SimpletrajTrajectory("meta_trajectory_aligned.xtc", topology), gui=True)
view
# Out:
# NGLWidget(max_frame=82799)

# %% [markdown]
# ### Clustering the meta-trajectory
#
# **Clustering** the **meta-trajectory** by **RMSd**. Extracting a set of **50 centroids** representing the most populated **conformations** from the chosen **base pair**.

# %%
import mdtraj as md
from sklearn.cluster import KMeans
import numpy as np

# Load trajectory
traj = md.load("meta_trajectory_aligned.xtc", top=topology)

# Flatten coordinates for clustering
X = traj.xyz.reshape(traj.n_frames, -1)

# Cluster into k groups
k = 50
kmeans = KMeans(n_clusters=k, random_state=42).fit(X)
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# Find closest frame to each centroid
from scipy.spatial.distance import cdist
closest_frames = np.argmin(cdist(X, centroids), axis=0)

# Extract those frames
centroid_traj = traj.slice(closest_frames)

# Save them into one multi-model PDB file
centroid_traj.save("cluster_centroids.pdb")

# %% [markdown]
# ### Visualize centroids (conformations)
#
# Representing the **clustering centroids** including the different **conformations** for the specific **base pair** with **NGLview**

# %%
view = nglview.show_structure_file("cluster_centroids.pdb", default_representation=False)
view.add_representation(repr_type='ball+stick', selection='all', color='element')
view.center()
view._remote_call('setSize', target='Widget', args=['','400px'])
view
# Out:
# NGLWidget()

# %% [markdown]
# ### Visualize conformations
#
# Representing the most relevant **conformations** found for the specific **base pair** with **NGLview**.
# For this specific case (A**A**T):
# - Left: **Watson-Crick** canonical base pairing
# - Middle: **Hoogsteen** base pairing
# - Right: **Opening**
#
# **Rotating / Translating** in the **left** pannel will trigger the same **rotations / translations** to the **middle** and **right** pannels.

# %%
# Show conformations
view1 = nglview.show_structure_file("cluster_centroids.pdb", default_representation=False)
view1._remote_call('setSize', target='Widget', args=['350px','400px'])
view1.add_representation(repr_type='ball+stick', selection='/1', color='element')
view1.camera='orthographic'
view1.center()
view1
view2 = nglview.show_structure_file("cluster_centroids.pdb", default_representation=False)
view2._remote_call('setSize', target='Widget', args=['350px','400px'])
view2.add_representation(repr_type='ball+stick', selection='/22', color='element')
view2.camera='orthographic'
view2.center()
view2
view3 = nglview.show_structure_file("cluster_centroids.pdb", default_representation=False)
view3._remote_call('setSize', target='Widget', args=['350px','400px'])
view3.add_representation(repr_type='ball+stick', selection='/11', color='element')
view3.camera='orthographic'
view3.center()
view3

def on_change(change):
    view2._set_camera_orientation(change['new'])
    view3._set_camera_orientation(change['new'])
    
view1.observe(on_change, ['_camera_orientation'])

ipywidgets.HBox([view1, view2, view3])
# Out:
# HBox(children=(NGLWidget(), NGLWidget(), NGLWidget()))
